# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import *
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer, make_column_selector,make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score

# %%
_ARREST_KEY = "ARREST_KEY"

_ARREST_BORO = "ARREST_BORO"
_JURISDICTION_CODE = "JURISDICTION_CODE"
_OFFENSE_LEVEL = "LAW_CAT_CD"

_ARREST_DATE = "ARREST_DATE"
_ARREST_MONTH = "ARREST_MONTH" 

_ARREST_PRECINCT = "ARREST_PRECINCT"

_PERPETRATOR_RACE = "PERP_RACE"
_PERPETRATOR_SEX = "PERP_SEX"
_PERPETRATOR_AGE_GROUP="AGE_GROUP"

_INTERNAL_CLASSIFICATION="PD_CD"
_INTERNAL_CLASSIFICATION_DESCRIPTION="PD_DESC"
_THREE_DIGIT_INTERNAL_CLASSIFICATION="KY_CD"

_LAW_CODE="LAW_CODE"

_GEOGRAPHICAL_POSITION = "New Georeferenced Column"

_NYS_X_COORD = "X_COORD_CD"
_NYS_Y_COORD = "Y_COORD_CD"

_LATITUDE='Latitude'
_LONGITUDE='Longitude'

# %%
df = pd.read_csv('./cleaned_data.csv')
df.head()
# Out:
#         OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  ARREST_PRECINCT  \
# 0  FELONY ASSAULT  PL-1211200          F           Q              105
# 1  FELONY ASSAULT  PL-1200502          F           B               48
# 2  FELONY ASSAULT  PL-1200512          F           S              121
# 3  FELONY ASSAULT  PL-1211200          F           Q              100
# 4            RAPE  PL-1302503          F           M               14
#
#    JURISDICTION_CODE   Latitude  Longitude ARREST_MONTH
# 0                  0  40.737043 -73.735514      January
# 1                  0  40.855109 -73.892818        March
# 2                  0  40.628967 -74.163275          May
# 3                  0  40.591980 -73.800066         June
# 4                  0  40.753533 -73.994537      January

# %%
df[_ARREST_PRECINCT] = df[_ARREST_PRECINCT].astype('object')

# %%
df_num= df.select_dtypes(exclude='object')
df_obj= df.select_dtypes(include='object')

df_num.info()
df_obj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188682 entries, 0 to 188681
# Data columns (total 3 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   JURISDICTION_CODE  188682 non-null  int64
#  1   Latitude           188682 non-null  float64
#  2   Longitude          188682 non-null  float64
# dtypes: float64(2), int64(1)
# memory usage: 4.3 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188682 entries, 0 to 188681
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   OFNS_DESC        188682 non-null  object
#  1   LAW_CODE         188682 non-null  object
#  2   LAW_CAT_CD       188682 non-null  object
#  3   ARREST_BORO      188682 non-null  object
#  4   ARREST_PRECINCT  188682 non-null  object
#  5   ARREST_MONTH     188682 non-null  object
# dtypes: object(6)
# memory usage: 8.6+ MB

# %%
df_obj[_OFFENSE_LEVEL].unique()
#df_obj=df_obj.drop(columns=["OFNS_DESC","LAW_CODE"])# drop some columns to deal with out of mem error
#!!! these features make a huge diff in accuracy.
# Out:
# array(['F', 'M', 'V'], dtype=object)

# %%
df_obj= pd.get_dummies(df_obj, drop_first=True)

target = (df_obj['LAW_CAT_CD_M'])
df_obj = df_obj.drop(columns=['LAW_CAT_CD_M'],axis=1)
df_obj
# Out:
#         OFNS_DESC_ADMINISTRATIVE CODES  \
# 0                                False
# 1                                False
# 2                                False
# 3                                False
# 4                                False
# ...                                ...
# 188677                           False
# 188678                           False
# 188679                           False
# 188680                           False
# 188681                           False
#
#         OFNS_DESC_ALCOHOLIC BEVERAGE CONTROL LAW  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ...                                          ...
# 188677                                     False
# 188678                                     False
# 188679                                     False
# 188680                                     False
# 188681                                     False
#
#         OFNS_DESC_ANTICIPATORY OFFENSES  OFNS_DESC_ARSON  \
# 0                                 False            False
# 1                                 False            False
# 2                                 False            False
# 3                                 False            False
# 4                                 False            False
# ...                                 ...              ...
# 188677                            False            False
# 188678                            False            False
# 188679                            False            False
# 188680                            False            False
# 188681                            False            False
#
#         OFNS_DESC_ASSAULT 3 & RELATED OFFENSES  OFNS_DESC_BURGLAR'S TOOLS  \
# 0                                        False                      False
# 1                                        False                      False
# 2                                        False                      False
# 3                                        False                      False
# 4                                        False                      False
# ...                                        ...                        ...
# 188677                                   False                      False
# 188678                                    True                      False
# 188679                                   False                      False
# 188680                                   False                      False
# 188681                                   False                      False
#
#         OFNS_DESC_BURGLARY  OFNS_DESC_CANNABIS RELATED OFFENSES  \
# 0                    False                                False
# 1                    False                                False
# 2                    False                                False
# 3                    False                                False
# 4                    False                                False
# ...                    ...                                  ...
# 188677               False                                False
# 188678               False                                False
# 188679                True                                False
# 188680               False                                False
# 188681               False                                False
#
#         OFNS_DESC_CHILD ABANDONMENT/NON SUPPORT 1  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
# ...                                           ...
# 188677                                      False
# 188678                                      False
# 188679                                      False
# 188680                                      False
# 188681                                      False
#
#         OFNS_DESC_CRIMINAL MISCHIEF & RELATED OF  ...  ARREST_PRECINCT_122  \
# 0                                          False  ...                False
# 1                                          False  ...                False
# 2                                          False  ...                False
# 3                                          False  ...                False
# 4                                          False  ...                False
# ...                                          ...  ...                  ...
# 188677                                     False  ...                False
# 188678                                     False  ...                False
# 188679                                     False  ...                False
# 188680                                     False  ...                False
# 188681                                     False  ...                False
#
#         ARREST_PRECINCT_123  ARREST_MONTH_August  ARREST_MONTH_February  \
# 0                     False                False                  False
# 1                     False                False                  False
# 2                     False                False                  False
# 3                     False                False                  False
# 4                     False                False                  False
# ...                     ...                  ...                    ...
# 188677                False                False                  False
# 188678                False                False                  False
# 188679                False                False                  False
# 188680                False                False                  False
# 188681                False                False                  False
#
#         ARREST_MONTH_January  ARREST_MONTH_July  ARREST_MONTH_June  \
# 0                       True              False              False
# 1                      False              False              False
# 2                      False              False              False
# 3                      False              False               True
# 4                       True              False              False
# ...                      ...                ...                ...
# 188677                 False              False              False
# 188678                 False              False              False
# 188679                 False              False              False
# 188680                 False              False              False
# 188681                 False              False              False
#
#         ARREST_MONTH_March  ARREST_MONTH_May  ARREST_MONTH_September
# 0                    False             False                   False
# 1                     True             False                   False
# 2                    False              True                   False
# 3                    False             False                   False
# 4                    False             False                   False
# ...                    ...               ...                     ...
# 188677               False             False                    True
# 188678               False             False                    True
# 188679               False             False                    True
# 188680               False             False                    True
# 188681               False             False                    True
#
# [188682 rows x 1100 columns]

# %%
attr = pd.concat([df_obj,df_num],axis=1)


print(attr.shape[1])
attr.head()
# Out:
# 1103
#    OFNS_DESC_ADMINISTRATIVE CODES  OFNS_DESC_ALCOHOLIC BEVERAGE CONTROL LAW  \
# 0                           False                                     False
# 1                           False                                     False
# 2                           False                                     False
# 3                           False                                     False
# 4                           False                                     False
#
#    OFNS_DESC_ANTICIPATORY OFFENSES  OFNS_DESC_ARSON  \
# 0                            False            False
# 1                            False            False
# 2                            False            False
# 3                            False            False
# 4                            False            False
#
#    OFNS_DESC_ASSAULT 3 & RELATED OFFENSES  OFNS_DESC_BURGLAR'S TOOLS  \
# 0                                   False                      False
# 1                                   False                      False
# 2                                   False                      False
# 3                                   False                      False
# 4                                   False                      False
#
#    OFNS_DESC_BURGLARY  OFNS_DESC_CANNABIS RELATED OFFENSES  \
# 0               False                                False
# 1               False                                False
# 2               False                                False
# 3               False                                False
# 4               False                                False
#
#    OFNS_DESC_CHILD ABANDONMENT/NON SUPPORT 1  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#    OFNS_DESC_CRIMINAL MISCHIEF & RELATED OF  ...  ARREST_MONTH_February  \
# 0                                     False  ...                  False
# 1                                     False  ...                  False
# 2                                     False  ...                  False
# 3                                     False  ...                  False
# 4                                     False  ...                  False
#
#    ARREST_MONTH_January  ARREST_MONTH_July  ARREST_MONTH_June  \
# 0                  True              False              False
# 1                 False              False              False
# 2                 False              False              False
# 3                 False              False               True
# 4                  True              False              False
#
#    ARREST_MONTH_March  ARREST_MONTH_May  ARREST_MONTH_September  \
# 0               False             False                   False
# 1                True             False                   False
# 2               False              True                   False
# 3               False             False                   False
# 4               False             False                   False
#
#    JURISDICTION_CODE   Latitude  Longitude
# 0                  0  40.737043 -73.735514
# 1                  0  40.855109 -73.892818
# 2                  0  40.628967 -74.163275
# 3                  0  40.591980 -73.800066
# 4                  0  40.753533 -73.994537
#
# [5 rows x 1103 columns]

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and test
attr_train, attr_test, target_train, target_test = train_test_split(attr, target, test_size=0.20, random_state=5)

# %%
attr_train.head()
# Out:
#         OFNS_DESC_ADMINISTRATIVE CODES  \
# 157705                           False
# 57809                            False
# 25319                            False
# 48111                            False
# 61612                            False
#
#         OFNS_DESC_ALCOHOLIC BEVERAGE CONTROL LAW  \
# 157705                                     False
# 57809                                      False
# 25319                                      False
# 48111                                      False
# 61612                                      False
#
#         OFNS_DESC_ANTICIPATORY OFFENSES  OFNS_DESC_ARSON  \
# 157705                            False            False
# 57809                             False            False
# 25319                             False            False
# 48111                             False            False
# 61612                             False            False
#
#         OFNS_DESC_ASSAULT 3 & RELATED OFFENSES  OFNS_DESC_BURGLAR'S TOOLS  \
# 157705                                   False                      False
# 57809                                    False                      False
# 25319                                    False                      False
# 48111                                    False                      False
# 61612                                    False                      False
#
#         OFNS_DESC_BURGLARY  OFNS_DESC_CANNABIS RELATED OFFENSES  \
# 157705               False                                False
# 57809                False                                False
# 25319                False                                False
# 48111                False                                False
# 61612                False                                False
#
#         OFNS_DESC_CHILD ABANDONMENT/NON SUPPORT 1  \
# 157705                                      False
# 57809                                       False
# 25319                                       False
# 48111                                       False
# 61612                                       False
#
#         OFNS_DESC_CRIMINAL MISCHIEF & RELATED OF  ...  ARREST_MONTH_February  \
# 157705                                     False  ...                  False
# 57809                                      False  ...                   True
# 25319                                      False  ...                   True
# 48111                                      False  ...                   True
# 61612                                      False  ...                  False
#
#         ARREST_MONTH_January  ARREST_MONTH_July  ARREST_MONTH_June  \
# 157705                 False              False              False
# 57809                  False              False              False
# 25319                  False              False              False
# 48111                  False              False              False
# 61612                  False              False              False
#
#         ARREST_MONTH_March  ARREST_MONTH_May  ARREST_MONTH_September  \
# 157705               False             False                   False
# 57809                False             False                   False
# 25319                False             False                   False
# 48111                False             False                   False
# 61612                 True             False                   False
#
#         JURISDICTION_CODE   Latitude  Longitude
# 157705                  0  40.594054 -73.960866
# 57809                   0  40.701098 -73.903569
# 25319                   0  40.822306 -73.914843
# 48111                   1  40.604783 -73.753998
# 61612                   0  40.871489 -73.904459
#
# [5 rows x 1103 columns]

# %%
from sklearn.compose import make_column_selector

cat_selector = make_column_selector(dtype_include=bool)
num_selector = make_column_selector(dtype_include=np.number)
num_selector(attr_train)
# Out:
# ['JURISDICTION_CODE', 'Latitude', 'Longitude']

# %%
cat_selector(attr_train)
# Out:
# ['OFNS_DESC_ADMINISTRATIVE CODES',
#  'OFNS_DESC_ALCOHOLIC BEVERAGE CONTROL LAW',
#  'OFNS_DESC_ANTICIPATORY OFFENSES',
#  'OFNS_DESC_ARSON',
#  'OFNS_DESC_ASSAULT 3 & RELATED OFFENSES',
#  "OFNS_DESC_BURGLAR'S TOOLS",
#  'OFNS_DESC_BURGLARY',
#  'OFNS_DESC_CANNABIS RELATED OFFENSES',
#  'OFNS_DESC_CHILD ABANDONMENT/NON SUPPORT 1',
#  'OFNS_DESC_CRIMINAL MISCHIEF & RELATED OF',
#  'OFNS_DESC_CRIMINAL TRESPASS',
#  'OFNS_DESC_DANGEROUS DRUGS',
#  'OFNS_DESC_DANGEROUS WEAPONS',
#  'OFNS_DESC_DISORDERLY CONDUCT',
#  'OFNS_DESC_DISRUPTION OF A RELIGIOUS SERV',
#  'OFNS_DESC_ESCAPE 3',
#  'OFNS_DESC_FELONY ASSAULT',
#  'OFNS_DESC_FORGERY',
#  'OFNS_DESC_FORTUNE TELLING',
#  'OFNS_DESC_FRAUDS',
#  'OFNS_DESC_FRAUDULENT ACCOSTING',
#  'OFNS_DESC_GAMBLING',
#  'OFNS_DESC_GRAND LARCENY',
#  'OFNS_DESC_GRAND LARCENY OF MOTOR VEHICLE',
#  'OFNS_DESC_HARRASSMENT 2',
#  'OFNS_DESC_HOMICIDE-NEGLIGENT,UNCLASSIFIE',
#  'OFNS_DESC_HOMICIDE-NEGLIGENT-VEHICLE',
#  'OFNS_DESC_INTOXICATED & IMPAIRED DRIVING',
#  'OFNS_DESC_INTOXICATED/IMPAIRED DRIVING',
#  'OFNS_DESC_JOSTLING',
#  'OFNS_DESC_KIDNAPPING & RELATED OFFENSES',
#  'OFNS_DESC_LOITERING',
#  'OFNS_DESC_LOITERING/GAMBLING (CARDS, DIC',
#  'OFNS_DESC_MISCELLANEOUS PENAL LAW',
#  'OFNS_DESC_MOVING INFRACTIONS',
#  'OFNS_DESC_MURDER & NON-NEGL. MANSLAUGHTE',
#  'OFNS_DESC_OFF. AGNST PUB ORD SENSBLTY &',
#  'OFNS_DESC_OFFENSES AGAINST PUBLIC ADMINI',
#  'OFNS_DESC_OFFENSES AGAINST PUBLIC SAFETY',
#  'OFNS_DESC_OFFENSES AGAINST THE PERSON',
#  'OFNS_DESC_OFFENSES INVOLVING FRAUD',
#  'OFNS_DESC_OFFENSES RELATED TO CHILDREN',
#  'OFNS_DESC_OTHER OFFENSES RELATED TO THEFT',
#  'OFNS_DESC_OTHER STATE LAWS',
#  'OFNS_DESC_OTHER STATE LAWS (NON PENAL LAW)',
#  'OFNS_DESC_OTHER TRAFFIC INFRACTION',
#  'OFNS_DESC_PETIT LARCENY',
#  'OFNS_DESC_POSSESSION OF STOLEN PROPERTY',
#  'OFNS_DESC_PROSTITUTION & RELATED OFFENSES',
#  'OFNS_DESC_RAPE',
#  'OFNS_DESC_ROBBERY',
#  'OFNS_DESC_SEX CRIMES',
#  'OFNS_DESC_THEFT-FRAUD',
#  'OFNS_DESC_UNAUTHORIZED USE OF A VEHICLE',
#  'OFNS_DESC_VEHICLE AND TRAFFIC LAWS',
#  'LAW_CODE_ABC00000MA',
#  'LAW_CODE_ABC00000V0',
#  'LAW_CODE_ABC0064A00',
#  'LAW_CODE_ABC0064B00',
#  'LAW_CODE_ABC0065000',
#  'LAW_CODE_ABC0092000',
#  'LAW_CODE_ABC0096000',
#  'LAW_CODE_ABC0100000',
#  'LAW_CODE_ABC0102000',
#  'LAW_CODE_ABC0105014',
#  'LAW_CODE_ABC0106000',
#  'LAW_CODE_ABC0106006',
#  'LAW_CODE_ABC0114000',
#  'LAW_CODE_AC-0020453',
#  'LAW_CODE_AC-010125B',
#  'LAW_CODE_AC-0161186',
#  'LAW_CODE_AC-019176B',
#  'LAW_CODE_AC-019190B',
#  'LAW_CODE_AC-019190C',
#  'LAW_CODE_AC-024218A',
#  'LAW_CODE_AC-10177',
#  'LAW_CODE_AC-10203A1',
#  'LAW_CODE_AM-00000MA',
#  'LAW_CODE_AM-00000MU',
#  'LAW_CODE_AM-035102A',
#  'LAW_CODE_AM-0353000',
#  'LAW_CODE_AM-0353A00',
#  'LAW_CODE_AM-0353A01',
#  'LAW_CODE_AM-0353D00',
#  'LAW_CODE_AM-0355000',
#  'LAW_CODE_COR000000F',
#  'LAW_CODE_COR0168D03',
#  'LAW_CODE_COR0168D04',
#  'LAW_CODE_COR0168D1B',
#  'LAW_CODE_COR0168E03',
#  'LAW_CODE_COR0168E04',
#  'LAW_CODE_COR0168E1A',
#  'LAW_CODE_COR0168EB2',
#  'LAW_CODE_COR0168EB3',
#  'LAW_CODE_COR0168FFD',
#  'LAW_CODE_COR0168FFE',
#  'LAW_CODE_COR0168G02',
#  'LAW_CODE_ED-6512000',
#  'LAW_CODE_ED-6512001',
#  'LAW_CODE_ED-6513001',
#  'LAW_CODE_EL-1713000',
#  'LAW_CODE_GB-00000MA',
#  'LAW_CODE_GB-0043000',
#  'LAW_CODE_GB-0089G1A',
#  'LAW_CODE_GCI0000000',
#  'LAW_CODE_GCI00000M0',
#  'LAW_CODE_LOC00000F0',
#  'LAW_CODE_LOC00000FE',
#  'LAW_CODE_LOC00000M0',
#  'LAW_CODE_LOC00000MA',
#  'LAW_CODE_LOC00000MB',
#  'LAW_CODE_LOC00000MU',
#  'LAW_CODE_LOC00000V0',
#  'LAW_CODE_PAR000103C',
#  'LAW_CODE_PHL00000FE',
#  'LAW_CODE_PHL00000MA',
#  'LAW_CODE_PHL3310000',
#  'LAW_CODE_PHL3380000',
#  'LAW_CODE_PHL3380005',
#  'LAW_CODE_PL-1000501',
#  'LAW_CODE_PL-1001000',
#  'LAW_CODE_PL-1051000',
#  'LAW_CODE_PL-1051001',
#  'LAW_CODE_PL-1051300',
#  'LAW_CODE_PL-1051500',
#  'LAW_CODE_PL-1150001',
#  'LAW_CODE_PL-1150002',
#  'LAW_CODE_PL-1150500',
#  'LAW_CODE_PL-1200001',
#  'LAW_CODE_PL-1200002',
#  'LAW_CODE_PL-1200003',
#  'LAW_CODE_PL-120001H',
#  'LAW_CODE_PL-120002H',
#  'LAW_CODE_PL-120003H',
#  'LAW_CODE_PL-1200100',
#  'LAW_CODE_PL-1200201',
#  'LAW_CODE_PL-1200301',
#  'LAW_CODE_PL-12004C5',
#  'LAW_CODE_PL-12004D3',
#  'LAW_CODE_PL-12004D4',
#  'LAW_CODE_PL-1200501',
#  'LAW_CODE_PL-1200502',
#  'LAW_CODE_PL-1200503',
#  'LAW_CODE_PL-1200504',
#  'LAW_CODE_PL-1200505',
#  'LAW_CODE_PL-1200506',
#  'LAW_CODE_PL-1200507',
#  'LAW_CODE_PL-1200508',
#  'LAW_CODE_PL-1200509',
#  'LAW_CODE_PL-1200510',
#  'LAW_CODE_PL-1200511',
#  'LAW_CODE_PL-1200512',
#  'LAW_CODE_PL-1200513',
#  'LAW_CODE_PL-120051H',
#  'LAW_CODE_PL-120051X',
#  'LAW_CODE_PL-120052H',
#  'LAW_CODE_PL-120052X',
#  'LAW_CODE_PL-120053A',
#  'LAW_CODE_PL-120053B',
#  'LAW_CODE_PL-120053C',
#  'LAW_CODE_PL-120053H',
#  'LAW_CODE_PL-120053X',
#  'LAW_CODE_PL-120054A',
#  'LAW_CODE_PL-120054X',
#  'LAW_CODE_PL-120057H',
#  'LAW_CODE_PL-120058H',
#  'LAW_CODE_PL-120059H',
#  'LAW_CODE_PL-12005BA',
#  'LAW_CODE_PL-12005BC',
#  'LAW_CODE_PL-12005EH',
#  'LAW_CODE_PL-12005ET',
#  'LAW_CODE_PL-12005WH',
#  'LAW_CODE_PL-12005WT',
#  'LAW_CODE_PL-12005WX',
#  'LAW_CODE_PL-12005XA',
#  'LAW_CODE_PL-12005XB',
#  'LAW_CODE_PL-1200600',
#  'LAW_CODE_PL-120060T',
#  'LAW_CODE_PL-1200700',
#  'LAW_CODE_PL-1200800',
#  'LAW_CODE_PL-120080T',
#  'LAW_CODE_PL-1201001',
#  'LAW_CODE_PL-1201002',
#  'LAW_CODE_PL-1201003',
#  'LAW_CODE_PL-1201004',
#  'LAW_CODE_PL-120104X',
#  'LAW_CODE_PL-1201100',
#  'LAW_CODE_PL-120110T',
#  'LAW_CODE_PL-1201200',
#  'LAW_CODE_PL-1201300',
#  'LAW_CODE_PL-120130H',
#  'LAW_CODE_PL-1201401',
#  'LAW_CODE_PL-1201402',
#  'LAW_CODE_PL-1201403',
#  'LAW_CODE_PL-120141H',
#  'LAW_CODE_PL-1201500',
#  'LAW_CODE_PL-120150H',
#  'LAW_CODE_PL-1201800',
#  'LAW_CODE_PL-120180T',
#  'LAW_CODE_PL-1202000',
#  'LAW_CODE_PL-120200H',
#  'LAW_CODE_PL-1202500',
#  'LAW_CODE_PL-120250H',
#  'LAW_CODE_PL-1204501',
#  'LAW_CODE_PL-1204502',
#  'LAW_CODE_PL-1204503',
#  'LAW_CODE_PL-120451H',
#  'LAW_CODE_PL-1205001',
#  'LAW_CODE_PL-1205002',
#  'LAW_CODE_PL-1205003',
#  'LAW_CODE_PL-1205004',
#  'LAW_CODE_PL-120501H',
#  'LAW_CODE_PL-120503H',
#  'LAW_CODE_PL-1205501',
#  'LAW_CODE_PL-1205502',
#  'LAW_CODE_PL-1205504',
#  'LAW_CODE_PL-1205505',
#  'LAW_CODE_PL-1206001',
#  'LAW_CODE_PL-120601H',
#  'LAW_CODE_PL-12070C1',
#  'LAW_CODE_PL-12070E1',
#  'LAW_CODE_PL-120D42B',
#  'LAW_CODE_PL-1211100',
#  'LAW_CODE_PL-121110A',
#  'LAW_CODE_PL-121110B',
#  'LAW_CODE_PL-12111AH',
#  'LAW_CODE_PL-1211200',
#  'LAW_CODE_PL-121120H',
#  'LAW_CODE_PL-121120T',
#  'LAW_CODE_PL-121120X',
#  'LAW_CODE_PL-1211300',
#  'LAW_CODE_PL-121130H',
#  'LAW_CODE_PL-121130X',
#  'LAW_CODE_PL-1251000',
#  'LAW_CODE_PL-1251201',
#  'LAW_CODE_PL-1251501',
#  'LAW_CODE_PL-1252001',
#  'LAW_CODE_PL-125201H',
#  'LAW_CODE_PL-1252501',
#  'LAW_CODE_PL-1252502',
#  'LAW_CODE_PL-1252503',
#  'LAW_CODE_PL-1252504',
#  'LAW_CODE_PL-125251H',
#  'LAW_CODE_PL-125251T',
#  'LAW_CODE_PL-125253H',
#  'LAW_CODE_PL-125255X',
#  'LAW_CODE_PL-12526A1',
#  'LAW_CODE_PL-12526A2',
#  'LAW_CODE_PL-125271A',
#  'LAW_CODE_PL-125271B',
#  'LAW_CODE_PL-125271F',
#  'LAW_CODE_PL-125271G',
#  'LAW_CODE_PL-125271H',
#  'LAW_CODE_PL-125271J',
#  'LAW_CODE_PL-12527AT',
#  'LAW_CODE_PL-12527ET',
#  'LAW_CODE_PL-12527IT',
#  'LAW_CODE_PL-1302001',
#  'LAW_CODE_PL-1302501',
#  'LAW_CODE_PL-1302502',
#  'LAW_CODE_PL-1302503',
#  'LAW_CODE_PL-1302504',
#  'LAW_CODE_PL-1302507',
#  'LAW_CODE_PL-1302508',
#  'LAW_CODE_PL-1302509',
#  'LAW_CODE_PL-1303001',
#  'LAW_CODE_PL-1303002',
#  'LAW_CODE_PL-130301T',
#  'LAW_CODE_PL-1303501',
#  'LAW_CODE_PL-1303502',
#  'LAW_CODE_PL-1303503',
#  'LAW_CODE_PL-1303504',
#  'LAW_CODE_PL-130351A',
#  'LAW_CODE_PL-130351B',
#  'LAW_CODE_PL-130351C',
#  'LAW_CODE_PL-130351H',
#  'LAW_CODE_PL-130352A',
#  'LAW_CODE_PL-130352B',
#  'LAW_CODE_PL-130352D',
#  'LAW_CODE_PL-130353C',
#  'LAW_CODE_PL-1304001',
#  'LAW_CODE_PL-1304002',
#  'LAW_CODE_PL-1304003',
#  'LAW_CODE_PL-1304501',
#  'LAW_CODE_PL-1304502',
#  'LAW_CODE_PL-130451T',
#  'LAW_CODE_PL-1305001',
#  'LAW_CODE_PL-1305002',
#  'LAW_CODE_PL-1305003',
#  'LAW_CODE_PL-1305004',
#  'LAW_CODE_PL-130504T',
#  'LAW_CODE_PL-1305201',
#  'LAW_CODE_PL-1305202',
#  'LAW_CODE_PL-130520H',
#  'LAW_CODE_PL-130521H',
#  'LAW_CODE_PL-13052A1',
#  'LAW_CODE_PL-1305300',
#  'LAW_CODE_PL-130530T',
#  'LAW_CODE_PL-1305500',
#  'LAW_CODE_PL-130550H',
#  'LAW_CODE_PL-1306001',
#  'LAW_CODE_PL-1306002',
#  'LAW_CODE_PL-1306501',
#  'LAW_CODE_PL-1306502',
#  'LAW_CODE_PL-1306503',
#  'LAW_CODE_PL-1306504',
#  'LAW_CODE_PL-130651B',
#  'LAW_CODE_PL-130651H',
#  'LAW_CODE_PL-1306601',
#  'LAW_CODE_PL-130661B',
#  'LAW_CODE_PL-130661C',
#  'LAW_CODE_PL-1306701',
#  'LAW_CODE_PL-130671B',
#  'LAW_CODE_PL-130751A',
#  'LAW_CODE_PL-130751B',
#  'LAW_CODE_PL-130801A',
#  'LAW_CODE_PL-130801B',
#  'LAW_CODE_PL-130851A',
#  'LAW_CODE_PL-130951B',
#  'LAW_CODE_PL-13095BT',
#  'LAW_CODE_PL-1309600',
#  'LAW_CODE_PL-1350500',
#  'LAW_CODE_PL-135050H',
#  'LAW_CODE_PL-1351000',
#  'LAW_CODE_PL-1352000',
#  'LAW_CODE_PL-135200H',
#  'LAW_CODE_PL-135200X',
#  'LAW_CODE_PL-1352501',
#  'LAW_CODE_PL-135252A',
#  'LAW_CODE_PL-135252B',
#  'LAW_CODE_PL-135252C',
#  'LAW_CODE_PL-1354501',
#  'LAW_CODE_PL-1354502',
#  'LAW_CODE_PL-1355001',
#  'LAW_CODE_PL-1355002',
#  'LAW_CODE_PL-1356039',
#  'LAW_CODE_PL-1356502',
#  'LAW_CODE_PL-1400500',
#  'LAW_CODE_PL-140100A',
#  'LAW_CODE_PL-140100B',
#  'LAW_CODE_PL-140100C',
#  'LAW_CODE_PL-140100D',
#  'LAW_CODE_PL-140100E',
#  'LAW_CODE_PL-140100F',
#  'LAW_CODE_PL-140100G',
#  'LAW_CODE_PL-14010EH',
#  'LAW_CODE_PL-14010GH',
#  'LAW_CODE_PL-1401501',
#  'LAW_CODE_PL-1401502',
#  'LAW_CODE_PL-1401701',
#  'LAW_CODE_PL-1401702',
#  'LAW_CODE_PL-1402000',
#  'LAW_CODE_PL-140200H',
#  'LAW_CODE_PL-140200X',
#  'LAW_CODE_PL-1402501',
#  'LAW_CODE_PL-1402502',
#  'LAW_CODE_PL-140251A',
#  'LAW_CODE_PL-140251B',
#  'LAW_CODE_PL-140251C',
#  'LAW_CODE_PL-140251D',
#  'LAW_CODE_PL-140251X',
#  'LAW_CODE_PL-140252X',
#  'LAW_CODE_PL-14025BX',
#  'LAW_CODE_PL-1403001',
#  'LAW_CODE_PL-1403002',
#  'LAW_CODE_PL-1403003',
#  'LAW_CODE_PL-1403004',
#  'LAW_CODE_PL-140301H',
#  'LAW_CODE_PL-1403500',
#  'LAW_CODE_PL-1404000',
#  'LAW_CODE_PL-1450001',
#  'LAW_CODE_PL-1450002',
#  'LAW_CODE_PL-1450003',
#  'LAW_CODE_PL-1450004',
#  'LAW_CODE_PL-145001H',
#  'LAW_CODE_PL-145002H',
#  'LAW_CODE_PL-145003H',
#  'LAW_CODE_PL-145004A',
#  'LAW_CODE_PL-145004B',
#  'LAW_CODE_PL-145004H',
#  'LAW_CODE_PL-14500AH',
#  'LAW_CODE_PL-14500BH',
#  'LAW_CODE_PL-1450501',
#  'LAW_CODE_PL-1450502',
#  'LAW_CODE_PL-145051H',
#  'LAW_CODE_PL-145052H',
#  'LAW_CODE_PL-1451000',
#  'LAW_CODE_PL-145100H',
#  'LAW_CODE_PL-1451200',
#  'LAW_CODE_PL-1451400',
#  'LAW_CODE_PL-1451500',
#  'LAW_CODE_PL-1452000',
#  'LAW_CODE_PL-145200T',
#  'LAW_CODE_PL-1452200',
#  'LAW_CODE_PL-1452300',
#  'LAW_CODE_PL-145230A',
#  'LAW_CODE_PL-145230C',
#  'LAW_CODE_PL-1452500',
#  'LAW_CODE_PL-1454000',
#  'LAW_CODE_PL-1454500',
#  'LAW_CODE_PL-1455001',
#  'LAW_CODE_PL-1456002',
#  'LAW_CODE_PL-1456500',
#  'LAW_CODE_PL-1500100',
#  'LAW_CODE_PL-1500501',
#  'LAW_CODE_PL-1501001',
#  'LAW_CODE_PL-1501500',
#  'LAW_CODE_PL-150150H',
#  'LAW_CODE_PL-1502001',
#  'LAW_CODE_PL-1552500',
#  'LAW_CODE_PL-155250H',
#  'LAW_CODE_PL-1553001',
#  'LAW_CODE_PL-1553002',
#  'LAW_CODE_PL-1553003',
#  'LAW_CODE_PL-1553004',
#  'LAW_CODE_PL-1553005',
#  'LAW_CODE_PL-1553006',
#  'LAW_CODE_PL-1553007',
#  'LAW_CODE_PL-1553008',
#  'LAW_CODE_PL-1553009',
#  'LAW_CODE_PL-1553010',
#  'LAW_CODE_PL-1553012',
#  'LAW_CODE_PL-155301H',
#  'LAW_CODE_PL-155302H',
#  'LAW_CODE_PL-155303H',
#  'LAW_CODE_PL-155304H',
#  'LAW_CODE_PL-155305H',
#  'LAW_CODE_PL-155307H',
#  'LAW_CODE_PL-155308H',
#  'LAW_CODE_PL-155309H',
#  'LAW_CODE_PL-1553501',
#  'LAW_CODE_PL-1553502',
#  'LAW_CODE_PL-155351H',
#  'LAW_CODE_PL-1554001',
#  'LAW_CODE_PL-1554002',
#  'LAW_CODE_PL-155402C',
#  'LAW_CODE_PL-1554200',
#  'LAW_CODE_PL-1554201',
#  'LAW_CODE_PL-1554300',
#  'LAW_CODE_PL-1560500',
#  'LAW_CODE_PL-1561002',
#  'LAW_CODE_PL-158350I',
#  'LAW_CODE_PL-1584500',
#  'LAW_CODE_PL-1600500',
#  'LAW_CODE_PL-160050H',
#  'LAW_CODE_PL-160050X',
#  'LAW_CODE_PL-1601001',
#  'LAW_CODE_PL-1601002',
#  'LAW_CODE_PL-1601003',
#  'LAW_CODE_PL-160101H',
#  'LAW_CODE_PL-160101X',
#  'LAW_CODE_PL-160102A',
#  'LAW_CODE_PL-160102B',
#  'LAW_CODE_PL-16010AH',
#  'LAW_CODE_PL-16010AX',
#  'LAW_CODE_PL-16010BH',
#  'LAW_CODE_PL-1601501',
#  'LAW_CODE_PL-1601502',
#  'LAW_CODE_PL-1601503',
#  'LAW_CODE_PL-1601504',
#  'LAW_CODE_PL-160151H',
#  'LAW_CODE_PL-160151X',
#  'LAW_CODE_PL-160152H',
#  'LAW_CODE_PL-160152X',
#  'LAW_CODE_PL-160153H',
#  'LAW_CODE_PL-160153T',
#  'LAW_CODE_PL-160153X',
#  'LAW_CODE_PL-160154X',
#  'LAW_CODE_PL-1650001',
#  'LAW_CODE_PL-165001B',
#  'LAW_CODE_PL-1650501',
#  'LAW_CODE_PL-1650502',
#  'LAW_CODE_PL-1650503',
#  'LAW_CODE_PL-1650600',
#  'LAW_CODE_PL-1650800',
#  'LAW_CODE_PL-1650901',
#  'LAW_CODE_PL-1651001',
#  'LAW_CODE_PL-1651002',
#  'LAW_CODE_PL-1651100',
#  'LAW_CODE_PL-1651501',
#  'LAW_CODE_PL-1651502',
#  'LAW_CODE_PL-1651503',
#  'LAW_CODE_PL-1651504',
#  'LAW_CODE_PL-1651506',
#  'LAW_CODE_PL-1651507',
#  'LAW_CODE_PL-1651509',
#  'LAW_CODE_PL-1651510',
#  'LAW_CODE_PL-1651512',
#  'LAW_CODE_PL-165154A',
#  'LAW_CODE_PL-165154D',
#  'LAW_CODE_PL-1651601',
#  'LAW_CODE_PL-1651700',
#  'LAW_CODE_PL-1652501',
#  'LAW_CODE_PL-1652502',
#  'LAW_CODE_PL-1653001',
#  'LAW_CODE_PL-1653002',
#  'LAW_CODE_PL-1653500',
#  'LAW_CODE_PL-1654000',
#  'LAW_CODE_PL-1654501',
#  'LAW_CODE_PL-1654502',
#  'LAW_CODE_PL-1654503',
#  'LAW_CODE_PL-1654504',
#  'LAW_CODE_PL-1654505',
#  'LAW_CODE_PL-1655000',
#  'LAW_CODE_PL-1655200',
#  'LAW_CODE_PL-1655400',
#  'LAW_CODE_PL-1657100',
#  'LAW_CODE_PL-1657200',
#  'LAW_CODE_PL-1657300',
#  'LAW_CODE_PL-1700500',
#  'LAW_CODE_PL-1701001',
#  'LAW_CODE_PL-1701002',
#  'LAW_CODE_PL-1701003',
#  'LAW_CODE_PL-1701004',
#  'LAW_CODE_PL-1701005',
#  'LAW_CODE_PL-1701501',
#  'LAW_CODE_PL-1701502',
#  'LAW_CODE_PL-1702000',
#  'LAW_CODE_PL-1702500',
#  'LAW_CODE_PL-1703000',
#  'LAW_CODE_PL-1704001',
#  'LAW_CODE_PL-1704002',
#  'LAW_CODE_PL-1706501',
#  'LAW_CODE_PL-1706502',
#  'LAW_CODE_PL-1706503',
#  'LAW_CODE_PL-1707001',
#  'LAW_CODE_PL-1707002',
#  'LAW_CODE_PL-1707003',
#  'LAW_CODE_PL-170703A',
#  'LAW_CODE_PL-170703B',
#  'LAW_CODE_PL-1750501',
#  'LAW_CODE_PL-1750503',
#  'LAW_CODE_PL-1751000',
#  'LAW_CODE_PL-1752500',
#  'LAW_CODE_PL-1753000',
#  'LAW_CODE_PL-1753501',
#  'LAW_CODE_PL-1753502',
#  'LAW_CODE_PL-1761500',
#  'LAW_CODE_PL-1762000',
#  'LAW_CODE_PL-1781000',
#  'LAW_CODE_PL-1781501',
#  'LAW_CODE_PL-1781502',
#  'LAW_CODE_PL-1782000',
#  'LAW_CODE_PL-1782500',
#  'LAW_CODE_PL-1872000',
#  'LAW_CODE_PL-1900502',
#  'LAW_CODE_PL-1902000',
#  'LAW_CODE_PL-1902300',
#  'LAW_CODE_PL-1902501',
#  'LAW_CODE_PL-1902502',
#  'LAW_CODE_PL-1902503',
#  'LAW_CODE_PL-1902504',
#  'LAW_CODE_PL-1902601',
#  'LAW_CODE_PL-1902602',
#  'LAW_CODE_PL-1904200',
#  'LAW_CODE_PL-1906501',
#  'LAW_CODE_PL-190651A',
#  'LAW_CODE_PL-190651B',
#  'LAW_CODE_PL-1907801',
#  'LAW_CODE_PL-1907802',
#  'LAW_CODE_PL-1907901',
#  'LAW_CODE_PL-1907902',
#  'LAW_CODE_PL-1907903',
#  'LAW_CODE_PL-1907904',
#  'LAW_CODE_PL-1908001',
#  'LAW_CODE_PL-1908002',
#  'LAW_CODE_PL-1908003',
#  'LAW_CODE_PL-1908004',
#  'LAW_CODE_PL-1908100',
#  'LAW_CODE_PL-1908200',
#  'LAW_CODE_PL-1908301',
#  'LAW_CODE_PL-1908302',
#  'LAW_CODE_PL-1908303',
#  'LAW_CODE_PL-1908500',
#  'LAW_CODE_PL-1908600',
#  'LAW_CODE_PL-1908F02',
#  'LAW_CODE_PL-1950001',
#  'LAW_CODE_PL-1950002',
#  'LAW_CODE_PL-1950500',
#  'LAW_CODE_PL-1950501',
#  'LAW_CODE_PL-1950502',
#  'LAW_CODE_PL-1950700',
#  'LAW_CODE_PL-1950800',
#  'LAW_CODE_PL-1951000',
#  'LAW_CODE_PL-1951600',
#  'LAW_CODE_PL-2000000',
#  'LAW_CODE_PL-2001000',
#  'LAW_CODE_PL-2003000',
#  'LAW_CODE_PL-2050500',
#  'LAW_CODE_PL-2051001',
#  'LAW_CODE_PL-2051002',
#  'LAW_CODE_PL-2051003',
#  'LAW_CODE_PL-2051502',
#  'LAW_CODE_PL-2051503',
#  'LAW_CODE_PL-2051700',
#  'LAW_CODE_PL-2052001',
#  'LAW_CODE_PL-2052002',
#  'LAW_CODE_PL-2052501',
#  'LAW_CODE_PL-2052502',
#  'LAW_CODE_PL-2053000',
#  'LAW_CODE_PL-2056000',
#  'LAW_CODE_PL-2056500',
#  'LAW_CODE_PL-2103500',
#  'LAW_CODE_PL-2104500',
#  'LAW_CODE_PL-2150000',
#  'LAW_CODE_PL-2151000',
#  'LAW_CODE_PL-2151101',
#  'LAW_CODE_PL-2151501',
#  'LAW_CODE_PL-2151502',
#  'LAW_CODE_PL-2154001',
#  'LAW_CODE_PL-2154002',
#  'LAW_CODE_PL-215401A',
#  'LAW_CODE_PL-215401B',
#  'LAW_CODE_PL-2155001',
#  'LAW_CODE_PL-2155002',
#  'LAW_CODE_PL-2155003',
#  'LAW_CODE_PL-2155004',
#  'LAW_CODE_PL-2155006',
#  'LAW_CODE_PL-2155007',
#  'LAW_CODE_PL-215510A',
#  'LAW_CODE_PL-215510B',
#  'LAW_CODE_PL-215510C',
#  'LAW_CODE_PL-215510D',
#  'LAW_CODE_PL-21551B1',
#  'LAW_CODE_PL-21551B2',
#  'LAW_CODE_PL-21551B3',
#  'LAW_CODE_PL-21551B4',
#  'LAW_CODE_PL-21551B5',
#  'LAW_CODE_PL-21551B6',
#  'LAW_CODE_PL-2155201',
#  'LAW_CODE_PL-2155202',
#  'LAW_CODE_PL-2155203',
#  'LAW_CODE_PL-2155500',
#  'LAW_CODE_PL-2155600',
#  'LAW_CODE_PL-2155700',
#  'LAW_CODE_PL-2155800',
#  'LAW_CODE_PL-2156500',
#  'LAW_CODE_PL-2156600',
#  'LAW_CODE_PL-2200300',
#  'LAW_CODE_PL-2200601',
#  'LAW_CODE_PL-2200602',
#  'LAW_CODE_PL-2200603',
#  'LAW_CODE_PL-2200604',
#  'LAW_CODE_PL-2200605',
#  'LAW_CODE_PL-2200606',
#  'LAW_CODE_PL-2200607',
#  'LAW_CODE_PL-2200901',
#  'LAW_CODE_PL-2200902',
#  'LAW_CODE_PL-2200903',
#  'LAW_CODE_PL-2200904',
#  'LAW_CODE_PL-2200906',
#  'LAW_CODE_PL-2200907',
#  'LAW_CODE_PL-2200908',
#  'LAW_CODE_PL-2200910',
#  'LAW_CODE_PL-2200911',
#  'LAW_CODE_PL-2200913',
#  'LAW_CODE_PL-2200914',
#  'LAW_CODE_PL-2201601',
#  'LAW_CODE_PL-2201602',
#  'LAW_CODE_PL-2201603',
#  'LAW_CODE_PL-2201604',
#  'LAW_CODE_PL-2201605',
#  'LAW_CODE_PL-2201606',
#  'LAW_CODE_PL-2201607',
#  'LAW_CODE_PL-2201608',
#  'LAW_CODE_PL-2201610',
#  'LAW_CODE_PL-2201611',
#  'LAW_CODE_PL-2201612',
#  'LAW_CODE_PL-2201613',
#  'LAW_CODE_PL-2201801',
#  'LAW_CODE_PL-2201802',
#  'LAW_CODE_PL-2201803',
#  'LAW_CODE_PL-2201804',
#  'LAW_CODE_PL-2201805',
#  'LAW_CODE_PL-2201806',
#  'LAW_CODE_PL-2202101',
#  'LAW_CODE_PL-2203100',
#  'LAW_CODE_PL-2203403',
#  'LAW_CODE_PL-2203407',
#  'LAW_CODE_PL-2203409',
#  'LAW_CODE_PL-2203901',
#  'LAW_CODE_PL-2203902',
#  'LAW_CODE_PL-2203903',
#  'LAW_CODE_PL-2203904',
#  'LAW_CODE_PL-2203906',
#  'LAW_CODE_PL-2203907',
#  'LAW_CODE_PL-2203909',
#  'LAW_CODE_PL-2204101',
#  'LAW_CODE_PL-2204102',
#  'LAW_CODE_PL-2204103',
#  'LAW_CODE_PL-2204105',
#  'LAW_CODE_PL-2204106',
#  'LAW_CODE_PL-2204301',
#  'LAW_CODE_PL-2204401',
#  'LAW_CODE_PL-2204402',
#  'LAW_CODE_PL-2204403',
#  'LAW_CODE_PL-2204600',
#  'LAW_CODE_PL-2205001',
#  'LAW_CODE_PL-2205002',
#  'LAW_CODE_PL-2205003',
#  'LAW_CODE_PL-2205500',
#  'LAW_CODE_PL-2206000',
#  'LAW_CODE_PL-2206501',
#  'LAW_CODE_PL-2207200',
#  'LAW_CODE_PL-2207701',
#  'LAW_CODE_PL-2222500',
#  'LAW_CODE_PL-2223001',
#  'LAW_CODE_PL-2223002',
#  'LAW_CODE_PL-2223501',
#  'LAW_CODE_PL-2223502',
#  'LAW_CODE_PL-2224001',
#  'LAW_CODE_PL-2224002',
#  'LAW_CODE_PL-2224500',
#  'LAW_CODE_PL-2225001',
#  'LAW_CODE_PL-2225002',
#  'LAW_CODE_PL-2225501',
#  'LAW_CODE_PL-2225502',
#  'LAW_CODE_PL-2226000',
#  'LAW_CODE_PL-2226500',
#  'LAW_CODE_PL-2250500',
#  'LAW_CODE_PL-2251001',
#  'LAW_CODE_PL-2251002',
#  'LAW_CODE_PL-225102B',
#  'LAW_CODE_PL-2251502',
#  'LAW_CODE_PL-2252001',
#  'LAW_CODE_PL-2253001',
#  'LAW_CODE_PL-2253002',
#  'LAW_CODE_PL-2253003',
#  'LAW_CODE_PL-2256500',
#  'LAW_CODE_PL-2257501',
#  'LAW_CODE_PL-2258001',
#  'LAW_CODE_PL-2300000',
#  'LAW_CODE_PL-2300400',
#  'LAW_CODE_PL-2300500',
#  'LAW_CODE_PL-2302001',
#  'LAW_CODE_PL-2302501',
#  'LAW_CODE_PL-2302502',
#  'LAW_CODE_PL-2303001',
#  'LAW_CODE_PL-2303401',
#  'LAW_CODE_PL-2303405',
#  'LAW_CODE_PL-230341A',
#  'LAW_CODE_PL-230345A',
#  'LAW_CODE_PL-2304000',
#  'LAW_CODE_PL-2350502',
#  'LAW_CODE_PL-2352103',
#  'LAW_CODE_PL-2400500',
#  'LAW_CODE_PL-2400602',
#  'LAW_CODE_PL-2400800',
#  'LAW_CODE_PL-2401000',
#  'LAW_CODE_PL-2402001',
#  'LAW_CODE_PL-2402002',
#  'LAW_CODE_PL-2402003',
#  'LAW_CODE_PL-2402004',
#  'LAW_CODE_PL-2402005',
#  'LAW_CODE_PL-2402006',
#  'LAW_CODE_PL-2402007',
#  'LAW_CODE_PL-2402100',
#  'LAW_CODE_PL-2402500',
#  'LAW_CODE_PL-240250H',
#  'LAW_CODE_PL-2402601',
#  'LAW_CODE_PL-2402602',
#  'LAW_CODE_PL-2402603',
#  'LAW_CODE_PL-2403001',
#  'LAW_CODE_PL-2403002',
#  'LAW_CODE_PL-2403003',
#  'LAW_CODE_PL-2403004',
#  'LAW_CODE_PL-2403005',
#  'LAW_CODE_PL-240301A',
#  'LAW_CODE_PL-240301B',
#  'LAW_CODE_PL-240301H',
#  'LAW_CODE_PL-240302H',
#  'LAW_CODE_PL-24030AH',
#  'LAW_CODE_PL-24030BH',
#  'LAW_CODE_PL-24030M1',
#  'LAW_CODE_PL-2403102',
#  'LAW_CODE_PL-2403103',
#  'LAW_CODE_PL-2403200',
#  'LAW_CODE_PL-2403502',
#  'LAW_CODE_PL-2403506',
#  'LAW_CODE_PL-2404502',
#  'LAW_CODE_PL-2404600',
#  'LAW_CODE_PL-2405001',
#  'LAW_CODE_PL-2405002',
#  'LAW_CODE_PL-2405003',
#  'LAW_CODE_PL-2405004',
#  'LAW_CODE_PL-240503A',
#  'LAW_CODE_PL-240504B',
#  'LAW_CODE_PL-2405501',
#  'LAW_CODE_PL-2405502',
#  'LAW_CODE_PL-2406001',
#  'LAW_CODE_PL-2406006',
#  'LAW_CODE_PL-2406200',
#  'LAW_CODE_PL-2407501',
#  'LAW_CODE_PL-2407700',
#  'LAW_CODE_PL-2410201',
#  'LAW_CODE_PL-2410202',
#  'LAW_CODE_PL-24500B2',
#  'LAW_CODE_PL-24500BI',
#  'LAW_CODE_PL-2450100',
#  'LAW_CODE_PL-2450301',
#  'LAW_CODE_PL-2450302',
#  'LAW_CODE_PL-2451100',
#  'LAW_CODE_PL-2451500',
#  'LAW_CODE_PL-2502501',
#  'LAW_CODE_PL-2504501',
#  'LAW_CODE_PL-2504502',
#  'LAW_CODE_PL-2504504',
#  'LAW_CODE_PL-2504505',
#  'LAW_CODE_PL-250453A',
#  'LAW_CODE_PL-2505000',
#  'LAW_CODE_PL-2505500',
#  'LAW_CODE_PL-2506001',
#  'LAW_CODE_PL-2506002',
#  'LAW_CODE_PL-2507101',
#  'LAW_CODE_PL-2507102',
#  'LAW_CODE_PL-2600001',
#  'LAW_CODE_PL-2600501',
#  'LAW_CODE_PL-2600502',
#  'LAW_CODE_PL-260061A',
#  'LAW_CODE_PL-2601001',
#  'LAW_CODE_PL-2601002',
#  'LAW_CODE_PL-2602001',
#  'LAW_CODE_PL-2602002',
#  'LAW_CODE_PL-2602400',
#  'LAW_CODE_PL-26025F0',
#  'LAW_CODE_PL-2603201',
#  'LAW_CODE_PL-2603202',
#  'LAW_CODE_PL-2603203',
#  'LAW_CODE_PL-2603204',
#  'LAW_CODE_PL-2630500',
#  'LAW_CODE_PL-2631000',
#  'LAW_CODE_PL-2631100',
#  'LAW_CODE_PL-2631500',
#  'LAW_CODE_PL-2631600',
#  'LAW_CODE_PL-2650022',
#  'LAW_CODE_PL-2650101',
#  'LAW_CODE_PL-2650102',
#  'LAW_CODE_PL-2650104',
#  'LAW_CODE_PL-2650105',
#  'LAW_CODE_PL-2650106',
#  'LAW_CODE_PL-2650107',
#  'LAW_CODE_PL-2650108',
#  'LAW_CODE_PL-265019I',
#  'LAW_CODE_PL-2650201',
#  'LAW_CODE_PL-2650202',
#  'LAW_CODE_PL-2650203',
#  'LAW_CODE_PL-2650206',
#  'LAW_CODE_PL-2650207',
#  'LAW_CODE_PL-2650208',
#  'LAW_CODE_PL-2650210',
#  'LAW_CODE_PL-265025A',
#  'LAW_CODE_PL-265025B',
#  'LAW_CODE_PL-26502BT',
#  'LAW_CODE_PL-2650302',
#  'LAW_CODE_PL-2650303',
#  'LAW_CODE_PL-265031A',
#  'LAW_CODE_PL-265031B',
#  'LAW_CODE_PL-265031C',
#  'LAW_CODE_PL-265032S',
#  'LAW_CODE_PL-265033S',
#  'LAW_CODE_PL-265033T',
#  'LAW_CODE_PL-26503AS',
#  'LAW_CODE_PL-26503AT',
#  'LAW_CODE_PL-26503BS',
#  'LAW_CODE_PL-26503BT',
#  'LAW_CODE_PL-26503CS',
#  'LAW_CODE_PL-26503CT',
#  'LAW_CODE_PL-26503WT',
#  'LAW_CODE_PL-2650401',
#  'LAW_CODE_PL-2650402',
#  'LAW_CODE_PL-2650801',
#  'LAW_CODE_PL-2650802',
#  'LAW_CODE_PL-2650901',
#  'LAW_CODE_PL-265091A',
#  'LAW_CODE_PL-265091B',
#  'LAW_CODE_PL-2651001',
#  'LAW_CODE_PL-2651002',
#  'LAW_CODE_PL-2651003',
#  'LAW_CODE_PL-2651004',
#  'LAW_CODE_PL-26510B0',
#  'LAW_CODE_PL-2651101',
#  'LAW_CODE_PL-2651201',
#  'LAW_CODE_PL-2651301',
#  'LAW_CODE_PL-2651302',
#  'LAW_CODE_PL-2651900',
#  'LAW_CODE_PL-2651A00',
#  'LAW_CODE_PL-2651B01',
#  'LAW_CODE_PL-2651B02',
#  'LAW_CODE_PL-2653702',
#  'LAW_CODE_PL-2700502',
#  'LAW_CODE_PL-2700506',
#  'LAW_CODE_PL-2700MA2',
#  'LAW_CODE_PL-2702001',
#  'LAW_CODE_PL-2702500',
#  'LAW_CODE_PL-2703000',
#  'LAW_CODE_PL-2703500',
#  'LAW_CODE_PL-4000008',
#  'LAW_CODE_PL-4602001',
#  'LAW_CODE_PL-460201A',
#  'LAW_CODE_PL-4701001',
#  'LAW_CODE_PL-4701501',
#  'LAW_CODE_PL-4701502',
#  'LAW_CODE_PL-4701503',
#  'LAW_CODE_PL-4702001',
#  'LAW_CODE_PL-4702002',
#  'LAW_CODE_PL-4901000',
#  'LAW_CODE_PL-4902001',
#  'LAW_CODE_PL-490201T',
#  'LAW_CODE_PRL0000000',
#  'LAW_CODE_PRL00000MA',
#  'LAW_CODE_RP-00000MU',
#  'LAW_CODE_RPA0076801',
#  'LAW_CODE_RR-00000FD',
#  'LAW_CODE_RR-00000MA',
#  'LAW_CODE_RR-00000V0',
#  'LAW_CODE_RR-0053E00',
#  'LAW_CODE_TAX00000MA',
#  'LAW_CODE_TAX04840A1',
#  'LAW_CODE_TAX181400A',
#  'LAW_CODE_TAX181400B',
#  'LAW_CODE_TAX181400G',
#  'LAW_CODE_TAX18140B3',
#  'LAW_CODE_TAX1814AI2',
#  'LAW_CODE_TAX1814C12',
#  'LAW_CODE_TAX1817000',
#  'LAW_CODE_TAX181700A',
#  'LAW_CODE_TAX181700D',
#  'LAW_CODE_TL-00000MA',
#  'LAW_CODE_TWN0000000',
#  'LAW_CODE_VTL030600E',
#  'LAW_CODE_VTL0319002',
#  'LAW_CODE_VTL034000A',
#  'LAW_CODE_VTL0355000',
#  'LAW_CODE_VTL0375007',
#  'LAW_CODE_VTL037501A',
#  'LAW_CODE_VTL03750MU',
#  'LAW_CODE_VTL0377001',
#  'LAW_CODE_VTL0392000',
#  'LAW_CODE_VTL0392002',
#  'LAW_CODE_VTL0392005',
#  'LAW_CODE_VTL0392AFE',
#  'LAW_CODE_VTL0392AMU',
#  'LAW_CODE_VTL0401B00',
#  'LAW_CODE_VTL040300M',
#  'LAW_CODE_VTL0415A01',
#  'LAW_CODE_VTL0415A5A',
#  'LAW_CODE_VTL0426000',
#  'LAW_CODE_VTL0510007',
#  'LAW_CODE_VTL0511001',
#  'LAW_CODE_VTL0511002',
#  'LAW_CODE_VTL0511003',
#  'LAW_CODE_VTL051101A',
#  'LAW_CODE_VTL05110A1',
#  'LAW_CODE_VTL05110A2',
#  'LAW_CODE_VTL05110A3',
#  'LAW_CODE_VTL05110A4',
#  'LAW_CODE_VTL05110AA',
#  'LAW_CODE_VTL05110E1',
#  'LAW_CODE_VTL05110E2',
#  'LAW_CODE_VTL05110E3',
#  'LAW_CODE_VTL05110E4',
#  'LAW_CODE_VTL05110E5',
#  'LAW_CODE_VTL05110EA',
#  'LAW_CODE_VTL05110FE',
#  'LAW_CODE_VTL05110MU',
#  'LAW_CODE_VTL0511A03',
#  'LAW_CODE_VTL0511A3A',
#  'LAW_CODE_VTL0511AFE',
#  'LAW_CODE_VTL0511AMU',
#  'LAW_CODE_VTL0511D01',
#  'LAW_CODE_VTL0512000',
#  'LAW_CODE_VTL06000AA',
#  'LAW_CODE_VTL06000EF',
#  'LAW_CODE_VTL06002AA',
#  'LAW_CODE_VTL06002AB',
#  'LAW_CODE_VTL06002AD',
#  'LAW_CODE_VTL06002AE',
#  'LAW_CODE_VTL1192000',
#  'LAW_CODE_VTL119201B',
#  'LAW_CODE_VTL119202C',
#  'LAW_CODE_VTL119202U',
#  'LAW_CODE_VTL119202V',
#  'LAW_CODE_VTL119202X',
#  'LAW_CODE_VTL119202Y',
#  'LAW_CODE_VTL119202Z',
#  'LAW_CODE_VTL119203C',
#  'LAW_CODE_VTL119203V',
#  'LAW_CODE_VTL11920AV',
#  'LAW_CODE_VTL11920D2',
#  'LAW_CODE_VTL11920D3',
#  'LAW_CODE_VTL11920D4',
#  'LAW_CODE_VTL11920E2',
#  'LAW_CODE_VTL11920E3',
#  'LAW_CODE_VTL11920E4',
#  'LAW_CODE_VTL11920U2',
#  'LAW_CODE_VTL11920U3',
#  'LAW_CODE_VTL11920U4',
#  'LAW_CODE_VTL1192D3C',
#  'LAW_CODE_VTL1192E1C',
#  'LAW_CODE_VTL1192E2S',
#  ...]

# %%
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.compose import make_column_transformer

categoricalProcessor = OneHotEncoder(
    handle_unknown="infrequent_if_exist"
)
numericalProcessor = MinMaxScaler()

categoricalPreprocessor = make_column_transformer(
        (categoricalProcessor, cat_selector),
    

)

numericalPreprocessor = make_column_transformer(
        (numericalProcessor, num_selector),
   

)
# See https://scikit-learn.org/stable/auto_examples/ensemble/plot_stack_predictors.html

# %%
# Create a pipeline with preprocessing and model
categoricalModel = Pipeline(steps=[('preprocessor', categoricalPreprocessor),
                        ('classifier', CategoricalNB())])

continuousModel = Pipeline(steps=[('preprocessor', numericalPreprocessor),
                        ('classifier', GaussianNB()
)])

# %%
# Fit the models
categoricalModel.fit(attr_train, target_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='infrequent_if_exist'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000001DF9FE1E0D0>)])),
#                 ('classifier', CategoricalNB())])

# %%
continuousModel.fit(attr_train, target_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000001DF9FE04110>)])),
#                 ('classifier', GaussianNB())])

# %%
target_pred_categorical = categoricalModel.predict_proba(attr_test)

# %%
target_pred_continuous = continuousModel.predict_proba(attr_test)

# %%
target_pred_categorical.size
# Out:
# 75474

# %%
target_pred_continuous.size
# Out:
# 75474

# %%
combined_probs = (target_pred_categorical + target_pred_continuous) / 2

combined_preds = np.argmax(combined_probs, axis=1)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# Evaluate the accuracy

#Compute and print the accuracy score.
accuracy = accuracy_score(target_test, combined_preds)
print(f'Accuracy: {accuracy}')
print()

# Print the confusion matrix
print(confusion_matrix(target_test, combined_preds))
print()

#Print the classification report
print('Classification Report')
print(classification_report(target_test, combined_preds))
# Out:
# Accuracy: 0.9987545379865914
#
# [[16296    34]
#  [   13 21394]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00     16330
#         True       1.00      1.00      1.00     21407
#
#     accuracy                           1.00     37737
#    macro avg       1.00      1.00      1.00     37737
# weighted avg       1.00      1.00      1.00     37737
