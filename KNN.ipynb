# %%
#egression->Future, data transformation

# %%
import numpy as np
import pandas as pd

# %%
_ARREST_KEY = "ARREST_KEY"

_ARREST_BORO = "ARREST_BORO"
_JURISDICTION_CODE = "JURISDICTION_CODE"
_OFFENSE_LEVEL = "LAW_CAT_CD"

_ARREST_DATE = "ARREST_DATE"
_ARREST_MONTH = "ARREST_MONTH" 

_ARREST_PRECINCT = "ARREST_PRECINCT"

_PERPETRATOR_RACE = "PERP_RACE"
_PERPETRATOR_SEX = "PERP_SEX"
_PERPETRATOR_AGE_GROUP="AGE_GROUP"

_INTERNAL_CLASSIFICATION="PD_CD"
_INTERNAL_CLASSIFICATION_DESCRIPTION="PD_DESC"
_THREE_DIGIT_INTERNAL_CLASSIFICATION="KY_CD"

_LAW_CODE="LAW_CODE"

_GEOGRAPHICAL_POSITION = "New Georeferenced Column"

_NYS_X_COORD = "X_COORD_CD"
_NYS_Y_COORD = "Y_COORD_CD"

_LATITUDE='Latitude'
_LONGITUDE='Longitude'

# %%
df = pd.read_csv('./cleaned_data.csv')
df.head()
# Out:
#         OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  ARREST_PRECINCT  \
# 0  FELONY ASSAULT  PL-1211200          F           Q              105
# 1  FELONY ASSAULT  PL-1200502          F           B               48
# 2  FELONY ASSAULT  PL-1200512          F           S              121
# 3  FELONY ASSAULT  PL-1211200          F           Q              100
# 4            RAPE  PL-1302503          F           M               14
#
#    JURISDICTION_CODE   Latitude  Longitude ARREST_MONTH
# 0                  0  40.737043 -73.735514      January
# 1                  0  40.855109 -73.892818        March
# 2                  0  40.628967 -74.163275          May
# 3                  0  40.591980 -73.800066         June
# 4                  0  40.753533 -73.994537      January

# %%
df.shape[1]
# Out:
# 9

# %%
df[_ARREST_PRECINCT] = df[_ARREST_PRECINCT].astype('object')

# %%
df_num= df.select_dtypes(exclude='object')
df_obj= df.select_dtypes(include='object')

df_num.info()
df_obj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188682 entries, 0 to 188681
# Data columns (total 3 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   JURISDICTION_CODE  188682 non-null  int64
#  1   Latitude           188682 non-null  float64
#  2   Longitude          188682 non-null  float64
# dtypes: float64(2), int64(1)
# memory usage: 4.3 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188682 entries, 0 to 188681
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   OFNS_DESC        188682 non-null  object
#  1   LAW_CODE         188682 non-null  object
#  2   LAW_CAT_CD       188682 non-null  object
#  3   ARREST_BORO      188682 non-null  object
#  4   ARREST_PRECINCT  188682 non-null  object
#  5   ARREST_MONTH     188682 non-null  object
# dtypes: object(6)
# memory usage: 8.6+ MB

# %%
df_obj[_OFFENSE_LEVEL].unique()
df_obj
# Out:
#                               OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# 0                        FELONY ASSAULT  PL-1211200          F           Q
# 1                        FELONY ASSAULT  PL-1200502          F           B
# 2                        FELONY ASSAULT  PL-1200512          F           S
# 3                        FELONY ASSAULT  PL-1211200          F           Q
# 4                                  RAPE  PL-1302503          F           M
# ...                                 ...         ...        ...         ...
# 188677                    PETIT LARCENY  PL-1552500          M           Q
# 188678     ASSAULT 3 & RELATED OFFENSES  PL-1200001          M           M
# 188679                         BURGLARY  PL-1402501          F           M
# 188680  OTHER OFFENSES RELATED TO THEFT  PL-1651503          M           B
# 188681                DANGEROUS WEAPONS  PL-265031B          F           B
#
#        ARREST_PRECINCT ARREST_MONTH
# 0                  105      January
# 1                   48        March
# 2                  121          May
# 3                  100         June
# 4                   14      January
# ...                ...          ...
# 188677             109    September
# 188678              34    September
# 188679              23    September
# 188680              44    September
# 188681              46    September
#
# [188682 rows x 6 columns]

# %%
df_obj= pd.get_dummies(df_obj, drop_first=True)
df_obj = df_obj.drop('LAW_CAT_CD_V',axis=1)

# %%
# Drop the target column from the data frame
attr = pd.concat([df_obj,df_num],axis=1)


target = (df_obj['LAW_CAT_CD_M'])

print(attr.shape[1])
attr.head()
# Out:
# 1103
#    OFNS_DESC_ADMINISTRATIVE CODES  OFNS_DESC_ALCOHOLIC BEVERAGE CONTROL LAW  \
# 0                           False                                     False
# 1                           False                                     False
# 2                           False                                     False
# 3                           False                                     False
# 4                           False                                     False
#
#    OFNS_DESC_ANTICIPATORY OFFENSES  OFNS_DESC_ARSON  \
# 0                            False            False
# 1                            False            False
# 2                            False            False
# 3                            False            False
# 4                            False            False
#
#    OFNS_DESC_ASSAULT 3 & RELATED OFFENSES  OFNS_DESC_BURGLAR'S TOOLS  \
# 0                                   False                      False
# 1                                   False                      False
# 2                                   False                      False
# 3                                   False                      False
# 4                                   False                      False
#
#    OFNS_DESC_BURGLARY  OFNS_DESC_CANNABIS RELATED OFFENSES  \
# 0               False                                False
# 1               False                                False
# 2               False                                False
# 3               False                                False
# 4               False                                False
#
#    OFNS_DESC_CHILD ABANDONMENT/NON SUPPORT 1  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#    OFNS_DESC_CRIMINAL MISCHIEF & RELATED OF  ...  ARREST_MONTH_February  \
# 0                                     False  ...                  False
# 1                                     False  ...                  False
# 2                                     False  ...                  False
# 3                                     False  ...                  False
# 4                                     False  ...                  False
#
#    ARREST_MONTH_January  ARREST_MONTH_July  ARREST_MONTH_June  \
# 0                  True              False              False
# 1                 False              False              False
# 2                 False              False              False
# 3                 False              False               True
# 4                  True              False              False
#
#    ARREST_MONTH_March  ARREST_MONTH_May  ARREST_MONTH_September  \
# 0               False             False                   False
# 1                True             False                   False
# 2               False              True                   False
# 3               False             False                   False
# 4               False             False                   False
#
#    JURISDICTION_CODE   Latitude  Longitude
# 0                  0  40.737043 -73.735514
# 1                  0  40.855109 -73.892818
# 2                  0  40.628967 -74.163275
# 3                  0  40.591980 -73.800066
# 4                  0  40.753533 -73.994537
#
# [5 rows x 1103 columns]

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and test
attr_train, attr_test, target_train, target_test = train_test_split(attr, target, test_size=0.20, random_state=5)

# %%
attr_train
# Out:
#         OFNS_DESC_ADMINISTRATIVE CODES  \
# 157705                           False
# 57809                            False
# 25319                            False
# 48111                            False
# 61612                            False
# ...                                ...
# 121974                           False
# 124605                           False
# 20463                            False
# 18638                            False
# 35683                            False
#
#         OFNS_DESC_ALCOHOLIC BEVERAGE CONTROL LAW  \
# 157705                                     False
# 57809                                      False
# 25319                                      False
# 48111                                      False
# 61612                                      False
# ...                                          ...
# 121974                                     False
# 124605                                     False
# 20463                                      False
# 18638                                      False
# 35683                                      False
#
#         OFNS_DESC_ANTICIPATORY OFFENSES  OFNS_DESC_ARSON  \
# 157705                            False            False
# 57809                             False            False
# 25319                             False            False
# 48111                             False            False
# 61612                             False            False
# ...                                 ...              ...
# 121974                            False            False
# 124605                            False            False
# 20463                             False            False
# 18638                             False            False
# 35683                             False            False
#
#         OFNS_DESC_ASSAULT 3 & RELATED OFFENSES  OFNS_DESC_BURGLAR'S TOOLS  \
# 157705                                   False                      False
# 57809                                    False                      False
# 25319                                    False                      False
# 48111                                    False                      False
# 61612                                    False                      False
# ...                                        ...                        ...
# 121974                                    True                      False
# 124605                                   False                      False
# 20463                                    False                      False
# 18638                                    False                      False
# 35683                                     True                      False
#
#         OFNS_DESC_BURGLARY  OFNS_DESC_CANNABIS RELATED OFFENSES  \
# 157705               False                                False
# 57809                False                                False
# 25319                False                                False
# 48111                False                                False
# 61612                False                                False
# ...                    ...                                  ...
# 121974               False                                False
# 124605               False                                False
# 20463                False                                False
# 18638                False                                False
# 35683                False                                False
#
#         OFNS_DESC_CHILD ABANDONMENT/NON SUPPORT 1  \
# 157705                                      False
# 57809                                       False
# 25319                                       False
# 48111                                       False
# 61612                                       False
# ...                                           ...
# 121974                                      False
# 124605                                      False
# 20463                                       False
# 18638                                       False
# 35683                                       False
#
#         OFNS_DESC_CRIMINAL MISCHIEF & RELATED OF  ...  ARREST_MONTH_February  \
# 157705                                     False  ...                  False
# 57809                                      False  ...                   True
# 25319                                      False  ...                   True
# 48111                                      False  ...                   True
# 61612                                      False  ...                  False
# ...                                          ...  ...                    ...
# 121974                                     False  ...                  False
# 124605                                     False  ...                  False
# 20463                                      False  ...                  False
# 18638                                      False  ...                  False
# 35683                                      False  ...                  False
#
#         ARREST_MONTH_January  ARREST_MONTH_July  ARREST_MONTH_June  \
# 157705                 False              False              False
# 57809                  False              False              False
# 25319                  False              False              False
# 48111                  False              False              False
# 61612                  False              False              False
# ...                      ...                ...                ...
# 121974                 False              False               True
# 124605                 False               True              False
# 20463                  False              False              False
# 18638                  False              False              False
# 35683                   True              False              False
#
#         ARREST_MONTH_March  ARREST_MONTH_May  ARREST_MONTH_September  \
# 157705               False             False                   False
# 57809                False             False                   False
# 25319                False             False                   False
# 48111                False             False                   False
# 61612                 True             False                   False
# ...                    ...               ...                     ...
# 121974               False             False                   False
# 124605               False             False                   False
# 20463                False             False                   False
# 18638                 True             False                   False
# 35683                False             False                   False
#
#         JURISDICTION_CODE   Latitude  Longitude
# 157705                  0  40.594054 -73.960866
# 57809                   0  40.701098 -73.903569
# 25319                   0  40.822306 -73.914843
# 48111                   1  40.604783 -73.753998
# 61612                   0  40.871489 -73.904459
# ...                   ...        ...        ...
# 121974                  0  40.548608 -74.159983
# 124605                  0  40.689640 -73.924051
# 20463                   1  40.731707 -74.000956
# 18638                   1  40.866070 -73.894382
# 35683                   0  40.876494 -73.911698
#
# [150945 rows x 1104 columns]

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer


preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown="infrequent_if_exist"), df_obj.columns.tolist()),
        ('num', StandardScaler(), df_num.columns.tolist()),
    ],     remainder='passthrough'
)

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline


model = Pipeline(steps=[
    ('preprocessor',preprocessor),
    ('classifier',KNeighborsClassifier())
])

# %%
model.fit (attr_train,target_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='infrequent_if_exist'),
#                                                   ['OFNS_DESC_ADMINISTRATIVE '
#                                                    'CODES',
#                                                    'OFNS_DESC_ALCOHOLIC '
#                                                    'BEVERAGE CONTROL LAW',
#                                                    'OFNS_DESC_ANTICIPATORY '
#                                                    'OFFENSES',
#                                                    'OFNS_DESC_ARSON',
#                                                    'OFNS_DESC_ASSAULT 3 & '
#                                                    'RELATED OFFENSES',
#                                                    "OFNS_DESC_BURGLAR'S TOOLS",
#                                                    'OFNS_D...
#                                                    'OFNS_DESC_GRAND LARCENY OF '
#                                                    'MOTOR VEHICLE',
#                                                    'OFNS_DESC_HARRASSMENT 2',
#                                                    'OFNS_DESC_HOMICIDE-NEGLIGENT,UNCLASSIFIE',
#                                                    'OFNS_DESC_HOMICIDE-NEGLIGENT-VEHICLE',
#                                                    'OFNS_DESC_INTOXICATED & '
#                                                    'IMPAIRED DRIVING',
#                                                    'OFNS_DESC_INTOXICATED/IMPAIRED '
#                                                    'DRIVING',
#                                                    'OFNS_DESC_JOSTLING', ...]),
#                                                  ('num', StandardScaler(),
#                                                   ['JURISDICTION_CODE',
#                                                    'Latitude',
#                                                    'Longitude'])])),
#                 ('classifier', KNeighborsClassifier())])

# %%
attr.iloc[:, 73]
attr_test.iloc[:, 73].head()

# %%
target_pred = model.predict(attr_test)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# Evaluate the accuracy

#Compute and print the accuracy score.
accuracy = accuracy_score(target_test, target_pred)
print(f'Accuracy: {accuracy}')
print()

# Print the confusion matrix
print(confusion_matrix(target_test, target_pred))
print()

#Print the classification report
print('Classification Report')
print(classification_report(target_test, target_pred))
# Out:
# Accuracy: 0.9981450565757745
#
# [[16267    63]
#  [    7 21400]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00     16330
#         True       1.00      1.00      1.00     21407
#
#     accuracy                           1.00     37737
#    macro avg       1.00      1.00      1.00     37737
# weighted avg       1.00      1.00      1.00     37737
