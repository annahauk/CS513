# %%
#egression->Future, data transformation

# %%
import numpy as np
import pandas as pd

# %%
_ARREST_KEY = "ARREST_KEY"

_ARREST_BORO = "ARREST_BORO"
_JURISDICTION_CODE = "JURISDICTION_CODE"
_OFFENSE_LEVEL = "LAW_CAT_CD"

_ARREST_DATE = "ARREST_DATE"
_ARREST_MONTH = "ARREST_MONTH" 

_ARREST_PRECINCT = "ARREST_PRECINCT"

_PERPETRATOR_RACE = "PERP_RACE"
_PERPETRATOR_SEX = "PERP_SEX"
_PERPETRATOR_AGE_GROUP="AGE_GROUP"

_INTERNAL_CLASSIFICATION="PD_CD"
_INTERNAL_CLASSIFICATION_DESCRIPTION="PD_DESC"
_THREE_DIGIT_INTERNAL_CLASSIFICATION="KY_CD"

_LAW_CODE="LAW_CODE"

_GEOGRAPHICAL_POSITION = "New Georeferenced Column"

_NYS_X_COORD = "X_COORD_CD"
_NYS_Y_COORD = "Y_COORD_CD"

_LATITUDE='Latitude'
_LONGITUDE='Longitude'

# %%
df = pd.read_csv('./cleaned_data.csv')
df.head()
# Out:
#         OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  ARREST_PRECINCT  \
# 0  FELONY ASSAULT  PL-1211200          F           Q              105
# 1  FELONY ASSAULT  PL-1200502          F           B               48
# 2  FELONY ASSAULT  PL-1200512          F           S              121
# 3  FELONY ASSAULT  PL-1211200          F           Q              100
# 4            RAPE  PL-1302503          F           M               14
#
#    JURISDICTION_CODE   Latitude  Longitude ARREST_MONTH
# 0                  0  40.737043 -73.735514      January
# 1                  0  40.855109 -73.892818        March
# 2                  0  40.628967 -74.163275          May
# 3                  0  40.591980 -73.800066         June
# 4                  0  40.753533 -73.994537      January

# %%
df.shape[1]
# Out:
# 9

# %%
df[_ARREST_PRECINCT] = df[_ARREST_PRECINCT].astype('object')

# %%
df_num= df.select_dtypes(exclude='object')
df_obj= df.select_dtypes(include='object')

df_num.info()
df_obj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188682 entries, 0 to 188681
# Data columns (total 3 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   JURISDICTION_CODE  188682 non-null  int64
#  1   Latitude           188682 non-null  float64
#  2   Longitude          188682 non-null  float64
# dtypes: float64(2), int64(1)
# memory usage: 4.3 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188682 entries, 0 to 188681
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   OFNS_DESC        188682 non-null  object
#  1   LAW_CODE         188682 non-null  object
#  2   LAW_CAT_CD       188682 non-null  object
#  3   ARREST_BORO      188682 non-null  object
#  4   ARREST_PRECINCT  188682 non-null  object
#  5   ARREST_MONTH     188682 non-null  object
# dtypes: object(6)
# memory usage: 8.6+ MB

# %%
df_obj[_OFFENSE_LEVEL].unique()
df_obj
# Out:
#                               OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# 0                        FELONY ASSAULT  PL-1211200          F           Q
# 1                        FELONY ASSAULT  PL-1200502          F           B
# 2                        FELONY ASSAULT  PL-1200512          F           S
# 3                        FELONY ASSAULT  PL-1211200          F           Q
# 4                                  RAPE  PL-1302503          F           M
# ...                                 ...         ...        ...         ...
# 188677                    PETIT LARCENY  PL-1552500          M           Q
# 188678     ASSAULT 3 & RELATED OFFENSES  PL-1200001          M           M
# 188679                         BURGLARY  PL-1402501          F           M
# 188680  OTHER OFFENSES RELATED TO THEFT  PL-1651503          M           B
# 188681                DANGEROUS WEAPONS  PL-265031B          F           B
#
#        ARREST_PRECINCT ARREST_MONTH
# 0                  105      January
# 1                   48        March
# 2                  121          May
# 3                  100         June
# 4                   14      January
# ...                ...          ...
# 188677             109    September
# 188678              34    September
# 188679              23    September
# 188680              44    September
# 188681              46    September
#
# [188682 rows x 6 columns]

# %%
#df_obj= pd.get_dummies(df_obj, drop_first=True)
# df_obj = df_obj.drop(columns=['LAW_CAT_CD_V'],axis=1)
# df_obj.columns
# Out:
# Index(['OFNS_DESC_ADMINISTRATIVE CODES',
#        'OFNS_DESC_ALCOHOLIC BEVERAGE CONTROL LAW',
#        'OFNS_DESC_ANTICIPATORY OFFENSES', 'OFNS_DESC_ARSON',
#        'OFNS_DESC_ASSAULT 3 & RELATED OFFENSES', 'OFNS_DESC_BURGLAR'S TOOLS',
#        'OFNS_DESC_BURGLARY', 'OFNS_DESC_CANNABIS RELATED OFFENSES',
#        'OFNS_DESC_CHILD ABANDONMENT/NON SUPPORT 1',
#        'OFNS_DESC_CRIMINAL MISCHIEF & RELATED OF',
#        ...
#        'ARREST_PRECINCT_122', 'ARREST_PRECINCT_123', 'ARREST_MONTH_August',
#        'ARREST_MONTH_February', 'ARREST_MONTH_January', 'ARREST_MONTH_July',
#        'ARREST_MONTH_June', 'ARREST_MONTH_March', 'ARREST_MONTH_May',
#        'ARREST_MONTH_September'],
#       dtype='object', length=1100)

# %%
# Drop the target column from the data frame
attr = pd.concat([df_obj.drop(columns=['LAW_CAT_CD_M']),df_num],axis=1)


target = (df_obj['LAW_CAT_CD_M'])

print(attr.shape[1])
attr.head()
# Out:
# 1102
#    OFNS_DESC_ADMINISTRATIVE CODES  OFNS_DESC_ALCOHOLIC BEVERAGE CONTROL LAW  \
# 0                           False                                     False
# 1                           False                                     False
# 2                           False                                     False
# 3                           False                                     False
# 4                           False                                     False
#
#    OFNS_DESC_ANTICIPATORY OFFENSES  OFNS_DESC_ARSON  \
# 0                            False            False
# 1                            False            False
# 2                            False            False
# 3                            False            False
# 4                            False            False
#
#    OFNS_DESC_ASSAULT 3 & RELATED OFFENSES  OFNS_DESC_BURGLAR'S TOOLS  \
# 0                                   False                      False
# 1                                   False                      False
# 2                                   False                      False
# 3                                   False                      False
# 4                                   False                      False
#
#    OFNS_DESC_BURGLARY  OFNS_DESC_CANNABIS RELATED OFFENSES  \
# 0               False                                False
# 1               False                                False
# 2               False                                False
# 3               False                                False
# 4               False                                False
#
#    OFNS_DESC_CHILD ABANDONMENT/NON SUPPORT 1  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#    OFNS_DESC_CRIMINAL MISCHIEF & RELATED OF  ...  ARREST_MONTH_February  \
# 0                                     False  ...                  False
# 1                                     False  ...                  False
# 2                                     False  ...                  False
# 3                                     False  ...                  False
# 4                                     False  ...                  False
#
#    ARREST_MONTH_January  ARREST_MONTH_July  ARREST_MONTH_June  \
# 0                  True              False              False
# 1                 False              False              False
# 2                 False              False              False
# 3                 False              False               True
# 4                  True              False              False
#
#    ARREST_MONTH_March  ARREST_MONTH_May  ARREST_MONTH_September  \
# 0               False             False                   False
# 1                True             False                   False
# 2               False              True                   False
# 3               False             False                   False
# 4               False             False                   False
#
#    JURISDICTION_CODE   Latitude  Longitude
# 0                  0  40.737043 -73.735514
# 1                  0  40.855109 -73.892818
# 2                  0  40.628967 -74.163275
# 3                  0  40.591980 -73.800066
# 4                  0  40.753533 -73.994537
#
# [5 rows x 1102 columns]

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and test
attr_train, attr_test, target_train, target_test = train_test_split(attr, target, test_size=0.30, random_state=5)

# %%
attr_train
# Out:
#         OFNS_DESC_ADMINISTRATIVE CODES  \
# 158385                           False
# 145387                           False
# 10483                            False
# 68490                            False
# 72030                            False
# ...                                ...
# 121974                           False
# 124605                           False
# 20463                            False
# 18638                            False
# 35683                            False
#
#         OFNS_DESC_ALCOHOLIC BEVERAGE CONTROL LAW  \
# 158385                                     False
# 145387                                     False
# 10483                                      False
# 68490                                      False
# 72030                                      False
# ...                                          ...
# 121974                                     False
# 124605                                     False
# 20463                                      False
# 18638                                      False
# 35683                                      False
#
#         OFNS_DESC_ANTICIPATORY OFFENSES  OFNS_DESC_ARSON  \
# 158385                            False            False
# 145387                            False            False
# 10483                             False            False
# 68490                             False            False
# 72030                             False            False
# ...                                 ...              ...
# 121974                            False            False
# 124605                            False            False
# 20463                             False            False
# 18638                             False            False
# 35683                             False            False
#
#         OFNS_DESC_ASSAULT 3 & RELATED OFFENSES  OFNS_DESC_BURGLAR'S TOOLS  \
# 158385                                   False                      False
# 145387                                   False                      False
# 10483                                    False                      False
# 68490                                    False                      False
# 72030                                    False                      False
# ...                                        ...                        ...
# 121974                                    True                      False
# 124605                                   False                      False
# 20463                                    False                      False
# 18638                                    False                      False
# 35683                                     True                      False
#
#         OFNS_DESC_BURGLARY  OFNS_DESC_CANNABIS RELATED OFFENSES  \
# 158385               False                                False
# 145387               False                                False
# 10483                False                                False
# 68490                False                                False
# 72030                False                                False
# ...                    ...                                  ...
# 121974               False                                False
# 124605               False                                False
# 20463                False                                False
# 18638                False                                False
# 35683                False                                False
#
#         OFNS_DESC_CHILD ABANDONMENT/NON SUPPORT 1  \
# 158385                                      False
# 145387                                      False
# 10483                                       False
# 68490                                       False
# 72030                                       False
# ...                                           ...
# 121974                                      False
# 124605                                      False
# 20463                                       False
# 18638                                       False
# 35683                                       False
#
#         OFNS_DESC_CRIMINAL MISCHIEF & RELATED OF  ...  ARREST_MONTH_February  \
# 158385                                     False  ...                  False
# 145387                                     False  ...                  False
# 10483                                      False  ...                  False
# 68490                                      False  ...                  False
# 72030                                       True  ...                  False
# ...                                          ...  ...                    ...
# 121974                                     False  ...                  False
# 124605                                     False  ...                  False
# 20463                                      False  ...                  False
# 18638                                      False  ...                  False
# 35683                                      False  ...                  False
#
#         ARREST_MONTH_January  ARREST_MONTH_July  ARREST_MONTH_June  \
# 158385                 False              False              False
# 145387                 False              False               True
# 10483                   True              False              False
# 68490                  False              False               True
# 72030                  False              False              False
# ...                      ...                ...                ...
# 121974                 False              False               True
# 124605                 False               True              False
# 20463                  False              False              False
# 18638                  False              False              False
# 35683                   True              False              False
#
#         ARREST_MONTH_March  ARREST_MONTH_May  ARREST_MONTH_September  \
# 158385               False             False                   False
# 145387               False             False                   False
# 10483                False             False                   False
# 68490                False             False                   False
# 72030                False              True                   False
# ...                    ...               ...                     ...
# 121974               False             False                   False
# 124605               False             False                   False
# 20463                False             False                   False
# 18638                 True             False                   False
# 35683                False             False                   False
#
#         JURISDICTION_CODE   Latitude  Longitude
# 158385                  0  40.851843 -73.901190
# 145387                  0  40.837685 -73.901571
# 10483                   0  40.749258 -73.888976
# 68490                   0  40.766513 -73.920035
# 72030                   0  40.733876 -74.005428
# ...                   ...        ...        ...
# 121974                  0  40.548608 -74.159983
# 124605                  0  40.689640 -73.924051
# 20463                   1  40.731707 -74.000956
# 18638                   1  40.866070 -73.894382
# 35683                   0  40.876494 -73.911698
#
# [132077 rows x 1102 columns]

# %%
target_train
# Out:
# 158385    False
# 145387    False
# 10483     False
# 68490     False
# 72030      True
#           ...
# 121974     True
# 124605     True
# 20463      True
# 18638      True
# 35683      True
# Name: LAW_CAT_CD_M, Length: 132077, dtype: bool

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer


preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(
            handle_unknown="infrequent_if_exist"
            ), df_obj.columns.tolist()),
        ('num', StandardScaler(), df_num.columns.tolist()),
    ],     remainder='passthrough'
)

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline


model = Pipeline(steps=[
    ('preprocessor',preprocessor),
    ('classifier',KNeighborsClassifier())
])

# %%
model.fit (attr_train,target_train)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'LAW_CAT_CD_M'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File c:\Users\cathe\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_indexing.py:361, in _get_column_indices(X, key)
#     360 for col in columns:
# --> 361     col_idx = all_columns.get_loc(col)
#     362     if not isinstance(col_idx, numbers.Integral):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#
# KeyError: 'LAW_CAT_CD_M'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 model.fit (attr_train,target_train)
#
# File c:\Users\cathe\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\cathe\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\pipeline.py:469, in Pipeline.fit(self, X, y, **params)
#     426 """Fit the model.
#     427
#     428 Fit all the transformers one after the other and sequentially transform the
#    (...)
#     466     Pipeline with fitted steps.
#     467 """
#     468 routed_params = self._check_method_params(method="fit", props=params)
# --> 469 Xt = self._fit(X, y, routed_params)
#     470 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     471     if self._final_estimator != "passthrough":
#
# File c:\Users\cathe\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\pipeline.py:406, in Pipeline._fit(self, X, y, routed_params)
#     404     cloned_transformer = clone(transformer)
#     405 # Fit or load from cache the current transformer
# --> 406 X, fitted_transformer = fit_transform_one_cached(
#     407     cloned_transformer,
#     408     X,
#     409     y,
#     410     None,
#     411     message_clsname="Pipeline",
#     412     message=self._log_message(step_idx),
#     413     params=routed_params[name],
#     414 )
#     415 # Replace the transformer of the step with the fitted
#     416 # transformer. This is necessary when loading the transformer
#     417 # from the cache.
#     418 self.steps[step_idx] = (name, fitted_transformer)
#
# File c:\Users\cathe\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\memory.py:312, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     311 def __call__(self, *args, **kwargs):
# --> 312     return self.func(*args, **kwargs)
#
# File c:\Users\cathe\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\pipeline.py:1310, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1308 with _print_elapsed_time(message_clsname, message):
#    1309     if hasattr(transformer, "fit_transform"):
# -> 1310         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1311     else:
#    1312         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1313             X, **params.get("transform", {})
#    1314         )
#
# File c:\Users\cathe\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File c:\Users\cathe\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\cathe\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\compose\_column_transformer.py:968, in ColumnTransformer.fit_transform(self, X, y, **params)
#     965 self._validate_transformers()
#     966 n_samples = _num_samples(X)
# --> 968 self._validate_column_callables(X)
#     969 self._validate_remainder(X)
#     971 if _routing_enabled():
#
# File c:\Users\cathe\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\compose\_column_transformer.py:536, in ColumnTransformer._validate_column_callables(self, X)
#     534         columns = columns(X)
#     535     all_columns.append(columns)
# --> 536     transformer_to_input_indices[name] = _get_column_indices(X, columns)
#     538 self._columns = all_columns
#     539 self._transformer_to_input_indices = transformer_to_input_indices
#
# File c:\Users\cathe\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_indexing.py:369, in _get_column_indices(X, key)
#     366         column_indices.append(col_idx)
#     368 except KeyError as e:
# --> 369     raise ValueError("A given column is not a column of the dataframe") from e
#     371 return column_indices
#
# ValueError: A given column is not a column of the dataframe

# %%
attr.iloc[:, 73]
attr_test.iloc[:, 73].head()
# Out:
# 73128     False
# 168854    False
# 163262    False
# 97913     False
# 139802    False
# Name: LAW_CODE_AC-019190C, dtype: bool

# %%
target_pred = model.predict(attr_test)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# Evaluate the accuracy

#Compute and print the accuracy score.
accuracy = accuracy_score(target_test, target_pred)
print(f'Accuracy: {accuracy}')
print()

# Print the confusion matrix
print(confusion_matrix(target_test, target_pred))
print()

#Print the classification report
print('Classification Report')
print(classification_report(target_test, target_pred))
# Out:
# Accuracy: 0.9976503842416747
#
# [[24533   118]
#  [   15 31939]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00     24651
#         True       1.00      1.00      1.00     31954
#
#     accuracy                           1.00     56605
#    macro avg       1.00      1.00      1.00     56605
# weighted avg       1.00      1.00      1.00     56605
