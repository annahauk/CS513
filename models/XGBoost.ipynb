# %% [markdown]
# # <b> XGBoost Model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os

df = pd.read_csv(os.path.join('NYPD_Arrest_Data_Clean.csv'))
df2 = pd.read_csv(os.path.join('NYPD_Arrest_Data_Clean_Demographics.csv'))

# %%
df
# Out:
#         OFNS_DESC  OFFENSE_LEVEL  ARREST_PRECINCT  JURISDICTION_CODE  \
# 0              17              0              105                  0
# 1               4              0              107                 71
# 2              17              0               48                  0
# 3              17              0              121                  0
# 4              17              0              100                  0
# ...           ...            ...              ...                ...
# 193605         47              1              109                  0
# 193606          5              1               34                  0
# 193607          7              0               23                  0
# 193608         43              1               44                  1
# 193609         13              0               46                  0
#
#          Latitude  Longitude  MONTH   FALL  SPRING  SUMMER  WINTER  BRONX  \
# 0       40.737043 -73.735514      1  False   False   False    True  False
# 1       40.732881 -73.807899      2  False   False   False    True  False
# 2       40.855109 -73.892818      3  False    True   False   False   True
# 3       40.628967 -74.163275      5  False    True   False   False  False
# 4       40.591980 -73.800066      6  False   False    True   False  False
# ...           ...        ...    ...    ...     ...     ...     ...    ...
# 193605  40.757691 -73.834115      9   True   False   False   False  False
# 193606  40.856808 -73.928265      9   True   False   False   False  False
# 193607  40.786116 -73.942614      9   True   False   False   False  False
# 193608  40.827812 -73.925929      9   True   False   False   False   True
# 193609  40.854588 -73.901861      9   True   False   False   False   True
#
#         BROOKLYN  MANHATTAN  QUEENS  STATEN_ISLAND
# 0          False      False    True          False
# 1          False      False    True          False
# 2          False      False   False          False
# 3          False      False   False           True
# 4          False      False    True          False
# ...          ...        ...     ...            ...
# 193605     False      False    True          False
# 193606     False       True   False          False
# 193607     False       True   False          False
# 193608     False      False   False          False
# 193609     False      False   False          False
#
# [193610 rows x 16 columns]

# %%
df2
# Out:
#         OFNS_DESC  OFFENSE_LEVEL  ARREST_PRECINCT  JURISDICTION_CODE  \
# 0              17              0              105                  0
# 1               4              0              107                 71
# 2              17              0               48                  0
# 3              17              0              121                  0
# 4              17              0              100                  0
# ...           ...            ...              ...                ...
# 193605         47              1              109                  0
# 193606          5              1               34                  0
# 193607          7              0               23                  0
# 193608         43              1               44                  1
# 193609         13              0               46                  0
#
#          Latitude  Longitude  MONTH   FALL  SPRING  SUMMER  ...  \
# 0       40.737043 -73.735514      1  False   False   False  ...
# 1       40.732881 -73.807899      2  False   False   False  ...
# 2       40.855109 -73.892818      3  False    True   False  ...
# 3       40.628967 -74.163275      5  False    True   False  ...
# 4       40.591980 -73.800066      6  False   False    True  ...
# ...           ...        ...    ...    ...     ...     ...  ...
# 193605  40.757691 -73.834115      9   True   False   False  ...
# 193606  40.856808 -73.928265      9   True   False   False  ...
# 193607  40.786116 -73.942614      9   True   False   False  ...
# 193608  40.827812 -73.925929      9   True   False   False  ...
# 193609  40.854588 -73.901861      9   True   False   False  ...
#
#         AGE_GROUP_<18  PERP_SEX_F  PERP_SEX_M  \
# 0               False       False        True
# 1               False       False        True
# 2               False       False        True
# 3               False       False        True
# 4               False       False        True
# ...               ...         ...         ...
# 193605          False       False        True
# 193606          False       False        True
# 193607          False       False        True
# 193608          False       False        True
# 193609          False       False        True
#
#         PERP_RACE_AMERICAN INDIAN/ALASKAN NATIVE  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ...                                          ...
# 193605                                     False
# 193606                                     False
# 193607                                     False
# 193608                                     False
# 193609                                     False
#
#         PERP_RACE_ASIAN / PACIFIC ISLANDER  PERP_RACE_BLACK  \
# 0                                    False            False
# 1                                    False            False
# 2                                    False             True
# 3                                    False            False
# 4                                    False             True
# ...                                    ...              ...
# 193605                               False            False
# 193606                               False            False
# 193607                               False            False
# 193608                               False             True
# 193609                               False            False
#
#         PERP_RACE_BLACK HISPANIC  PERP_RACE_UNKNOWN  PERP_RACE_WHITE  \
# 0                          False              False             True
# 1                          False              False             True
# 2                          False              False            False
# 3                          False              False             True
# 4                          False              False            False
# ...                          ...                ...              ...
# 193605                     False              False            False
# 193606                     False              False            False
# 193607                     False              False             True
# 193608                     False              False            False
# 193609                      True              False            False
#
#         PERP_RACE_WHITE HISPANIC
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# ...                          ...
# 193605                      True
# 193606                      True
# 193607                     False
# 193608                     False
# 193609                     False
#
# [193610 rows x 30 columns]

# %%
from sklearn.model_selection import train_test_split

X = df.drop(columns='OFFENSE_LEVEL')
y = df['OFFENSE_LEVEL']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

X2 = df2.drop(columns='OFFENSE_LEVEL')
y2 = df2['OFFENSE_LEVEL']

X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size=0.3, random_state=1234)

# %% [markdown]
# # <b> XGBoost for Data without Demographics

# %%
# run XGBoost on df
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier

xgb = XGBClassifier(n_estimators=100, random_state=1234)
xgb.fit(X_train, y_train)
y_pred = xgb.predict(X_test)

accuracy_score(y_test, y_pred)

print('Accuracy of XGBoost:', accuracy_score(y_test, y_pred))
# Out:
# Accuracy of XGBoost: 0.9319766540984453

# %% [markdown]
# # <b> XGBoost for Data with Demographics

# %%
# Clean feature names
X_train2.columns = X_train2.columns.str.replace('[', '').str.replace(']', '').str.replace('<', '').str.replace('>', '')
X_test2.columns = X_test2.columns.str.replace('[', '').str.replace(']', '').str.replace('<', '').str.replace('>', '')

# Run XGBoost on df2
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

xgb2 = XGBClassifier(n_estimators=100, random_state=1234)
xgb2.fit(X_train2, y_train2)
y_pred2 = xgb2.predict(X_test2)

accuracy = accuracy_score(y_test2, y_pred2)
print('Accuracy of XGBoost on df2:', accuracy)
# Out:
# Accuracy of XGBoost on df2: 0.9342664807258578

# %% [markdown]
# # <b> Hyperparameter Tuning

# %%
#run grid search on df
from sklearn.model_selection import GridSearchCV

param_grid = {'n_estimators': [100, 200, 300], 'max_depth': [3, 4, 5]}
grid_search = GridSearchCV(XGBClassifier(random_state=1234), param_grid, cv=5, verbose=3)
grid_search.fit(X_train, y_train)

print('Best parameters:', grid_search.best_params_)
print('Best score:', grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END .....max_depth=3, n_estimators=100;, score=0.926 total time=   0.7s
# [CV 2/5] END .....max_depth=3, n_estimators=100;, score=0.928 total time=   0.6s
# [CV 3/5] END .....max_depth=3, n_estimators=100;, score=0.928 total time=   0.6s
# [CV 4/5] END .....max_depth=3, n_estimators=100;, score=0.928 total time=   0.6s
# [CV 5/5] END .....max_depth=3, n_estimators=100;, score=0.929 total time=   0.6s
# [CV 1/5] END .....max_depth=3, n_estimators=200;, score=0.929 total time=   1.2s
# [CV 2/5] END .....max_depth=3, n_estimators=200;, score=0.929 total time=   1.2s
# [CV 3/5] END .....max_depth=3, n_estimators=200;, score=0.929 total time=   1.2s
# [CV 4/5] END .....max_depth=3, n_estimators=200;, score=0.929 total time=   1.2s
# [CV 5/5] END .....max_depth=3, n_estimators=200;, score=0.931 total time=   1.3s
# [CV 1/5] END .....max_depth=3, n_estimators=300;, score=0.930 total time=   1.8s
# [CV 2/5] END .....max_depth=3, n_estimators=300;, score=0.930 total time=   1.9s
# [CV 3/5] END .....max_depth=3, n_estimators=300;, score=0.929 total time=   1.9s
# [CV 4/5] END .....max_depth=3, n_estimators=300;, score=0.929 total time=   1.9s
# [CV 5/5] END .....max_depth=3, n_estimators=300;, score=0.931 total time=   1.8s
# [CV 1/5] END .....max_depth=4, n_estimators=100;, score=0.930 total time=   0.8s
# [CV 2/5] END .....max_depth=4, n_estimators=100;, score=0.930 total time=   0.8s
# [CV 3/5] END .....max_depth=4, n_estimators=100;, score=0.929 total time=   0.8s
# [CV 4/5] END .....max_depth=4, n_estimators=100;, score=0.930 total time=   0.8s
# [CV 5/5] END .....max_depth=4, n_estimators=100;, score=0.932 total time=   0.8s
# [CV 1/5] END .....max_depth=4, n_estimators=200;, score=0.929 total time=   1.5s
# [CV 2/5] END .....max_depth=4, n_estimators=200;, score=0.931 total time=   1.5s
# [CV 3/5] END .....max_depth=4, n_estimators=200;, score=0.931 total time=   1.5s
# [CV 4/5] END .....max_depth=4, n_estimators=200;, score=0.931 total time=   1.4s
# [CV 5/5] END .....max_depth=4, n_estimators=200;, score=0.931 total time=   1.5s
# [CV 1/5] END .....max_depth=4, n_estimators=300;, score=0.931 total time=   2.2s
# [CV 2/5] END .....max_depth=4, n_estimators=300;, score=0.931 total time=   2.2s
# [CV 3/5] END .....max_depth=4, n_estimators=300;, score=0.931 total time=   2.3s
# [CV 4/5] END .....max_depth=4, n_estimators=300;, score=0.932 total time=   2.3s
# [CV 5/5] END .....max_depth=4, n_estimators=300;, score=0.932 total time=   2.3s
# [CV 1/5] END .....max_depth=5, n_estimators=100;, score=0.930 total time=   0.9s
# [CV 2/5] END .....max_depth=5, n_estimators=100;, score=0.930 total time=   0.9s
# [CV 3/5] END .....max_depth=5, n_estimators=100;, score=0.930 total time=   0.9s
# [CV 4/5] END .....max_depth=5, n_estimators=100;, score=0.932 total time=   0.9s
# [CV 5/5] END .....max_depth=5, n_estimators=100;, score=0.932 total time=   0.9s
# [CV 1/5] END .....max_depth=5, n_estimators=200;, score=0.930 total time=   1.7s
# [CV 2/5] END .....max_depth=5, n_estimators=200;, score=0.933 total time=   1.7s
# [CV 3/5] END .....max_depth=5, n_estimators=200;, score=0.930 total time=   1.7s
# [CV 4/5] END .....max_depth=5, n_estimators=200;, score=0.931 total time=   1.8s
# [CV 5/5] END .....max_depth=5, n_estimators=200;, score=0.931 total time=   1.8s
# [CV 1/5] END .....max_depth=5, n_estimators=300;, score=0.929 total time=   2.5s
# [CV 2/5] END .....max_depth=5, n_estimators=300;, score=0.932 total time=   2.6s
# [CV 3/5] END .....max_depth=5, n_estimators=300;, score=0.931 total time=   2.7s
# [CV 4/5] END .....max_depth=5, n_estimators=300;, score=0.932 total time=   2.7s
# [CV 5/5] END .....max_depth=5, n_estimators=300;, score=0.931 total time=   2.6s
# Best parameters: {'max_depth': 4, 'n_estimators': 300}
# Best score: 0.9312166650449342

# %%
# run grid search on df2
param_grid = {'n_estimators': [100, 200, 300], 'max_depth': [3, 4, 5]}
grid_search2 = GridSearchCV(XGBClassifier(random_state=1234), param_grid, cv=5, verbose=3)
grid_search2.fit(X_train2, y_train2)

print('Best parameters:', grid_search2.best_params_)
print('Best score:', grid_search2.best_score_)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END .....max_depth=3, n_estimators=100;, score=0.929 total time=   0.9s
# [CV 2/5] END .....max_depth=3, n_estimators=100;, score=0.929 total time=   0.8s
# [CV 3/5] END .....max_depth=3, n_estimators=100;, score=0.930 total time=   0.8s
# [CV 4/5] END .....max_depth=3, n_estimators=100;, score=0.930 total time=   0.8s
# [CV 5/5] END .....max_depth=3, n_estimators=100;, score=0.932 total time=   0.7s
# [CV 1/5] END .....max_depth=3, n_estimators=200;, score=0.932 total time=   1.3s
# [CV 2/5] END .....max_depth=3, n_estimators=200;, score=0.931 total time=   1.3s
# [CV 3/5] END .....max_depth=3, n_estimators=200;, score=0.931 total time=   1.5s
# [CV 4/5] END .....max_depth=3, n_estimators=200;, score=0.932 total time=   1.5s
# [CV 5/5] END .....max_depth=3, n_estimators=200;, score=0.934 total time=   1.5s
# [CV 1/5] END .....max_depth=3, n_estimators=300;, score=0.932 total time=   2.0s
# [CV 2/5] END .....max_depth=3, n_estimators=300;, score=0.932 total time=   2.1s
# [CV 3/5] END .....max_depth=3, n_estimators=300;, score=0.932 total time=   2.2s
# [CV 4/5] END .....max_depth=3, n_estimators=300;, score=0.932 total time=   2.1s
# [CV 5/5] END .....max_depth=3, n_estimators=300;, score=0.936 total time=   2.1s
# [CV 1/5] END .....max_depth=4, n_estimators=100;, score=0.932 total time=   0.9s
# [CV 2/5] END .....max_depth=4, n_estimators=100;, score=0.932 total time=   0.9s
# [CV 3/5] END .....max_depth=4, n_estimators=100;, score=0.930 total time=   0.9s
# [CV 4/5] END .....max_depth=4, n_estimators=100;, score=0.932 total time=   0.9s
# [CV 5/5] END .....max_depth=4, n_estimators=100;, score=0.934 total time=   0.8s
# [CV 1/5] END .....max_depth=4, n_estimators=200;, score=0.933 total time=   1.6s
# [CV 2/5] END .....max_depth=4, n_estimators=200;, score=0.932 total time=   1.7s
# [CV 3/5] END .....max_depth=4, n_estimators=200;, score=0.932 total time=   1.6s
# [CV 4/5] END .....max_depth=4, n_estimators=200;, score=0.933 total time=   1.7s
# [CV 5/5] END .....max_depth=4, n_estimators=200;, score=0.935 total time=   1.6s
# [CV 1/5] END .....max_depth=4, n_estimators=300;, score=0.934 total time=   2.4s
# [CV 2/5] END .....max_depth=4, n_estimators=300;, score=0.932 total time=   2.4s
# [CV 3/5] END .....max_depth=4, n_estimators=300;, score=0.933 total time=   2.4s
# [CV 4/5] END .....max_depth=4, n_estimators=300;, score=0.933 total time=   2.4s
# [CV 5/5] END .....max_depth=4, n_estimators=300;, score=0.936 total time=   2.3s
# [CV 1/5] END .....max_depth=5, n_estimators=100;, score=0.933 total time=   1.0s
# [CV 2/5] END .....max_depth=5, n_estimators=100;, score=0.932 total time=   1.0s
# [CV 3/5] END .....max_depth=5, n_estimators=100;, score=0.932 total time=   0.9s
# [CV 4/5] END .....max_depth=5, n_estimators=100;, score=0.934 total time=   1.0s
# [CV 5/5] END .....max_depth=5, n_estimators=100;, score=0.936 total time=   1.0s
# [CV 1/5] END .....max_depth=5, n_estimators=200;, score=0.933 total time=   1.8s
# [CV 2/5] END .....max_depth=5, n_estimators=200;, score=0.933 total time=   1.8s
# [CV 3/5] END .....max_depth=5, n_estimators=200;, score=0.933 total time=   1.9s
# [CV 4/5] END .....max_depth=5, n_estimators=200;, score=0.934 total time=   2.0s
# [CV 5/5] END .....max_depth=5, n_estimators=200;, score=0.937 total time=   1.9s
# [CV 1/5] END .....max_depth=5, n_estimators=300;, score=0.933 total time=   2.7s
# [CV 2/5] END .....max_depth=5, n_estimators=300;, score=0.933 total time=   2.9s
# [CV 3/5] END .....max_depth=5, n_estimators=300;, score=0.934 total time=   2.9s
# [CV 4/5] END .....max_depth=5, n_estimators=300;, score=0.934 total time=   2.7s
# [CV 5/5] END .....max_depth=5, n_estimators=300;, score=0.935 total time=   2.7s
# Best parameters: {'max_depth': 5, 'n_estimators': 200}
# Best score: 0.9339024864200155

# %% [markdown]
# # <b> Analysis, Accuracy, and Metrics

# %%
# print classificatioon report for df
from sklearn.metrics import classification_report

y_pred = grid_search.predict(X_test)
print(classification_report(y_test, y_pred))

# print classification report for df2
y_pred2 = grid_search2.predict(X_test2)
print(classification_report(y_test2, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92     24823
#            1       0.96      0.92      0.94     32721
#            2       0.96      0.86      0.91       539
#
#     accuracy                           0.93     58083
#    macro avg       0.94      0.91      0.92     58083
# weighted avg       0.93      0.93      0.93     58083
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.92     24823
#            1       0.96      0.93      0.94     32721
#            2       0.97      0.86      0.91       539
#
#     accuracy                           0.93     58083
#    macro avg       0.94      0.91      0.92     58083
# weighted avg       0.93      0.93      0.93     58083

# %%
# Generate classification report
report = classification_report(y_test, y_pred, digits=2, output_dict=True)
df = pd.DataFrame(report).T

# Convert support column to integer
df['support'] = df['support'].apply(int)

# Apply background gradient
styled_df = df.style.background_gradient(cmap='viridis', subset=pd.IndexSlice['0':'9', :'f1-score'])

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_dd5a3_row0_col0, #T_dd5a3_row2_col1, #T_dd5a3_row2_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_dd5a3_row0_col1, #T_dd5a3_row1_col2, #T_dd5a3_row2_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_dd5a3_row0_col2 {
#   background-color: #25858e;
#   color: #f1f1f1;
# }
# #T_dd5a3_row1_col0 {
#   background-color: #addc30;
#   color: #000000;
# }
# #T_dd5a3_row1_col1 {
#   background-color: #5cc863;
#   color: #000000;
# }
# </style>
# <table id="T_dd5a3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd5a3_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_dd5a3_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_dd5a3_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_dd5a3_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd5a3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dd5a3_row0_col0" class="data row0 col0" >0.899332</td>
#       <td id="T_dd5a3_row0_col1" class="data row0 col1" >0.944366</td>
#       <td id="T_dd5a3_row0_col2" class="data row0 col2" >0.921299</td>
#       <td id="T_dd5a3_row0_col3" class="data row0 col3" >24823</td>
#     </tr>
#     <tr>
#       <th id="T_dd5a3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dd5a3_row1_col0" class="data row1 col0" >0.956467</td>
#       <td id="T_dd5a3_row1_col1" class="data row1 col1" >0.921916</td>
#       <td id="T_dd5a3_row1_col2" class="data row1 col2" >0.938873</td>
#       <td id="T_dd5a3_row1_col3" class="data row1 col3" >32721</td>
#     </tr>
#     <tr>
#       <th id="T_dd5a3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dd5a3_row2_col0" class="data row2 col0" >0.964435</td>
#       <td id="T_dd5a3_row2_col1" class="data row2 col1" >0.855288</td>
#       <td id="T_dd5a3_row2_col2" class="data row2 col2" >0.906588</td>
#       <td id="T_dd5a3_row2_col3" class="data row2 col3" >539</td>
#     </tr>
#     <tr>
#       <th id="T_dd5a3_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_dd5a3_row3_col0" class="data row3 col0" >0.930892</td>
#       <td id="T_dd5a3_row3_col1" class="data row3 col1" >0.930892</td>
#       <td id="T_dd5a3_row3_col2" class="data row3 col2" >0.930892</td>
#       <td id="T_dd5a3_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_dd5a3_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_dd5a3_row4_col0" class="data row4 col0" >0.940078</td>
#       <td id="T_dd5a3_row4_col1" class="data row4 col1" >0.907190</td>
#       <td id="T_dd5a3_row4_col2" class="data row4 col2" >0.922254</td>
#       <td id="T_dd5a3_row4_col3" class="data row4 col3" >58083</td>
#     </tr>
#     <tr>
#       <th id="T_dd5a3_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_dd5a3_row5_col0" class="data row5 col0" >0.932123</td>
#       <td id="T_dd5a3_row5_col1" class="data row5 col1" >0.930892</td>
#       <td id="T_dd5a3_row5_col2" class="data row5 col2" >0.931063</td>
#       <td id="T_dd5a3_row5_col3" class="data row5 col3" >58083</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Generate classification report
report2 = classification_report(y_test2, y_pred2, digits=2, output_dict=True)
df2 = pd.DataFrame(report2).T

# Convert support column to integer
df2['support'] = df2['support'].apply(int)

# Apply background gradient
styled_df2 = df2.style.background_gradient(cmap='viridis', subset=pd.IndexSlice['0':'9', :'f1-score'])

# Display the styled DataFrame
styled_df2
# Out:
# <style type="text/css">
# #T_24c4e_row0_col0, #T_24c4e_row2_col1, #T_24c4e_row2_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_24c4e_row0_col1, #T_24c4e_row1_col2, #T_24c4e_row2_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_24c4e_row0_col2 {
#   background-color: #228c8d;
#   color: #f1f1f1;
# }
# #T_24c4e_row1_col0 {
#   background-color: #90d743;
#   color: #000000;
# }
# #T_24c4e_row1_col1 {
#   background-color: #81d34d;
#   color: #000000;
# }
# </style>
# <table id="T_24c4e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_24c4e_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_24c4e_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_24c4e_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_24c4e_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_24c4e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_24c4e_row0_col0" class="data row0 col0" >0.905841</td>
#       <td id="T_24c4e_row0_col1" class="data row0 col1" >0.944084</td>
#       <td id="T_24c4e_row0_col2" class="data row0 col2" >0.924567</td>
#       <td id="T_24c4e_row0_col3" class="data row0 col3" >24823</td>
#     </tr>
#     <tr>
#       <th id="T_24c4e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_24c4e_row1_col0" class="data row1 col0" >0.956514</td>
#       <td id="T_24c4e_row1_col1" class="data row1 col1" >0.927661</td>
#       <td id="T_24c4e_row1_col2" class="data row1 col2" >0.941866</td>
#       <td id="T_24c4e_row1_col3" class="data row1 col3" >32721</td>
#     </tr>
#     <tr>
#       <th id="T_24c4e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_24c4e_row2_col0" class="data row2 col0" >0.966527</td>
#       <td id="T_24c4e_row2_col1" class="data row2 col1" >0.857143</td>
#       <td id="T_24c4e_row2_col2" class="data row2 col2" >0.908555</td>
#       <td id="T_24c4e_row2_col3" class="data row2 col3" >539</td>
#     </tr>
#     <tr>
#       <th id="T_24c4e_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_24c4e_row3_col0" class="data row3 col0" >0.934025</td>
#       <td id="T_24c4e_row3_col1" class="data row3 col1" >0.934025</td>
#       <td id="T_24c4e_row3_col2" class="data row3 col2" >0.934025</td>
#       <td id="T_24c4e_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_24c4e_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_24c4e_row4_col0" class="data row4 col0" >0.942960</td>
#       <td id="T_24c4e_row4_col1" class="data row4 col1" >0.909629</td>
#       <td id="T_24c4e_row4_col2" class="data row4 col2" >0.924996</td>
#       <td id="T_24c4e_row4_col3" class="data row4 col3" >58083</td>
#     </tr>
#     <tr>
#       <th id="T_24c4e_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_24c4e_row5_col0" class="data row5 col0" >0.934950</td>
#       <td id="T_24c4e_row5_col1" class="data row5 col1" >0.934025</td>
#       <td id="T_24c4e_row5_col2" class="data row5 col2" >0.934164</td>
#       <td id="T_24c4e_row5_col3" class="data row5 col3" >58083</td>
#     </tr>
#   </tbody>
# </table>
