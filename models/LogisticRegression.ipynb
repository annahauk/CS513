# %% [markdown]
# # <b> Logistic Regression Model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os

df = pd.read_csv(os.path.join('NYPD_Arrest_Data_Clean.csv'))
df2 = pd.read_csv(os.path.join('NYPD_Arrest_Data_Clean_Demographics.csv'))

# %%
df
# Out:
#         OFNS_DESC  OFFENSE_LEVEL  ARREST_PRECINCT  JURISDICTION_CODE  \
# 0              17              0              105                  0
# 1               4              0              107                 71
# 2              17              0               48                  0
# 3              17              0              121                  0
# 4              17              0              100                  0
# ...           ...            ...              ...                ...
# 193605         47              1              109                  0
# 193606          5              1               34                  0
# 193607          7              0               23                  0
# 193608         43              1               44                  1
# 193609         13              0               46                  0
#
#          Latitude  Longitude  MONTH   FALL  SPRING  SUMMER  WINTER  BRONX  \
# 0       40.737043 -73.735514      1  False   False   False    True  False
# 1       40.732881 -73.807899      2  False   False   False    True  False
# 2       40.855109 -73.892818      3  False    True   False   False   True
# 3       40.628967 -74.163275      5  False    True   False   False  False
# 4       40.591980 -73.800066      6  False   False    True   False  False
# ...           ...        ...    ...    ...     ...     ...     ...    ...
# 193605  40.757691 -73.834115      9   True   False   False   False  False
# 193606  40.856808 -73.928265      9   True   False   False   False  False
# 193607  40.786116 -73.942614      9   True   False   False   False  False
# 193608  40.827812 -73.925929      9   True   False   False   False   True
# 193609  40.854588 -73.901861      9   True   False   False   False   True
#
#         BROOKLYN  MANHATTAN  QUEENS  STATEN_ISLAND
# 0          False      False    True          False
# 1          False      False    True          False
# 2          False      False   False          False
# 3          False      False   False           True
# 4          False      False    True          False
# ...          ...        ...     ...            ...
# 193605     False      False    True          False
# 193606     False       True   False          False
# 193607     False       True   False          False
# 193608     False      False   False          False
# 193609     False      False   False          False
#
# [193610 rows x 16 columns]

# %%
df2
# Out:
#         OFNS_DESC  OFFENSE_LEVEL  ARREST_PRECINCT  JURISDICTION_CODE  \
# 0              17              0              105                  0
# 1               4              0              107                 71
# 2              17              0               48                  0
# 3              17              0              121                  0
# 4              17              0              100                  0
# ...           ...            ...              ...                ...
# 193605         47              1              109                  0
# 193606          5              1               34                  0
# 193607          7              0               23                  0
# 193608         43              1               44                  1
# 193609         13              0               46                  0
#
#          Latitude  Longitude  MONTH   FALL  SPRING  SUMMER  ...  \
# 0       40.737043 -73.735514      1  False   False   False  ...
# 1       40.732881 -73.807899      2  False   False   False  ...
# 2       40.855109 -73.892818      3  False    True   False  ...
# 3       40.628967 -74.163275      5  False    True   False  ...
# 4       40.591980 -73.800066      6  False   False    True  ...
# ...           ...        ...    ...    ...     ...     ...  ...
# 193605  40.757691 -73.834115      9   True   False   False  ...
# 193606  40.856808 -73.928265      9   True   False   False  ...
# 193607  40.786116 -73.942614      9   True   False   False  ...
# 193608  40.827812 -73.925929      9   True   False   False  ...
# 193609  40.854588 -73.901861      9   True   False   False  ...
#
#         AGE_GROUP_<18  PERP_SEX_F  PERP_SEX_M  \
# 0               False       False        True
# 1               False       False        True
# 2               False       False        True
# 3               False       False        True
# 4               False       False        True
# ...               ...         ...         ...
# 193605          False       False        True
# 193606          False       False        True
# 193607          False       False        True
# 193608          False       False        True
# 193609          False       False        True
#
#         PERP_RACE_AMERICAN INDIAN/ALASKAN NATIVE  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ...                                          ...
# 193605                                     False
# 193606                                     False
# 193607                                     False
# 193608                                     False
# 193609                                     False
#
#         PERP_RACE_ASIAN / PACIFIC ISLANDER  PERP_RACE_BLACK  \
# 0                                    False            False
# 1                                    False            False
# 2                                    False             True
# 3                                    False            False
# 4                                    False             True
# ...                                    ...              ...
# 193605                               False            False
# 193606                               False            False
# 193607                               False            False
# 193608                               False             True
# 193609                               False            False
#
#         PERP_RACE_BLACK HISPANIC  PERP_RACE_UNKNOWN  PERP_RACE_WHITE  \
# 0                          False              False             True
# 1                          False              False             True
# 2                          False              False            False
# 3                          False              False             True
# 4                          False              False            False
# ...                          ...                ...              ...
# 193605                     False              False            False
# 193606                     False              False            False
# 193607                     False              False             True
# 193608                     False              False            False
# 193609                      True              False            False
#
#         PERP_RACE_WHITE HISPANIC
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# ...                          ...
# 193605                      True
# 193606                      True
# 193607                     False
# 193608                     False
# 193609                     False
#
# [193610 rows x 30 columns]

# %% [markdown]
# ## <b>Split

# %%
from sklearn.model_selection import train_test_split

X = df.drop(columns='OFFENSE_LEVEL')
y = df['OFFENSE_LEVEL']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

X2 = df2.drop(columns='OFFENSE_LEVEL')
y2 = df2['OFFENSE_LEVEL']

X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size=0.3, random_state=1234)

# %% [markdown]
# # <b> Logistic Regression for Data without Demographics

# %%
# Logistic Regression for df
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

model = LogisticRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

accuracy_score(y_test, y_pred)

print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
# Out:
# Accuracy: 0.4428490263932648
# /Users/annahauk/Desktop/CS513/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# Scale the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Logistic Regression with increased max_iter and scaled data
model = LogisticRegression(max_iter=1000, solver='liblinear')
model.fit(X_train_scaled, y_train)
y_pred = model.predict(X_test_scaled)

accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.4644904705335468

# %%
# preform hyper parameter tuning
from sklearn.model_selection import GridSearchCV

param_grid = {'max_iter': [1000, 2000, 3000], 'solver': ['liblinear', 'saga']}
grid = GridSearchCV(model, param_grid, verbose=3)

grid.fit(X_train_scaled, y_train)

print(grid.best_params_)
print(grid.best_score_)
print(grid.best_estimator_)
print(grid.best_index_)
print(grid.scorer_)
print(grid.n_splits_)
print(grid.refit_time_)
print(grid.cv_results_)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5] END ...max_iter=1000, solver=liblinear;, score=0.468 total time=   0.4s
# [CV 2/5] END ...max_iter=1000, solver=liblinear;, score=0.469 total time=   0.5s
# [CV 3/5] END ...max_iter=1000, solver=liblinear;, score=0.464 total time=   0.4s
# [CV 4/5] END ...max_iter=1000, solver=liblinear;, score=0.467 total time=   0.5s
# [CV 5/5] END ...max_iter=1000, solver=liblinear;, score=0.464 total time=   0.4s
# /Users/annahauk/Desktop/CS513/.venv/lib/python3.13/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 1/5] END ........max_iter=1000, solver=saga;, score=0.467 total time=  31.1s
# /Users/annahauk/Desktop/CS513/.venv/lib/python3.13/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 2/5] END ........max_iter=1000, solver=saga;, score=0.469 total time=  33.6s
# [CV 3/5] END ........max_iter=1000, solver=saga;, score=0.465 total time=   4.9s
# /Users/annahauk/Desktop/CS513/.venv/lib/python3.13/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 4/5] END ........max_iter=1000, solver=saga;, score=0.466 total time=  31.2s
# /Users/annahauk/Desktop/CS513/.venv/lib/python3.13/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 5/5] END ........max_iter=1000, solver=saga;, score=0.463 total time=  33.8s
# [CV 1/5] END ...max_iter=2000, solver=liblinear;, score=0.468 total time=   0.4s
# [CV 2/5] END ...max_iter=2000, solver=liblinear;, score=0.469 total time=   0.5s
# [CV 3/5] END ...max_iter=2000, solver=liblinear;, score=0.464 total time=   0.4s
# [CV 4/5] END ...max_iter=2000, solver=liblinear;, score=0.467 total time=   0.5s
# [CV 5/5] END ...max_iter=2000, solver=liblinear;, score=0.464 total time=   0.4s
# /Users/annahauk/Desktop/CS513/.venv/lib/python3.13/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 1/5] END ........max_iter=2000, solver=saga;, score=0.467 total time= 1.1min
# /Users/annahauk/Desktop/CS513/.venv/lib/python3.13/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 2/5] END ........max_iter=2000, solver=saga;, score=0.469 total time= 1.1min
# [CV 3/5] END ........max_iter=2000, solver=saga;, score=0.465 total time=   4.5s
# /Users/annahauk/Desktop/CS513/.venv/lib/python3.13/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 4/5] END ........max_iter=2000, solver=saga;, score=0.466 total time= 1.1min
# /Users/annahauk/Desktop/CS513/.venv/lib/python3.13/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 5/5] END ........max_iter=2000, solver=saga;, score=0.464 total time= 1.1min
# [CV 1/5] END ...max_iter=3000, solver=liblinear;, score=0.468 total time=   0.4s
# [CV 2/5] END ...max_iter=3000, solver=liblinear;, score=0.469 total time=   0.4s
# [CV 3/5] END ...max_iter=3000, solver=liblinear;, score=0.464 total time=   0.4s
# [CV 4/5] END ...max_iter=3000, solver=liblinear;, score=0.467 total time=   0.6s
# [CV 5/5] END ...max_iter=3000, solver=liblinear;, score=0.464 total time=   0.4s
# /Users/annahauk/Desktop/CS513/.venv/lib/python3.13/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 1/5] END ........max_iter=3000, solver=saga;, score=0.467 total time= 1.6min
# /Users/annahauk/Desktop/CS513/.venv/lib/python3.13/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 2/5] END ........max_iter=3000, solver=saga;, score=0.469 total time= 1.5min
# [CV 3/5] END ........max_iter=3000, solver=saga;, score=0.465 total time=   4.2s
# /Users/annahauk/Desktop/CS513/.venv/lib/python3.13/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 4/5] END ........max_iter=3000, solver=saga;, score=0.466 total time= 1.4min
# /Users/annahauk/Desktop/CS513/.venv/lib/python3.13/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [CV 5/5] END ........max_iter=3000, solver=saga;, score=0.464 total time= 1.4min
# {'max_iter': 1000, 'solver': 'liblinear'}
# 0.46628344074537453
# LogisticRegression(max_iter=1000, solver='liblinear')
# 0
# <class 'sklearn.linear_model._logistic.LogisticRegression'>.score
# 5
# 0.47287726402282715
# {'mean_fit_time': array([ 0.43926959, 26.9196918 ,  0.44529457, 52.8164278 ,  0.43992262,
#        71.01685615]), 'std_fit_time': array([ 0.03924208, 11.08119551,  0.03851784, 24.18469667,  0.06895704,
#        33.84258792]), 'mean_score_time': array([0.00138521, 0.00177369, 0.00149345, 0.00173922, 0.00138898,
#        0.0017313 ]), 'std_score_time': array([6.19471850e-05, 3.08277365e-04, 1.91252067e-04, 1.48888797e-04,
#        1.08229998e-04, 1.67963112e-04]), 'param_max_iter': masked_array(data=[1000, 1000, 2000, 2000, 3000, 3000],
#              mask=[False, False, False, False, False, False],
#        fill_value=999999), 'param_solver': masked_array(data=['liblinear', 'saga', 'liblinear', 'saga', 'liblinear',
#                    'saga'],
#              mask=[False, False, False, False, False, False],
#        fill_value=np.str_('?'),
#             dtype=object), 'params': [{'max_iter': 1000, 'solver': 'liblinear'}, {'max_iter': 1000, 'solver': 'saga'}, {'max_iter': 2000, 'solver': 'liblinear'}, {'max_iter': 2000, 'solver': 'saga'}, {'max_iter': 3000, 'solver': 'liblinear'}, {'max_iter': 3000, 'solver': 'saga'}], 'split0_test_score': array([0.46783   , 0.46694459, 0.46783   , 0.46712905, 0.46783   ,
#        0.46723973]), 'split1_test_score': array([0.46886298, 0.46897366, 0.46886298, 0.46912123, 0.46886298,
#        0.46912123]), 'split2_test_score': array([0.46437927, 0.46496956, 0.46437927, 0.46496956, 0.46437927,
#        0.46496956]), 'split3_test_score': array([0.46651909, 0.46563365, 0.46651909, 0.46611326, 0.46651909,
#        0.46622394]), 'split4_test_score': array([0.46382586, 0.46327246, 0.46382586, 0.46364139, 0.46382586,
#        0.46364139]), 'mean_test_score': array([0.46628344, 0.46595878, 0.46628344, 0.4661949 , 0.46628344,
#        0.46623917]), 'std_test_score': array([0.00193737, 0.00191635, 0.00193737, 0.00186893, 0.00193737,
#        0.00187978]), 'rank_test_score': array([1, 6, 1, 5, 1, 4], dtype=int32)}

# %% [markdown]
# # <b> Logistic Regression for Data with Demographics

# %% [markdown]
# # <b> Analysis, Accuracy, and Metrics
