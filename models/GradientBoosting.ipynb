# %% [markdown]
# # <b> Gradient Boosting Model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os

df = pd.read_csv(os.path.join('NYPD_Arrest_Data_Clean.csv'))
df2 = pd.read_csv(os.path.join('NYPD_Arrest_Data_Clean_Demographics.csv'))

# %%
df
# Out:
#         OFNS_DESC  OFFENSE_LEVEL  ARREST_PRECINCT  JURISDICTION_CODE  \
# 0              17              0              105                  0
# 1               4              0              107                 71
# 2              17              0               48                  0
# 3              17              0              121                  0
# 4              17              0              100                  0
# ...           ...            ...              ...                ...
# 193605         47              1              109                  0
# 193606          5              1               34                  0
# 193607          7              0               23                  0
# 193608         43              1               44                  1
# 193609         13              0               46                  0
#
#          Latitude  Longitude  MONTH   FALL  SPRING  SUMMER  WINTER  BRONX  \
# 0       40.737043 -73.735514      1  False   False   False    True  False
# 1       40.732881 -73.807899      2  False   False   False    True  False
# 2       40.855109 -73.892818      3  False    True   False   False   True
# 3       40.628967 -74.163275      5  False    True   False   False  False
# 4       40.591980 -73.800066      6  False   False    True   False  False
# ...           ...        ...    ...    ...     ...     ...     ...    ...
# 193605  40.757691 -73.834115      9   True   False   False   False  False
# 193606  40.856808 -73.928265      9   True   False   False   False  False
# 193607  40.786116 -73.942614      9   True   False   False   False  False
# 193608  40.827812 -73.925929      9   True   False   False   False   True
# 193609  40.854588 -73.901861      9   True   False   False   False   True
#
#         BROOKLYN  MANHATTAN  QUEENS  STATEN_ISLAND
# 0          False      False    True          False
# 1          False      False    True          False
# 2          False      False   False          False
# 3          False      False   False           True
# 4          False      False    True          False
# ...          ...        ...     ...            ...
# 193605     False      False    True          False
# 193606     False       True   False          False
# 193607     False       True   False          False
# 193608     False      False   False          False
# 193609     False      False   False          False
#
# [193610 rows x 16 columns]

# %%
df2
# Out:
#         OFNS_DESC  OFFENSE_LEVEL  ARREST_PRECINCT  JURISDICTION_CODE  \
# 0              17              0              105                  0
# 1               4              0              107                 71
# 2              17              0               48                  0
# 3              17              0              121                  0
# 4              17              0              100                  0
# ...           ...            ...              ...                ...
# 193605         47              1              109                  0
# 193606          5              1               34                  0
# 193607          7              0               23                  0
# 193608         43              1               44                  1
# 193609         13              0               46                  0
#
#          Latitude  Longitude  MONTH   FALL  SPRING  SUMMER  ...  \
# 0       40.737043 -73.735514      1  False   False   False  ...
# 1       40.732881 -73.807899      2  False   False   False  ...
# 2       40.855109 -73.892818      3  False    True   False  ...
# 3       40.628967 -74.163275      5  False    True   False  ...
# 4       40.591980 -73.800066      6  False   False    True  ...
# ...           ...        ...    ...    ...     ...     ...  ...
# 193605  40.757691 -73.834115      9   True   False   False  ...
# 193606  40.856808 -73.928265      9   True   False   False  ...
# 193607  40.786116 -73.942614      9   True   False   False  ...
# 193608  40.827812 -73.925929      9   True   False   False  ...
# 193609  40.854588 -73.901861      9   True   False   False  ...
#
#         AGE_GROUP_<18  PERP_SEX_F  PERP_SEX_M  \
# 0               False       False        True
# 1               False       False        True
# 2               False       False        True
# 3               False       False        True
# 4               False       False        True
# ...               ...         ...         ...
# 193605          False       False        True
# 193606          False       False        True
# 193607          False       False        True
# 193608          False       False        True
# 193609          False       False        True
#
#         PERP_RACE_AMERICAN INDIAN/ALASKAN NATIVE  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ...                                          ...
# 193605                                     False
# 193606                                     False
# 193607                                     False
# 193608                                     False
# 193609                                     False
#
#         PERP_RACE_ASIAN / PACIFIC ISLANDER  PERP_RACE_BLACK  \
# 0                                    False            False
# 1                                    False            False
# 2                                    False             True
# 3                                    False            False
# 4                                    False             True
# ...                                    ...              ...
# 193605                               False            False
# 193606                               False            False
# 193607                               False            False
# 193608                               False             True
# 193609                               False            False
#
#         PERP_RACE_BLACK HISPANIC  PERP_RACE_UNKNOWN  PERP_RACE_WHITE  \
# 0                          False              False             True
# 1                          False              False             True
# 2                          False              False            False
# 3                          False              False             True
# 4                          False              False            False
# ...                          ...                ...              ...
# 193605                     False              False            False
# 193606                     False              False            False
# 193607                     False              False             True
# 193608                     False              False            False
# 193609                      True              False            False
#
#         PERP_RACE_WHITE HISPANIC
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# ...                          ...
# 193605                      True
# 193606                      True
# 193607                     False
# 193608                     False
# 193609                     False
#
# [193610 rows x 30 columns]

# %%
from sklearn.model_selection import train_test_split

X = df.drop(columns='OFFENSE_LEVEL')
y = df['OFFENSE_LEVEL']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

X2 = df2.drop(columns='OFFENSE_LEVEL')
y2 = df2['OFFENSE_LEVEL']

X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size=0.3, random_state=1234)

# %% [markdown]
# # <b> Gradient Classifier for Data without Demographics

# %%
# gradient booster classifier on df
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score

gbc = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=1, random_state=1234)
gbc.fit(X_train, y_train)

y_pred = gbc.predict(X_test)
accuracy_score(y_test, y_pred)

print('Accuracy of Gradient Booster Classifier on df:', accuracy_score(y_test, y_pred))
# Out:
# Accuracy of Gradient Booster Classifier on df: 0.9104901606321988

# %% [markdown]
# # <b> Gradient Classifier for Data with Demographics

# %%
# gradient booster classifier on df2

gbc_2 = GradientBoostingClassifier(n_estimators=100,learning_rate=1.0, max_depth=1, random_state=1234)
gbc_2.fit(X_train2, y_train2)

y_pred2 = gbc_2.predict(X_test2)
accuracy_score(y_test2, y_pred2)

print('Accuracy of Gradient Booster Classifier on df2:', accuracy_score(y_test2, y_pred2))
# Out:
# Accuracy of Gradient Booster Classifier on df2: 0.9089234371502849

# %% [markdown]
# # <b> Hyperparameter Tuning

# %%
# gridsearchcv on df
from sklearn.model_selection import GridSearchCV

param_grid = {'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.1],
    'max_depth': [3, 4, 5],
    'min_samples_leaf': [1, 2, 4]
}

grid_search = GridSearchCV(GradientBoostingClassifier(random_state=1234), param_grid, cv=3, n_jobs=-1, verbose=3)
grid_search.fit(X_train, y_train)

print('Best parameters for df:', grid_search.best_params_)
print('Best score for df:', grid_search.best_score_)

#Best parameters for df: {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 1, 'n_estimators': 300}
#Best score for df: 0.9304419095119894
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# [CV 3/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=100;, score=0.925 total time=  26.5s
# [CV 1/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=100;, score=0.924 total time=  27.4s
# [CV 1/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, n_estimators=100;, score=0.923 total time=  27.4s
# [CV 2/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=100;, score=0.924 total time=  27.8s
# [CV 2/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, n_estimators=100;, score=0.923 total time=  22.5s
# [CV 2/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=200;, score=0.926 total time=  54.4s
# [CV 1/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=200;, score=0.926 total time=  54.8s
# [CV 3/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=200;, score=0.928 total time=  55.0s
# [CV 3/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, n_estimators=100;, score=0.925 total time=  28.3s
# [CV 1/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=300;, score=0.929 total time= 1.2min
# [CV 2/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=300;, score=0.927 total time= 1.3min
# [CV 3/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=300;, score=0.928 total time= 1.4min
# [CV 2/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, n_estimators=200;, score=0.926 total time=  54.7s
# [CV 1/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, n_estimators=200;, score=0.925 total time=  55.1s
# [CV 1/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, n_estimators=100;, score=0.924 total time=  27.5s
# [CV 3/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, n_estimators=200;, score=0.927 total time=  44.2s
# [CV 2/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, n_estimators=100;, score=0.924 total time=  24.2s
# [CV 3/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, n_estimators=100;, score=0.925 total time=  28.1s
# [CV 3/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, n_estimators=300;, score=0.929 total time= 1.2min
# [CV 1/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, n_estimators=300;, score=0.928 total time= 1.3min
# [CV 2/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, n_estimators=300;, score=0.927 total time= 1.4min
# [CV 1/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=1, n_estimators=100;, score=0.927 total time=  31.5s
# [CV 1/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, n_estimators=200;, score=0.926 total time=  57.2s
# [CV 3/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, n_estimators=200;, score=0.927 total time=  56.7s
# [CV 2/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, n_estimators=200;, score=0.926 total time=  57.1s
# [CV 2/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=1, n_estimators=100;, score=0.927 total time=  32.8s
# [CV 3/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=1, n_estimators=100;, score=0.927 total time=  33.2s
# [CV 2/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, n_estimators=300;, score=0.928 total time= 1.2min
# [CV 1/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, n_estimators=300;, score=0.928 total time= 1.4min
# [CV 3/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, n_estimators=300;, score=0.928 total time= 1.4min
# [CV 1/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=2, n_estimators=100;, score=0.927 total time=  32.1s
# [CV 2/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=2, n_estimators=100;, score=0.926 total time=  37.3s
# [CV 3/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=2, n_estimators=100;, score=0.927 total time=  36.2s
# [CV 3/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=1, n_estimators=200;, score=0.929 total time= 1.1min
# [CV 2/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=1, n_estimators=200;, score=0.928 total time= 1.2min
# [CV 1/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=1, n_estimators=200;, score=0.929 total time= 1.2min
# [CV 1/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=4, n_estimators=100;, score=0.928 total time=  34.9s
# [CV 2/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=1, n_estimators=300;, score=0.929 total time= 1.8min
# [CV 1/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=1, n_estimators=300;, score=0.930 total time= 1.8min
# [CV 1/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=2, n_estimators=200;, score=0.929 total time= 1.2min
# [CV 3/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=1, n_estimators=300;, score=0.931 total time= 1.7min
# [CV 2/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=2, n_estimators=200;, score=0.929 total time= 1.2min
# [CV 3/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=2, n_estimators=200;, score=0.930 total time= 1.2min
# [CV 2/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=4, n_estimators=100;, score=0.927 total time=  36.1s
# [CV 3/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=4, n_estimators=100;, score=0.927 total time=  36.2s
# [CV 2/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=2, n_estimators=300;, score=0.929 total time= 1.7min
# [CV 1/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=2, n_estimators=300;, score=0.931 total time= 1.8min
# [CV 3/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=2, n_estimators=300;, score=0.930 total time= 1.7min
# [CV 1/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=4, n_estimators=200;, score=0.930 total time= 1.2min
# [CV 2/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=4, n_estimators=200;, score=0.928 total time= 1.2min
# [CV 1/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=100;, score=0.929 total time=  44.9s
# [CV 3/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=4, n_estimators=200;, score=0.929 total time= 1.2min
# [CV 2/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=100;, score=0.929 total time=  44.2s
# [CV 3/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=100;, score=0.929 total time=  45.7s
# [CV 1/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=4, n_estimators=300;, score=0.930 total time= 1.8min
# [CV 2/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=4, n_estimators=300;, score=0.929 total time= 1.8min
# [CV 3/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=4, n_estimators=300;, score=0.930 total time= 1.7min
# [CV 1/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=0.929 total time=  43.0s
# [CV 1/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=200;, score=0.930 total time= 1.5min
# [CV 2/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=200;, score=0.929 total time= 1.5min
# [CV 3/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=200;, score=0.931 total time= 1.5min
# [CV 2/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=0.929 total time=  44.4s
# [CV 3/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=0.930 total time=  45.3s
# [CV 1/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=300;, score=0.931 total time= 2.2min
# [CV 1/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, n_estimators=100;, score=0.929 total time=  47.5s
# [CV 2/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=300;, score=0.929 total time= 2.2min
# [CV 1/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, n_estimators=200;, score=0.930 total time= 1.5min
# [CV 3/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=300;, score=0.931 total time= 2.3min
# [CV 2/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, n_estimators=200;, score=0.929 total time= 1.6min
# [CV 3/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, n_estimators=200;, score=0.931 total time= 1.5min
# [CV 2/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, n_estimators=100;, score=0.929 total time=  48.0s
# [CV 3/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, n_estimators=100;, score=0.929 total time=  46.4s
# [CV 1/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, n_estimators=300;, score=0.931 total time= 2.2min
# [CV 2/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, n_estimators=300;, score=0.929 total time= 2.2min
# [CV 3/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, n_estimators=300;, score=0.931 total time= 2.2min
# [CV 1/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, n_estimators=200;, score=0.931 total time= 1.4min
# [CV 2/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, n_estimators=200;, score=0.928 total time= 1.4min
# [CV 3/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, n_estimators=200;, score=0.930 total time= 1.4min
# [CV 1/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, n_estimators=300;, score=0.931 total time= 1.9min
# [CV 2/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, n_estimators=300;, score=0.929 total time= 1.9min
# [CV 3/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, n_estimators=300;, score=0.931 total time= 1.8min
# Best parameters for df: {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 1, 'n_estimators': 300}
# Best score for df: 0.9304419095119894

# %%
# run gridsearch on df2
param_grid = {'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.1],
    'max_depth': [3, 4, 5],
    'min_samples_leaf': [1, 2, 4]
}
grid_search2 = GridSearchCV(GradientBoostingClassifier(random_state=1234), param_grid, cv=3, n_jobs=-1, verbose=3)
grid_search2.fit(X_train2, y_train2)

print('Best parameters for df2:', grid_search2.best_params_)
print('Best score for df2:', grid_search2.best_score_)
# Out:
# Fitting 3 folds for each of 54 candidates, totalling 162 fits
# [CV 2/3] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=100;, score=0.878 total time=  38.1s
# [CV 1/3] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=100;, score=0.880 total time=  38.2s
# [CV 1/3] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=100;, score=0.880 total time=  38.5s
# [CV 3/3] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=100;, score=0.880 total time=  38.7s
# [CV 2/3] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=200;, score=0.891 total time= 1.2min
# [CV 3/3] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=100;, score=0.880 total time=  37.6s
# [CV 1/3] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=200;, score=0.892 total time= 1.3min
# [CV 3/3] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=200;, score=0.891 total time= 1.3min
# [CV 2/3] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=100;, score=0.878 total time=  38.7s
# [CV 3/3] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=300;, score=0.893 total time= 1.8min
# [CV 1/3] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=300;, score=0.897 total time= 1.8min
# [CV 2/3] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, n_estimators=300;, score=0.894 total time= 1.8min
# [CV 2/3] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=200;, score=0.891 total time= 1.2min
# [CV 1/3] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=200;, score=0.892 total time= 1.2min
# [CV 1/3] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=100;, score=0.880 total time=  34.8s
# [CV 2/3] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=100;, score=0.878 total time=  35.7s
# [CV 3/3] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=200;, score=0.891 total time= 1.2min
# [CV 3/3] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=100;, score=0.880 total time=  35.7s
# [CV 1/3] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=200;, score=0.892 total time= 1.2min
# [CV 1/3] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=300;, score=0.900 total time= 1.8min
# [CV 2/3] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=300;, score=0.892 total time= 1.8min
# [CV 3/3] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=200;, score=0.891 total time= 1.2min
# [CV 3/3] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, n_estimators=300;, score=0.893 total time= 1.8min
# [CV 2/3] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=200;, score=0.891 total time= 1.2min
# [CV 1/3] END learning_rate=0.01, max_depth=4, min_samples_leaf=1, n_estimators=100;, score=0.897 total time=  50.4s
# [CV 1/3] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=300;, score=0.900 total time= 1.8min
# [CV 2/3] END learning_rate=0.01, max_depth=4, min_samples_leaf=1, n_estimators=100;, score=0.896 total time=  47.9s
# [CV 3/3] END learning_rate=0.01, max_depth=4, min_samples_leaf=1, n_estimators=100;, score=0.897 total time=  48.4s
# [CV 2/3] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=300;, score=0.892 total time= 1.8min
# [CV 3/3] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, n_estimators=300;, score=0.893 total time= 1.8min
# [CV 1/3] END learning_rate=0.01, max_depth=4, min_samples_leaf=2, n_estimators=100;, score=0.897 total time=  47.9s
# [CV 2/3] END learning_rate=0.01, max_depth=4, min_samples_leaf=2, n_estimators=100;, score=0.896 total time=  46.0s
# [CV 1/3] END learning_rate=0.01, max_depth=4, min_samples_leaf=1, n_estimators=200;, score=0.905 total time= 1.6min
# [CV 2/3] END learning_rate=0.01, max_depth=4, min_samples_leaf=1, n_estimators=200;, score=0.905 total time= 1.6min
# [CV 3/3] END learning_rate=0.01, max_depth=4, min_samples_leaf=1, n_estimators=200;, score=0.905 total time= 1.6min
# [CV 3/3] END learning_rate=0.01, max_depth=4, min_samples_leaf=2, n_estimators=100;, score=0.897 total time=  48.0s
# [CV 1/3] END learning_rate=0.01, max_depth=4, min_samples_leaf=1, n_estimators=300;, score=0.921 total time= 2.4min
# [CV 2/3] END learning_rate=0.01, max_depth=4, min_samples_leaf=1, n_estimators=300;, score=0.919 total time= 2.4min
# [CV 1/3] END learning_rate=0.01, max_depth=4, min_samples_leaf=4, n_estimators=100;, score=0.897 total time=  48.9s
# [CV 1/3] END learning_rate=0.01, max_depth=4, min_samples_leaf=2, n_estimators=200;, score=0.905 total time= 1.7min
# [CV 3/3] END learning_rate=0.01, max_depth=4, min_samples_leaf=1, n_estimators=300;, score=0.918 total time= 2.4min
# [CV 3/3] END learning_rate=0.01, max_depth=4, min_samples_leaf=2, n_estimators=200;, score=0.905 total time= 1.7min
# [CV 2/3] END learning_rate=0.01, max_depth=4, min_samples_leaf=2, n_estimators=200;, score=0.905 total time= 1.7min
# [CV 2/3] END learning_rate=0.01, max_depth=4, min_samples_leaf=4, n_estimators=100;, score=0.896 total time=  48.6s
# [CV 3/3] END learning_rate=0.01, max_depth=4, min_samples_leaf=4, n_estimators=100;, score=0.897 total time=  48.9s
# [CV 1/3] END learning_rate=0.01, max_depth=4, min_samples_leaf=2, n_estimators=300;, score=0.921 total time= 2.5min
# [CV 3/3] END learning_rate=0.01, max_depth=4, min_samples_leaf=2, n_estimators=300;, score=0.918 total time= 2.5min
# [CV 2/3] END learning_rate=0.01, max_depth=4, min_samples_leaf=2, n_estimators=300;, score=0.920 total time= 2.5min
# [CV 1/3] END learning_rate=0.01, max_depth=4, min_samples_leaf=4, n_estimators=200;, score=0.905 total time= 1.7min
# [CV 2/3] END learning_rate=0.01, max_depth=4, min_samples_leaf=4, n_estimators=200;, score=0.905 total time= 1.7min
# [CV 1/3] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=100;, score=0.918 total time= 1.1min
# [CV 3/3] END learning_rate=0.01, max_depth=4, min_samples_leaf=4, n_estimators=200;, score=0.905 total time= 1.7min
# [CV 3/3] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=100;, score=0.919 total time= 1.1min
# [CV 2/3] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=100;, score=0.917 total time= 1.1min
# [CV 1/3] END learning_rate=0.01, max_depth=4, min_samples_leaf=4, n_estimators=300;, score=0.921 total time= 2.6min
# [CV 2/3] END learning_rate=0.01, max_depth=4, min_samples_leaf=4, n_estimators=300;, score=0.919 total time= 2.6min
# [CV 3/3] END learning_rate=0.01, max_depth=4, min_samples_leaf=4, n_estimators=300;, score=0.918 total time= 2.5min
# [CV 1/3] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=200;, score=0.925 total time= 2.1min
# [CV 1/3] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=0.918 total time= 1.1min
# [CV 2/3] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=200;, score=0.925 total time= 2.2min
# [CV 3/3] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=200;, score=0.926 total time= 2.2min
# [CV 3/3] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=0.919 total time= 1.1min
# [CV 2/3] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=0.917 total time= 1.1min
# [CV 1/3] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=300;, score=0.926 total time= 3.3min
# [CV 1/3] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=200;, score=0.925 total time= 2.1min
# [CV 1/3] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=100;, score=0.918 total time= 1.1min
# [CV 2/3] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=300;, score=0.926 total time= 3.2min
# [CV 3/3] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=200;, score=0.926 total time= 2.1min
# [CV 3/3] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, n_estimators=300;, score=0.928 total time= 3.2min
# [CV 2/3] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=200;, score=0.925 total time= 2.1min
# [CV 2/3] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=100;, score=0.917 total time= 1.1min
# [CV 3/3] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=100;, score=0.919 total time= 1.1min
# [CV 1/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=100;, score=0.926 total time=  36.8s
# [CV 1/3] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=300;, score=0.926 total time= 3.2min
# [CV 2/3] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=300;, score=0.926 total time= 3.2min
# [CV 3/3] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, n_estimators=300;, score=0.928 total time= 3.1min
# [CV 1/3] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=200;, score=0.925 total time= 2.1min
# [CV 2/3] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=200;, score=0.925 total time= 2.1min
# [CV 2/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=100;, score=0.925 total time=  36.3s
# [CV 3/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=100;, score=0.927 total time=  36.5s
# [CV 3/3] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=200;, score=0.926 total time= 2.1min
# [CV 1/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, n_estimators=100;, score=0.926 total time=  34.5s
# [CV 1/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=200;, score=0.928 total time= 1.2min
# [CV 2/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=200;, score=0.928 total time= 1.2min
# [CV 3/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=200;, score=0.927 total time= 1.2min
# [CV 1/3] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=300;, score=0.926 total time= 3.1min
# [CV 2/3] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=300;, score=0.926 total time= 3.1min
# [CV 2/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, n_estimators=100;, score=0.925 total time=  36.1s
# [CV 3/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, n_estimators=100;, score=0.927 total time=  35.9s
# [CV 1/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=300;, score=0.930 total time= 1.7min
# [CV 3/3] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, n_estimators=300;, score=0.928 total time= 3.1min
# [CV 2/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=300;, score=0.929 total time= 1.7min
# [CV 3/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, n_estimators=300;, score=0.928 total time= 1.7min
# [CV 1/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, n_estimators=200;, score=0.928 total time= 1.1min
# [CV 1/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, n_estimators=100;, score=0.926 total time=  35.7s
# [CV 2/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, n_estimators=200;, score=0.927 total time= 1.2min
# [CV 2/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, n_estimators=100;, score=0.925 total time=  32.0s
# [CV 3/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, n_estimators=100;, score=0.927 total time=  32.8s
# [CV 3/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, n_estimators=200;, score=0.931 total time= 1.2min
# [CV 1/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, n_estimators=300;, score=0.930 total time= 1.7min
# [CV 3/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, n_estimators=300;, score=0.931 total time= 1.6min
# [CV 1/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, n_estimators=200;, score=0.928 total time= 1.2min
# [CV 2/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, n_estimators=300;, score=0.928 total time= 1.7min
# [CV 1/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=1, n_estimators=100;, score=0.928 total time=  48.4s
# [CV 2/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, n_estimators=200;, score=0.928 total time= 1.2min
# [CV 3/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, n_estimators=200;, score=0.930 total time= 1.2min
# [CV 3/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=1, n_estimators=100;, score=0.931 total time=  43.8s
# [CV 2/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=1, n_estimators=100;, score=0.928 total time=  49.0s
# [CV 1/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, n_estimators=300;, score=0.930 total time= 1.8min
# [CV 2/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, n_estimators=300;, score=0.928 total time= 1.8min
# [CV 3/3] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, n_estimators=300;, score=0.931 total time= 1.8min
# [CV 1/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=1, n_estimators=200;, score=0.931 total time= 1.4min
# [CV 1/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=2, n_estimators=100;, score=0.929 total time=  46.8s
# [CV 2/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=1, n_estimators=200;, score=0.929 total time= 1.5min
# [CV 3/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=1, n_estimators=200;, score=0.933 total time= 1.5min
# [CV 2/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=2, n_estimators=100;, score=0.928 total time=  44.5s
# [CV 3/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=2, n_estimators=100;, score=0.930 total time=  46.4s
# [CV 1/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=1, n_estimators=300;, score=0.932 total time= 2.2min
# [CV 1/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=2, n_estimators=200;, score=0.931 total time= 1.5min
# [CV 1/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=4, n_estimators=100;, score=0.928 total time=  45.6s
# [CV 2/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=1, n_estimators=300;, score=0.930 total time= 2.3min
# [CV 3/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=2, n_estimators=200;, score=0.932 total time= 1.5min
# [CV 3/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=1, n_estimators=300;, score=0.934 total time= 2.3min
# [CV 2/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=2, n_estimators=200;, score=0.930 total time= 1.6min
# [CV 2/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=4, n_estimators=100;, score=0.928 total time=  44.5s
# [CV 3/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=4, n_estimators=100;, score=0.930 total time=  44.5s
# [CV 3/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=2, n_estimators=300;, score=0.934 total time= 2.1min
# [CV 1/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=2, n_estimators=300;, score=0.933 total time= 2.2min
# [CV 2/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=2, n_estimators=300;, score=0.930 total time= 2.2min
# [CV 1/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=4, n_estimators=200;, score=0.931 total time= 1.5min
# [CV 2/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=4, n_estimators=200;, score=0.929 total time= 1.5min
# [CV 1/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=100;, score=0.931 total time=  54.6s
# [CV 3/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=4, n_estimators=200;, score=0.933 total time= 1.5min
# [CV 3/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=100;, score=0.933 total time=  56.1s
# [CV 2/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=100;, score=0.929 total time=  57.8s
# [CV 1/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=4, n_estimators=300;, score=0.933 total time= 2.2min
# [CV 2/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=4, n_estimators=300;, score=0.930 total time= 2.2min
# [CV 3/3] END learning_rate=0.1, max_depth=4, min_samples_leaf=4, n_estimators=300;, score=0.934 total time= 2.2min
# [CV 1/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=0.931 total time=  53.4s
# [CV 1/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=200;, score=0.932 total time= 1.9min
# [CV 2/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=200;, score=0.931 total time= 1.8min
# [CV 3/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=200;, score=0.933 total time= 1.8min
# [CV 2/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=0.929 total time=  54.6s
# [CV 3/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, n_estimators=100;, score=0.932 total time=  57.1s
# [CV 1/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=300;, score=0.933 total time= 2.7min
# [CV 1/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, n_estimators=100;, score=0.931 total time=  54.6s
# [CV 2/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=300;, score=0.931 total time= 2.8min
# [CV 1/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, n_estimators=200;, score=0.933 total time= 1.9min
# [CV 2/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, n_estimators=200;, score=0.930 total time= 1.8min
# [CV 3/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, n_estimators=300;, score=0.934 total time= 2.7min
# [CV 3/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, n_estimators=200;, score=0.934 total time= 1.8min
# [CV 2/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, n_estimators=100;, score=0.929 total time=  53.9s
# [CV 3/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, n_estimators=100;, score=0.933 total time=  55.9s
# [CV 1/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, n_estimators=300;, score=0.934 total time= 2.8min
# [CV 2/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, n_estimators=300;, score=0.931 total time= 2.7min
# [CV 3/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, n_estimators=300;, score=0.934 total time= 2.7min
# [CV 1/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, n_estimators=200;, score=0.933 total time= 1.7min
# [CV 2/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, n_estimators=200;, score=0.931 total time= 1.7min
# [CV 3/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, n_estimators=200;, score=0.934 total time= 1.7min
# [CV 1/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, n_estimators=300;, score=0.933 total time= 2.4min
# [CV 2/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, n_estimators=300;, score=0.931 total time= 2.3min
# [CV 3/3] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, n_estimators=300;, score=0.935 total time= 2.3min
# Best parameters for df2: {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 4, 'n_estimators': 300}
# Best score for df2: 0.9329875375285175

# %% [markdown]
# # <b> Analysis, Accuracy, and Metrics

# %%
# check mse
from sklearn.metrics import mean_squared_error

gbc_best = GradientBoostingClassifier(n_estimators=300, learning_rate=0.1, max_depth=5, min_samples_leaf=1, random_state=1234)
gbc_best.fit(X_train, y_train)

y_pred_best = gbc_best.predict(X_test)
mean_squared_error(y_test, y_pred_best)

print('Mean Squared Error for df:', mean_squared_error(y_test, y_pred_best))
# Out:
# Mean Squared Error for df: 0.07354991994215175

# %%
# print classification report on df with best model
from sklearn.metrics import classification_report

best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92     24823
#            1       0.96      0.92      0.94     32721
#            2       0.94      0.86      0.90       539
#
#     accuracy                           0.93     58083
#    macro avg       0.93      0.91      0.92     58083
# weighted avg       0.93      0.93      0.93     58083

# %%
# Generate classification report
report = classification_report(y_test, y_pred, digits=2, output_dict=True)
df = pd.DataFrame(report).T

# Convert support column to integer
df['support'] = df['support'].apply(int)

# Apply background gradient
styled_df = df.style.background_gradient(cmap='viridis', subset=pd.IndexSlice['0':'9', :'f1-score'])

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_028ef_row0_col0, #T_028ef_row2_col1, #T_028ef_row2_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_028ef_row0_col1, #T_028ef_row1_col0, #T_028ef_row1_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_028ef_row0_col2 {
#   background-color: #1f9a8a;
#   color: #f1f1f1;
# }
# #T_028ef_row1_col1 {
#   background-color: #25ab82;
#   color: #f1f1f1;
# }
# #T_028ef_row2_col0 {
#   background-color: #54c568;
#   color: #000000;
# }
# </style>
# <table id="T_028ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_028ef_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_028ef_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_028ef_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_028ef_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_028ef_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_028ef_row0_col0" class="data row0 col0" >0.894910</td>
#       <td id="T_028ef_row0_col1" class="data row0 col1" >0.950610</td>
#       <td id="T_028ef_row0_col2" class="data row0 col2" >0.921920</td>
#       <td id="T_028ef_row0_col3" class="data row0 col3" >24823</td>
#     </tr>
#     <tr>
#       <th id="T_028ef_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_028ef_row1_col0" class="data row1 col0" >0.961180</td>
#       <td id="T_028ef_row1_col1" class="data row1 col1" >0.917117</td>
#       <td id="T_028ef_row1_col2" class="data row1 col2" >0.938632</td>
#       <td id="T_028ef_row1_col3" class="data row1 col3" >32721</td>
#     </tr>
#     <tr>
#       <th id="T_028ef_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_028ef_row2_col0" class="data row2 col0" >0.943320</td>
#       <td id="T_028ef_row2_col1" class="data row2 col1" >0.864564</td>
#       <td id="T_028ef_row2_col2" class="data row2 col2" >0.902227</td>
#       <td id="T_028ef_row2_col3" class="data row2 col3" >539</td>
#     </tr>
#     <tr>
#       <th id="T_028ef_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_028ef_row3_col0" class="data row3 col0" >0.930944</td>
#       <td id="T_028ef_row3_col1" class="data row3 col1" >0.930944</td>
#       <td id="T_028ef_row3_col2" class="data row3 col2" >0.930944</td>
#       <td id="T_028ef_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_028ef_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_028ef_row4_col0" class="data row4 col0" >0.933137</td>
#       <td id="T_028ef_row4_col1" class="data row4 col1" >0.910764</td>
#       <td id="T_028ef_row4_col2" class="data row4 col2" >0.920926</td>
#       <td id="T_028ef_row4_col3" class="data row4 col3" >58083</td>
#     </tr>
#     <tr>
#       <th id="T_028ef_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_028ef_row5_col0" class="data row5 col0" >0.932693</td>
#       <td id="T_028ef_row5_col1" class="data row5 col1" >0.930944</td>
#       <td id="T_028ef_row5_col2" class="data row5 col2" >0.931152</td>
#       <td id="T_028ef_row5_col3" class="data row5 col3" >58083</td>
#     </tr>
#   </tbody>
# </table>

# %%
# generate classification report on df2 with best model
best_model2 = grid_search2.best_estimator_
y_pred2 = best_model2.predict(X_test2)
print(classification_report(y_test2, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.93     24823
#            1       0.96      0.93      0.94     32721
#            2       0.96      0.86      0.91       539
#
#     accuracy                           0.93     58083
#    macro avg       0.94      0.91      0.93     58083
# weighted avg       0.94      0.93      0.93     58083

# %%
# Generate classification report
report = classification_report(y_test2, y_pred2, digits=2, output_dict=True)
df = pd.DataFrame(report).T

# Convert support column to integer
df['support'] = df['support'].apply(int)

# Apply background gradient
styled_df = df.style.background_gradient(cmap='viridis', subset=pd.IndexSlice['0':'9', :'f1-score'])

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_29746_row0_col0, #T_29746_row2_col1, #T_29746_row2_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_29746_row0_col1, #T_29746_row1_col2, #T_29746_row2_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_29746_row0_col2 {
#   background-color: #228c8d;
#   color: #f1f1f1;
# }
# #T_29746_row1_col0 {
#   background-color: #dae319;
#   color: #000000;
# }
# #T_29746_row1_col1 {
#   background-color: #58c765;
#   color: #000000;
# }
# </style>
# <table id="T_29746">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29746_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_29746_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_29746_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_29746_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29746_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_29746_row0_col0" class="data row0 col0" >0.904030</td>
#       <td id="T_29746_row0_col1" class="data row0 col1" >0.947951</td>
#       <td id="T_29746_row0_col2" class="data row0 col2" >0.925470</td>
#       <td id="T_29746_row0_col3" class="data row0 col3" >24823</td>
#     </tr>
#     <tr>
#       <th id="T_29746_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_29746_row1_col0" class="data row1 col0" >0.959361</td>
#       <td id="T_29746_row1_col1" class="data row1 col1" >0.925644</td>
#       <td id="T_29746_row1_col2" class="data row1 col2" >0.942201</td>
#       <td id="T_29746_row1_col3" class="data row1 col3" >32721</td>
#     </tr>
#     <tr>
#       <th id="T_29746_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_29746_row2_col0" class="data row2 col0" >0.962733</td>
#       <td id="T_29746_row2_col1" class="data row2 col1" >0.862709</td>
#       <td id="T_29746_row2_col2" class="data row2 col2" >0.909980</td>
#       <td id="T_29746_row2_col3" class="data row2 col3" >539</td>
#     </tr>
#     <tr>
#       <th id="T_29746_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_29746_row3_col0" class="data row3 col0" >0.934594</td>
#       <td id="T_29746_row3_col1" class="data row3 col1" >0.934594</td>
#       <td id="T_29746_row3_col2" class="data row3 col2" >0.934594</td>
#       <td id="T_29746_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_29746_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_29746_row4_col0" class="data row4 col0" >0.942041</td>
#       <td id="T_29746_row4_col1" class="data row4 col1" >0.912101</td>
#       <td id="T_29746_row4_col2" class="data row4 col2" >0.925884</td>
#       <td id="T_29746_row4_col3" class="data row4 col3" >58083</td>
#     </tr>
#     <tr>
#       <th id="T_29746_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_29746_row5_col0" class="data row5 col0" >0.935746</td>
#       <td id="T_29746_row5_col1" class="data row5 col1" >0.934594</td>
#       <td id="T_29746_row5_col2" class="data row5 col2" >0.934752</td>
#       <td id="T_29746_row5_col3" class="data row5 col3" >58083</td>
#     </tr>
#   </tbody>
# </table>
