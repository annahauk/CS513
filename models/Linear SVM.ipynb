# %% [markdown]
# # <b> Linear SVM Model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os

df = pd.read_csv(os.path.join('NYPD_Arrest_Data_Clean.csv'))
df2 = pd.read_csv(os.path.join('NYPD_Arrest_Data_Clean_Demographics.csv'))

# %%
df
# Out:
#         OFNS_DESC  OFFENSE_LEVEL  ARREST_PRECINCT  JURISDICTION_CODE  \
# 0              17              0              105                  0
# 1               4              0              107                 71
# 2              17              0               48                  0
# 3              17              0              121                  0
# 4              17              0              100                  0
# ...           ...            ...              ...                ...
# 193605         47              1              109                  0
# 193606          5              1               34                  0
# 193607          7              0               23                  0
# 193608         43              1               44                  1
# 193609         13              0               46                  0
#
#          Latitude  Longitude  MONTH   FALL  SPRING  SUMMER  WINTER  BRONX  \
# 0       40.737043 -73.735514      1  False   False   False    True  False
# 1       40.732881 -73.807899      2  False   False   False    True  False
# 2       40.855109 -73.892818      3  False    True   False   False   True
# 3       40.628967 -74.163275      5  False    True   False   False  False
# 4       40.591980 -73.800066      6  False   False    True   False  False
# ...           ...        ...    ...    ...     ...     ...     ...    ...
# 193605  40.757691 -73.834115      9   True   False   False   False  False
# 193606  40.856808 -73.928265      9   True   False   False   False  False
# 193607  40.786116 -73.942614      9   True   False   False   False  False
# 193608  40.827812 -73.925929      9   True   False   False   False   True
# 193609  40.854588 -73.901861      9   True   False   False   False   True
#
#         BROOKLYN  MANHATTAN  QUEENS  STATEN_ISLAND
# 0          False      False    True          False
# 1          False      False    True          False
# 2          False      False   False          False
# 3          False      False   False           True
# 4          False      False    True          False
# ...          ...        ...     ...            ...
# 193605     False      False    True          False
# 193606     False       True   False          False
# 193607     False       True   False          False
# 193608     False      False   False          False
# 193609     False      False   False          False
#
# [193610 rows x 16 columns]

# %%
df2
# Out:
#         OFNS_DESC  OFFENSE_LEVEL  ARREST_PRECINCT  JURISDICTION_CODE  \
# 0              17              0              105                  0
# 1               4              0              107                 71
# 2              17              0               48                  0
# 3              17              0              121                  0
# 4              17              0              100                  0
# ...           ...            ...              ...                ...
# 193605         47              1              109                  0
# 193606          5              1               34                  0
# 193607          7              0               23                  0
# 193608         43              1               44                  1
# 193609         13              0               46                  0
#
#          Latitude  Longitude  MONTH   FALL  SPRING  SUMMER  ...  \
# 0       40.737043 -73.735514      1  False   False   False  ...
# 1       40.732881 -73.807899      2  False   False   False  ...
# 2       40.855109 -73.892818      3  False    True   False  ...
# 3       40.628967 -74.163275      5  False    True   False  ...
# 4       40.591980 -73.800066      6  False   False    True  ...
# ...           ...        ...    ...    ...     ...     ...  ...
# 193605  40.757691 -73.834115      9   True   False   False  ...
# 193606  40.856808 -73.928265      9   True   False   False  ...
# 193607  40.786116 -73.942614      9   True   False   False  ...
# 193608  40.827812 -73.925929      9   True   False   False  ...
# 193609  40.854588 -73.901861      9   True   False   False  ...
#
#         AGE_GROUP_<18  PERP_SEX_F  PERP_SEX_M  \
# 0               False       False        True
# 1               False       False        True
# 2               False       False        True
# 3               False       False        True
# 4               False       False        True
# ...               ...         ...         ...
# 193605          False       False        True
# 193606          False       False        True
# 193607          False       False        True
# 193608          False       False        True
# 193609          False       False        True
#
#         PERP_RACE_AMERICAN INDIAN/ALASKAN NATIVE  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ...                                          ...
# 193605                                     False
# 193606                                     False
# 193607                                     False
# 193608                                     False
# 193609                                     False
#
#         PERP_RACE_ASIAN / PACIFIC ISLANDER  PERP_RACE_BLACK  \
# 0                                    False            False
# 1                                    False            False
# 2                                    False             True
# 3                                    False            False
# 4                                    False             True
# ...                                    ...              ...
# 193605                               False            False
# 193606                               False            False
# 193607                               False            False
# 193608                               False             True
# 193609                               False            False
#
#         PERP_RACE_BLACK HISPANIC  PERP_RACE_UNKNOWN  PERP_RACE_WHITE  \
# 0                          False              False             True
# 1                          False              False             True
# 2                          False              False            False
# 3                          False              False             True
# 4                          False              False            False
# ...                          ...                ...              ...
# 193605                     False              False            False
# 193606                     False              False            False
# 193607                     False              False             True
# 193608                     False              False            False
# 193609                      True              False            False
#
#         PERP_RACE_WHITE HISPANIC
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# ...                          ...
# 193605                      True
# 193606                      True
# 193607                     False
# 193608                     False
# 193609                     False
#
# [193610 rows x 30 columns]

# %%
from sklearn.model_selection import train_test_split

X = df.drop(columns='OFFENSE_LEVEL')
y = df['OFFENSE_LEVEL']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

X2 = df2.drop(columns='OFFENSE_LEVEL')
y2 = df2['OFFENSE_LEVEL']

X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size=0.3, random_state=1234)

# %% [markdown]
# # <b> Linear SVM for Data without Demographics

# %%
# run linear SVC on df
from sklearn.metrics import accuracy_score
from sklearn.svm import LinearSVC

model = LinearSVC()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
accuracy_score(y_test, y_pred)

print('Accuracy:', accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.461804658850266

# %% [markdown]
# # <b> Linear SVM for Data with Demographics

# %%
# run linear SVC on df2
model2 = LinearSVC()
model2.fit(X_train2, y_train2)
y_pred2 = model2.predict(X_test2)
accuracy_score(y_test2, y_pred2)

print('Accuracy:', accuracy_score(y_test2, y_pred2))
# Out:
# Accuracy: 0.5534838076545633

# %% [markdown]
# # <b> Analysis, Accuracy, and Metrics

# %%
# print classification report for df and df2
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
print(classification_report(y_test2, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.27      0.14      0.19     24823
#            1       0.52      0.71      0.60     32721
#            2       0.00      0.00      0.00       539
#
#     accuracy                           0.46     58083
#    macro avg       0.26      0.28      0.26     58083
# weighted avg       0.41      0.46      0.42     58083
#
#               precision    recall  f1-score   support
#
#            0       0.48      0.27      0.34     24823
#            1       0.58      0.78      0.66     32721
#            2       0.00      0.00      0.00       539
#
#     accuracy                           0.55     58083
#    macro avg       0.35      0.35      0.34     58083
# weighted avg       0.53      0.55      0.52     58083
# /Users/annahauk/Desktop/CS513/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/annahauk/Desktop/CS513/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/annahauk/Desktop/CS513/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/annahauk/Desktop/CS513/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/annahauk/Desktop/CS513/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/annahauk/Desktop/CS513/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Generate classification report
report = classification_report(y_test, y_pred, digits=2, output_dict=True)
df = pd.DataFrame(report).T

# Convert support column to integer
df['support'] = df['support'].apply(int)

# Apply background gradient
styled_df = df.style.background_gradient(cmap='viridis', subset=pd.IndexSlice['0':'9', :'f1-score'])

# Display the styled DataFrame
styled_df
# Out:
# /Users/annahauk/Desktop/CS513/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/annahauk/Desktop/CS513/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/annahauk/Desktop/CS513/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# <style type="text/css">
# #T_7cf31_row0_col0 {
#   background-color: #1f978b;
#   color: #f1f1f1;
# }
# #T_7cf31_row0_col1 {
#   background-color: #404588;
#   color: #f1f1f1;
# }
# #T_7cf31_row0_col2 {
#   background-color: #32648e;
#   color: #f1f1f1;
# }
# #T_7cf31_row1_col0, #T_7cf31_row1_col1, #T_7cf31_row1_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_7cf31_row2_col0, #T_7cf31_row2_col1, #T_7cf31_row2_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7cf31">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7cf31_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_7cf31_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_7cf31_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_7cf31_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7cf31_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7cf31_row0_col0" class="data row0 col0" >0.273829</td>
#       <td id="T_7cf31_row0_col1" class="data row0 col1" >0.144664</td>
#       <td id="T_7cf31_row0_col2" class="data row0 col2" >0.189314</td>
#       <td id="T_7cf31_row0_col3" class="data row0 col3" >24823</td>
#     </tr>
#     <tr>
#       <th id="T_7cf31_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7cf31_row1_col0" class="data row1 col0" >0.516623</td>
#       <td id="T_7cf31_row1_col1" class="data row1 col1" >0.710003</td>
#       <td id="T_7cf31_row1_col2" class="data row1 col2" >0.598069</td>
#       <td id="T_7cf31_row1_col3" class="data row1 col3" >32721</td>
#     </tr>
#     <tr>
#       <th id="T_7cf31_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7cf31_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_7cf31_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_7cf31_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_7cf31_row2_col3" class="data row2 col3" >539</td>
#     </tr>
#     <tr>
#       <th id="T_7cf31_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_7cf31_row3_col0" class="data row3 col0" >0.461805</td>
#       <td id="T_7cf31_row3_col1" class="data row3 col1" >0.461805</td>
#       <td id="T_7cf31_row3_col2" class="data row3 col2" >0.461805</td>
#       <td id="T_7cf31_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7cf31_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_7cf31_row4_col0" class="data row4 col0" >0.263484</td>
#       <td id="T_7cf31_row4_col1" class="data row4 col1" >0.284889</td>
#       <td id="T_7cf31_row4_col2" class="data row4 col2" >0.262461</td>
#       <td id="T_7cf31_row4_col3" class="data row4 col3" >58083</td>
#     </tr>
#     <tr>
#       <th id="T_7cf31_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_7cf31_row5_col0" class="data row5 col0" >0.408066</td>
#       <td id="T_7cf31_row5_col1" class="data row5 col1" >0.461805</td>
#       <td id="T_7cf31_row5_col2" class="data row5 col2" >0.417829</td>
#       <td id="T_7cf31_row5_col3" class="data row5 col3" >58083</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Generate classification report
report2 = classification_report(y_test2, y_pred2, digits=2, output_dict=True)
df2 = pd.DataFrame(report2).T

# Convert support column to integer
df2['support'] = df2['support'].apply(int)

# Apply background gradient
styled_df2 = df2.style.background_gradient(cmap='viridis', subset=pd.IndexSlice['0':'9', :'f1-score'])

# Display the styled DataFrame
styled_df2
# Out:
# /Users/annahauk/Desktop/CS513/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/annahauk/Desktop/CS513/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/annahauk/Desktop/CS513/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# <style type="text/css">
# #T_3c754_row0_col0 {
#   background-color: #8ed645;
#   color: #000000;
# }
# #T_3c754_row0_col1 {
#   background-color: #306a8e;
#   color: #f1f1f1;
# }
# #T_3c754_row0_col2 {
#   background-color: #20938c;
#   color: #f1f1f1;
# }
# #T_3c754_row1_col0, #T_3c754_row1_col1, #T_3c754_row1_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_3c754_row2_col0, #T_3c754_row2_col1, #T_3c754_row2_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3c754">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c754_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_3c754_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_3c754_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_3c754_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c754_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3c754_row0_col0" class="data row0 col0" >0.477977</td>
#       <td id="T_3c754_row0_col1" class="data row0 col1" >0.265802</td>
#       <td id="T_3c754_row0_col2" class="data row0 col2" >0.341626</td>
#       <td id="T_3c754_row0_col3" class="data row0 col3" >24823</td>
#     </tr>
#     <tr>
#       <th id="T_3c754_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3c754_row1_col0" class="data row1 col0" >0.577023</td>
#       <td id="T_3c754_row1_col1" class="data row1 col1" >0.780844</td>
#       <td id="T_3c754_row1_col2" class="data row1 col2" >0.663636</td>
#       <td id="T_3c754_row1_col3" class="data row1 col3" >32721</td>
#     </tr>
#     <tr>
#       <th id="T_3c754_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3c754_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_3c754_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_3c754_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_3c754_row2_col3" class="data row2 col3" >539</td>
#     </tr>
#     <tr>
#       <th id="T_3c754_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_3c754_row3_col0" class="data row3 col0" >0.553484</td>
#       <td id="T_3c754_row3_col1" class="data row3 col1" >0.553484</td>
#       <td id="T_3c754_row3_col2" class="data row3 col2" >0.553484</td>
#       <td id="T_3c754_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_3c754_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_3c754_row4_col0" class="data row4 col0" >0.351667</td>
#       <td id="T_3c754_row4_col1" class="data row4 col1" >0.348882</td>
#       <td id="T_3c754_row4_col2" class="data row4 col2" >0.335088</td>
#       <td id="T_3c754_row4_col3" class="data row4 col3" >58083</td>
#     </tr>
#     <tr>
#       <th id="T_3c754_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_3c754_row5_col0" class="data row5 col0" >0.529339</td>
#       <td id="T_3c754_row5_col1" class="data row5 col1" >0.553484</td>
#       <td id="T_3c754_row5_col2" class="data row5 col2" >0.519860</td>
#       <td id="T_3c754_row5_col3" class="data row5 col3" >58083</td>
#     </tr>
#   </tbody>
# </table>
