# %% [markdown]
# # <b> Bagging Classifier Model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os

df = pd.read_csv(os.path.join('NYPD_Arrest_Data_Clean.csv'))
df2 = pd.read_csv(os.path.join('NYPD_Arrest_Data_Clean_Demographics.csv'))

# %%
df
# Out:
#         OFNS_DESC  OFFENSE_LEVEL  ARREST_PRECINCT  JURISDICTION_CODE  \
# 0              17              0              105                  0
# 1               4              0              107                 71
# 2              17              0               48                  0
# 3              17              0              121                  0
# 4              17              0              100                  0
# ...           ...            ...              ...                ...
# 193605         47              1              109                  0
# 193606          5              1               34                  0
# 193607          7              0               23                  0
# 193608         43              1               44                  1
# 193609         13              0               46                  0
#
#          Latitude  Longitude  MONTH   FALL  SPRING  SUMMER  WINTER  BRONX  \
# 0       40.737043 -73.735514      1  False   False   False    True  False
# 1       40.732881 -73.807899      2  False   False   False    True  False
# 2       40.855109 -73.892818      3  False    True   False   False   True
# 3       40.628967 -74.163275      5  False    True   False   False  False
# 4       40.591980 -73.800066      6  False   False    True   False  False
# ...           ...        ...    ...    ...     ...     ...     ...    ...
# 193605  40.757691 -73.834115      9   True   False   False   False  False
# 193606  40.856808 -73.928265      9   True   False   False   False  False
# 193607  40.786116 -73.942614      9   True   False   False   False  False
# 193608  40.827812 -73.925929      9   True   False   False   False   True
# 193609  40.854588 -73.901861      9   True   False   False   False   True
#
#         BROOKLYN  MANHATTAN  QUEENS  STATEN_ISLAND
# 0          False      False    True          False
# 1          False      False    True          False
# 2          False      False   False          False
# 3          False      False   False           True
# 4          False      False    True          False
# ...          ...        ...     ...            ...
# 193605     False      False    True          False
# 193606     False       True   False          False
# 193607     False       True   False          False
# 193608     False      False   False          False
# 193609     False      False   False          False
#
# [193610 rows x 16 columns]

# %%
df2
# Out:
#         OFNS_DESC  OFFENSE_LEVEL  ARREST_PRECINCT  JURISDICTION_CODE  \
# 0              17              0              105                  0
# 1               4              0              107                 71
# 2              17              0               48                  0
# 3              17              0              121                  0
# 4              17              0              100                  0
# ...           ...            ...              ...                ...
# 193605         47              1              109                  0
# 193606          5              1               34                  0
# 193607          7              0               23                  0
# 193608         43              1               44                  1
# 193609         13              0               46                  0
#
#          Latitude  Longitude  MONTH   FALL  SPRING  SUMMER  ...  \
# 0       40.737043 -73.735514      1  False   False   False  ...
# 1       40.732881 -73.807899      2  False   False   False  ...
# 2       40.855109 -73.892818      3  False    True   False  ...
# 3       40.628967 -74.163275      5  False    True   False  ...
# 4       40.591980 -73.800066      6  False   False    True  ...
# ...           ...        ...    ...    ...     ...     ...  ...
# 193605  40.757691 -73.834115      9   True   False   False  ...
# 193606  40.856808 -73.928265      9   True   False   False  ...
# 193607  40.786116 -73.942614      9   True   False   False  ...
# 193608  40.827812 -73.925929      9   True   False   False  ...
# 193609  40.854588 -73.901861      9   True   False   False  ...
#
#         AGE_GROUP_<18  PERP_SEX_F  PERP_SEX_M  \
# 0               False       False        True
# 1               False       False        True
# 2               False       False        True
# 3               False       False        True
# 4               False       False        True
# ...               ...         ...         ...
# 193605          False       False        True
# 193606          False       False        True
# 193607          False       False        True
# 193608          False       False        True
# 193609          False       False        True
#
#         PERP_RACE_AMERICAN INDIAN/ALASKAN NATIVE  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ...                                          ...
# 193605                                     False
# 193606                                     False
# 193607                                     False
# 193608                                     False
# 193609                                     False
#
#         PERP_RACE_ASIAN / PACIFIC ISLANDER  PERP_RACE_BLACK  \
# 0                                    False            False
# 1                                    False            False
# 2                                    False             True
# 3                                    False            False
# 4                                    False             True
# ...                                    ...              ...
# 193605                               False            False
# 193606                               False            False
# 193607                               False            False
# 193608                               False             True
# 193609                               False            False
#
#         PERP_RACE_BLACK HISPANIC  PERP_RACE_UNKNOWN  PERP_RACE_WHITE  \
# 0                          False              False             True
# 1                          False              False             True
# 2                          False              False            False
# 3                          False              False             True
# 4                          False              False            False
# ...                          ...                ...              ...
# 193605                     False              False            False
# 193606                     False              False            False
# 193607                     False              False             True
# 193608                     False              False            False
# 193609                      True              False            False
#
#         PERP_RACE_WHITE HISPANIC
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# ...                          ...
# 193605                      True
# 193606                      True
# 193607                     False
# 193608                     False
# 193609                     False
#
# [193610 rows x 30 columns]

# %%
from sklearn.model_selection import train_test_split

X = df.drop(columns='OFFENSE_LEVEL')
y = df['OFFENSE_LEVEL']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

X2 = df2.drop(columns='OFFENSE_LEVEL')
y2 = df2['OFFENSE_LEVEL']

X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size=0.3, random_state=1234)

# %% [markdown]
# # <b> Histogram Gradient Classifier for Data without Demographics

# %%
# bagging classifier on df
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier

bag = BaggingClassifier(n_estimators=100, random_state=1234)
bag.fit(X_train, y_train)
y_pred = bag.predict(X_test)

accuracy_score(y_test, y_pred)

print('Accuracy: {:.4f}'.format(accuracy_score(y_test, y_pred)))
# Out:
# Accuracy: 0.9328

# %% [markdown]
# # <b> Bagging Classifier for Data with Demographics

# %%
# run bagging classifier on df2
bag2 = BaggingClassifier(n_estimators=100, random_state=1234)
bag2.fit(X_train2, y_train2)
y_pred2 = bag2.predict(X_test2)

accuracy_score(y_test2, y_pred2)

print('Accuracy: {:.4f}'.format(accuracy_score(y_test2, y_pred2)))
# Out:
# Accuracy: 0.9320

# %% [markdown]
# # <b> Hyperparameter Tuning

# %%
# run gridsearch on df for bagging classifier
from sklearn.model_selection import GridSearchCV

param_grid = {'n_estimators': [50, 100, 200, 300, 400, 500],
              'max_samples': [0.1, 0.5, 1.0]}
grid = GridSearchCV(BaggingClassifier(random_state=1234), param_grid, cv=5, verbose=3)
grid.fit(X_train, y_train)

print('Best parameters: {}'.format(grid.best_params_))
print('Best cross-validation: {:.4f}'.format(grid.best_score_))
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5] END ..max_samples=0.1, n_estimators=50;, score=0.928 total time=   1.4s
# [CV 2/5] END ..max_samples=0.1, n_estimators=50;, score=0.932 total time=   1.3s
# [CV 3/5] END ..max_samples=0.1, n_estimators=50;, score=0.931 total time=   1.3s
# [CV 4/5] END ..max_samples=0.1, n_estimators=50;, score=0.932 total time=   1.3s
# [CV 5/5] END ..max_samples=0.1, n_estimators=50;, score=0.932 total time=   1.3s
# [CV 1/5] END .max_samples=0.1, n_estimators=100;, score=0.929 total time=   2.6s
# [CV 2/5] END .max_samples=0.1, n_estimators=100;, score=0.932 total time=   2.6s
# [CV 3/5] END .max_samples=0.1, n_estimators=100;, score=0.931 total time=   2.6s
# [CV 4/5] END .max_samples=0.1, n_estimators=100;, score=0.932 total time=   2.6s
# [CV 5/5] END .max_samples=0.1, n_estimators=100;, score=0.933 total time=   2.6s
# [CV 1/5] END .max_samples=0.1, n_estimators=200;, score=0.931 total time=   5.2s
# [CV 2/5] END .max_samples=0.1, n_estimators=200;, score=0.932 total time=   5.2s
# [CV 3/5] END .max_samples=0.1, n_estimators=200;, score=0.932 total time=   5.2s
# [CV 4/5] END .max_samples=0.1, n_estimators=200;, score=0.933 total time=   5.2s
# [CV 5/5] END .max_samples=0.1, n_estimators=200;, score=0.933 total time=   5.2s
# [CV 1/5] END .max_samples=0.1, n_estimators=300;, score=0.931 total time=   8.1s
# [CV 2/5] END .max_samples=0.1, n_estimators=300;, score=0.933 total time=   8.0s
# [CV 3/5] END .max_samples=0.1, n_estimators=300;, score=0.932 total time=   8.4s
# [CV 4/5] END .max_samples=0.1, n_estimators=300;, score=0.933 total time=   8.3s
# [CV 5/5] END .max_samples=0.1, n_estimators=300;, score=0.933 total time=   8.1s
# [CV 1/5] END .max_samples=0.1, n_estimators=400;, score=0.931 total time=  10.7s
# [CV 2/5] END .max_samples=0.1, n_estimators=400;, score=0.933 total time=  10.8s
# [CV 3/5] END .max_samples=0.1, n_estimators=400;, score=0.932 total time=  10.7s
# [CV 4/5] END .max_samples=0.1, n_estimators=400;, score=0.932 total time=  10.7s
# [CV 5/5] END .max_samples=0.1, n_estimators=400;, score=0.933 total time=  10.8s
# [CV 1/5] END .max_samples=0.1, n_estimators=500;, score=0.931 total time=  13.6s
# [CV 2/5] END .max_samples=0.1, n_estimators=500;, score=0.933 total time=  13.3s
# [CV 3/5] END .max_samples=0.1, n_estimators=500;, score=0.932 total time=  13.0s
# [CV 4/5] END .max_samples=0.1, n_estimators=500;, score=0.932 total time=  13.4s
# [CV 5/5] END .max_samples=0.1, n_estimators=500;, score=0.932 total time=  13.2s
# [CV 1/5] END ..max_samples=0.5, n_estimators=50;, score=0.931 total time=   4.9s
# [CV 2/5] END ..max_samples=0.5, n_estimators=50;, score=0.932 total time=   5.0s
# [CV 3/5] END ..max_samples=0.5, n_estimators=50;, score=0.931 total time=   4.9s
# [CV 4/5] END ..max_samples=0.5, n_estimators=50;, score=0.932 total time=   4.9s
# [CV 5/5] END ..max_samples=0.5, n_estimators=50;, score=0.931 total time=   4.9s
# [CV 1/5] END .max_samples=0.5, n_estimators=100;, score=0.931 total time=   9.7s
# [CV 2/5] END .max_samples=0.5, n_estimators=100;, score=0.934 total time=   9.9s
# [CV 3/5] END .max_samples=0.5, n_estimators=100;, score=0.931 total time=   9.8s
# [CV 4/5] END .max_samples=0.5, n_estimators=100;, score=0.932 total time=   9.8s
# [CV 5/5] END .max_samples=0.5, n_estimators=100;, score=0.932 total time=   9.8s
# [CV 1/5] END .max_samples=0.5, n_estimators=200;, score=0.931 total time=  19.4s
# [CV 2/5] END .max_samples=0.5, n_estimators=200;, score=0.933 total time=  19.7s
# [CV 3/5] END .max_samples=0.5, n_estimators=200;, score=0.931 total time=  19.8s
# [CV 4/5] END .max_samples=0.5, n_estimators=200;, score=0.933 total time=  19.7s
# [CV 5/5] END .max_samples=0.5, n_estimators=200;, score=0.933 total time=  19.6s
# [CV 1/5] END .max_samples=0.5, n_estimators=300;, score=0.932 total time=  29.2s
# [CV 2/5] END .max_samples=0.5, n_estimators=300;, score=0.933 total time=  29.6s
# [CV 3/5] END .max_samples=0.5, n_estimators=300;, score=0.932 total time=  29.9s
# [CV 4/5] END .max_samples=0.5, n_estimators=300;, score=0.932 total time=  30.0s
# [CV 5/5] END .max_samples=0.5, n_estimators=300;, score=0.933 total time=  29.8s
# [CV 1/5] END .max_samples=0.5, n_estimators=400;, score=0.932 total time=  38.9s
# [CV 2/5] END .max_samples=0.5, n_estimators=400;, score=0.933 total time=  39.3s
# [CV 3/5] END .max_samples=0.5, n_estimators=400;, score=0.932 total time=  39.8s
# [CV 4/5] END .max_samples=0.5, n_estimators=400;, score=0.933 total time=  39.4s
# [CV 5/5] END .max_samples=0.5, n_estimators=400;, score=0.932 total time=  39.4s
# [CV 1/5] END .max_samples=0.5, n_estimators=500;, score=0.932 total time=  48.8s
# [CV 2/5] END .max_samples=0.5, n_estimators=500;, score=0.933 total time=  49.3s
# [CV 3/5] END .max_samples=0.5, n_estimators=500;, score=0.932 total time=  49.2s
# [CV 4/5] END .max_samples=0.5, n_estimators=500;, score=0.933 total time=  49.8s
# [CV 5/5] END .max_samples=0.5, n_estimators=500;, score=0.932 total time=  51.7s
# [CV 1/5] END ..max_samples=1.0, n_estimators=50;, score=0.930 total time=   8.3s
# [CV 2/5] END ..max_samples=1.0, n_estimators=50;, score=0.932 total time=   8.0s
# [CV 3/5] END ..max_samples=1.0, n_estimators=50;, score=0.930 total time=   8.3s
# [CV 4/5] END ..max_samples=1.0, n_estimators=50;, score=0.928 total time=   8.4s
# [CV 5/5] END ..max_samples=1.0, n_estimators=50;, score=0.930 total time=   8.2s
# [CV 1/5] END .max_samples=1.0, n_estimators=100;, score=0.929 total time=  16.4s
# [CV 2/5] END .max_samples=1.0, n_estimators=100;, score=0.931 total time=  16.5s
# [CV 3/5] END .max_samples=1.0, n_estimators=100;, score=0.930 total time=  16.0s
# [CV 4/5] END .max_samples=1.0, n_estimators=100;, score=0.929 total time=  16.3s
# [CV 5/5] END .max_samples=1.0, n_estimators=100;, score=0.930 total time=  16.0s
# [CV 1/5] END .max_samples=1.0, n_estimators=200;, score=0.930 total time=  31.6s
# [CV 2/5] END .max_samples=1.0, n_estimators=200;, score=0.932 total time=  32.6s
# [CV 3/5] END .max_samples=1.0, n_estimators=200;, score=0.930 total time=  32.0s
# [CV 4/5] END .max_samples=1.0, n_estimators=200;, score=0.929 total time=  32.8s
# [CV 5/5] END .max_samples=1.0, n_estimators=200;, score=0.929 total time=  33.6s
# [CV 1/5] END .max_samples=1.0, n_estimators=300;, score=0.930 total time=  48.4s
# [CV 2/5] END .max_samples=1.0, n_estimators=300;, score=0.932 total time=  50.0s
# [CV 3/5] END .max_samples=1.0, n_estimators=300;, score=0.931 total time=  48.5s
# [CV 4/5] END .max_samples=1.0, n_estimators=300;, score=0.930 total time=  49.1s
# [CV 5/5] END .max_samples=1.0, n_estimators=300;, score=0.930 total time=  49.4s
# [CV 1/5] END .max_samples=1.0, n_estimators=400;, score=0.930 total time= 1.1min
# [CV 2/5] END .max_samples=1.0, n_estimators=400;, score=0.932 total time= 1.1min
# [CV 3/5] END .max_samples=1.0, n_estimators=400;, score=0.931 total time= 1.1min
# [CV 4/5] END .max_samples=1.0, n_estimators=400;, score=0.930 total time= 1.1min
# [CV 5/5] END .max_samples=1.0, n_estimators=400;, score=0.930 total time= 1.1min
# [CV 1/5] END .max_samples=1.0, n_estimators=500;, score=0.930 total time= 1.3min
# [CV 2/5] END .max_samples=1.0, n_estimators=500;, score=0.932 total time= 1.3min
# [CV 3/5] END .max_samples=1.0, n_estimators=500;, score=0.931 total time= 1.3min
# [CV 4/5] END .max_samples=1.0, n_estimators=500;, score=0.930 total time= 1.3min
# [CV 5/5] END .max_samples=1.0, n_estimators=500;, score=0.930 total time= 1.3min
# Best parameters: {'max_samples': 0.5, 'n_estimators': 400}
# Best cross-validation: 0.9323

# %% [markdown]
# # <b> Analysis, Accuracy, and Metrics

# %%
# print classification report on df with best model
from sklearn.metrics import classification_report

# Best parameters: {'max_samples': 0.5, 'n_estimators': 400}
# Best cross-validation: 0.9323

y_pred = grid.best_estimator_.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92     24823
#            1       0.95      0.94      0.94     32721
#            2       0.95      0.86      0.91       539
#
#     accuracy                           0.93     58083
#    macro avg       0.94      0.91      0.92     58083
# weighted avg       0.93      0.93      0.93     58083

# %%
# Generate classification report
report = classification_report(y_test, y_pred, digits=2, output_dict=True)
df = pd.DataFrame(report).T

# Convert support column to integer
df['support'] = df['support'].apply(int)

# Apply background gradient
styled_df = df.style.background_gradient(cmap='viridis', subset=pd.IndexSlice['0':'9', :'f1-score'])

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_dbf76_row0_col0, #T_dbf76_row2_col1, #T_dbf76_row2_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_dbf76_row0_col1 {
#   background-color: #f8e621;
#   color: #000000;
# }
# #T_dbf76_row0_col2 {
#   background-color: #21908d;
#   color: #f1f1f1;
# }
# #T_dbf76_row1_col0 {
#   background-color: #f1e51d;
#   color: #000000;
# }
# #T_dbf76_row1_col1, #T_dbf76_row1_col2, #T_dbf76_row2_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# </style>
# <table id="T_dbf76">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dbf76_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_dbf76_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_dbf76_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_dbf76_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dbf76_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dbf76_row0_col0" class="data row0 col0" >0.913929</td>
#       <td id="T_dbf76_row0_col1" class="data row0 col1" >0.934657</td>
#       <td id="T_dbf76_row0_col2" class="data row0 col2" >0.924177</td>
#       <td id="T_dbf76_row0_col3" class="data row0 col3" >24823</td>
#     </tr>
#     <tr>
#       <th id="T_dbf76_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dbf76_row1_col0" class="data row1 col0" >0.950166</td>
#       <td id="T_dbf76_row1_col1" class="data row1 col1" >0.935240</td>
#       <td id="T_dbf76_row1_col2" class="data row1 col2" >0.942644</td>
#       <td id="T_dbf76_row1_col3" class="data row1 col3" >32721</td>
#     </tr>
#     <tr>
#       <th id="T_dbf76_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dbf76_row2_col0" class="data row2 col0" >0.951020</td>
#       <td id="T_dbf76_row2_col1" class="data row2 col1" >0.864564</td>
#       <td id="T_dbf76_row2_col2" class="data row2 col2" >0.905734</td>
#       <td id="T_dbf76_row2_col3" class="data row2 col3" >539</td>
#     </tr>
#     <tr>
#       <th id="T_dbf76_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_dbf76_row3_col0" class="data row3 col0" >0.934335</td>
#       <td id="T_dbf76_row3_col1" class="data row3 col1" >0.934335</td>
#       <td id="T_dbf76_row3_col2" class="data row3 col2" >0.934335</td>
#       <td id="T_dbf76_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_dbf76_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_dbf76_row4_col0" class="data row4 col0" >0.938372</td>
#       <td id="T_dbf76_row4_col1" class="data row4 col1" >0.911487</td>
#       <td id="T_dbf76_row4_col2" class="data row4 col2" >0.924185</td>
#       <td id="T_dbf76_row4_col3" class="data row4 col3" >58083</td>
#     </tr>
#     <tr>
#       <th id="T_dbf76_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_dbf76_row5_col0" class="data row5 col0" >0.934687</td>
#       <td id="T_dbf76_row5_col1" class="data row5 col1" >0.934335</td>
#       <td id="T_dbf76_row5_col2" class="data row5 col2" >0.934409</td>
#       <td id="T_dbf76_row5_col3" class="data row5 col3" >58083</td>
#     </tr>
#   </tbody>
# </table>

# %%
# print classification report on df2 with {'max_samples': 0.5, 'n_estimators': 400}
bag2 = BaggingClassifier(n_estimators=400, max_samples=0.5, random_state=1234)
bag2.fit(X_train2, y_train2)
y_pred2 = bag2.predict(X_test2)

print(classification_report(y_test2, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.92     24823
#            1       0.95      0.93      0.94     32721
#            2       0.96      0.86      0.91       539
#
#     accuracy                           0.93     58083
#    macro avg       0.94      0.91      0.92     58083
# weighted avg       0.93      0.93      0.93     58083

# %%
# Generate classification report
report = classification_report(y_test2, y_pred2, digits=2, output_dict=True)
df = pd.DataFrame(report).T

# Convert support column to integer
df['support'] = df['support'].apply(int)

# Apply background gradient
styled_df = df.style.background_gradient(cmap='viridis', subset=pd.IndexSlice['0':'9', :'f1-score'])

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_4f03d_row0_col0, #T_4f03d_row2_col1, #T_4f03d_row2_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_4f03d_row0_col1, #T_4f03d_row1_col2, #T_4f03d_row2_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_4f03d_row0_col2 {
#   background-color: #218e8d;
#   color: #f1f1f1;
# }
# #T_4f03d_row1_col0 {
#   background-color: #5ac864;
#   color: #000000;
# }
# #T_4f03d_row1_col1 {
#   background-color: #ece51b;
#   color: #000000;
# }
# </style>
# <table id="T_4f03d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f03d_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_4f03d_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_4f03d_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_4f03d_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f03d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4f03d_row0_col0" class="data row0 col0" >0.912496</td>
#       <td id="T_4f03d_row0_col1" class="data row0 col1" >0.936390</td>
#       <td id="T_4f03d_row0_col2" class="data row0 col2" >0.924288</td>
#       <td id="T_4f03d_row0_col3" class="data row0 col3" >24823</td>
#     </tr>
#     <tr>
#       <th id="T_4f03d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4f03d_row1_col0" class="data row1 col0" >0.951232</td>
#       <td id="T_4f03d_row1_col1" class="data row1 col1" >0.934110</td>
#       <td id="T_4f03d_row1_col2" class="data row1 col2" >0.942593</td>
#       <td id="T_4f03d_row1_col3" class="data row1 col3" >32721</td>
#     </tr>
#     <tr>
#       <th id="T_4f03d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4f03d_row2_col0" class="data row2 col0" >0.964435</td>
#       <td id="T_4f03d_row2_col1" class="data row2 col1" >0.855288</td>
#       <td id="T_4f03d_row2_col2" class="data row2 col2" >0.906588</td>
#       <td id="T_4f03d_row2_col3" class="data row2 col3" >539</td>
#     </tr>
#     <tr>
#       <th id="T_4f03d_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_4f03d_row3_col0" class="data row3 col0" >0.934353</td>
#       <td id="T_4f03d_row3_col1" class="data row3 col1" >0.934353</td>
#       <td id="T_4f03d_row3_col2" class="data row3 col2" >0.934353</td>
#       <td id="T_4f03d_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4f03d_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_4f03d_row4_col0" class="data row4 col0" >0.942721</td>
#       <td id="T_4f03d_row4_col1" class="data row4 col1" >0.908596</td>
#       <td id="T_4f03d_row4_col2" class="data row4 col2" >0.924490</td>
#       <td id="T_4f03d_row4_col3" class="data row4 col3" >58083</td>
#     </tr>
#     <tr>
#       <th id="T_4f03d_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_4f03d_row5_col0" class="data row5 col0" >0.934800</td>
#       <td id="T_4f03d_row5_col1" class="data row5 col1" >0.934353</td>
#       <td id="T_4f03d_row5_col2" class="data row5 col2" >0.934436</td>
#       <td id="T_4f03d_row5_col3" class="data row5 col3" >58083</td>
#     </tr>
#   </tbody>
# </table>
