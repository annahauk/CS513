# %% [markdown]
# # <b> Histogram Gradient Boosting Model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os

df = pd.read_csv(os.path.join('NYPD_Arrest_Data_Clean.csv'))
df2 = pd.read_csv(os.path.join('NYPD_Arrest_Data_Clean_Demographics.csv'))

# %%
df
# Out:
#         OFNS_DESC  OFFENSE_LEVEL  ARREST_PRECINCT  JURISDICTION_CODE  \
# 0              17              0              105                  0
# 1               4              0              107                 71
# 2              17              0               48                  0
# 3              17              0              121                  0
# 4              17              0              100                  0
# ...           ...            ...              ...                ...
# 193605         47              1              109                  0
# 193606          5              1               34                  0
# 193607          7              0               23                  0
# 193608         43              1               44                  1
# 193609         13              0               46                  0
#
#          Latitude  Longitude  MONTH   FALL  SPRING  SUMMER  WINTER  BRONX  \
# 0       40.737043 -73.735514      1  False   False   False    True  False
# 1       40.732881 -73.807899      2  False   False   False    True  False
# 2       40.855109 -73.892818      3  False    True   False   False   True
# 3       40.628967 -74.163275      5  False    True   False   False  False
# 4       40.591980 -73.800066      6  False   False    True   False  False
# ...           ...        ...    ...    ...     ...     ...     ...    ...
# 193605  40.757691 -73.834115      9   True   False   False   False  False
# 193606  40.856808 -73.928265      9   True   False   False   False  False
# 193607  40.786116 -73.942614      9   True   False   False   False  False
# 193608  40.827812 -73.925929      9   True   False   False   False   True
# 193609  40.854588 -73.901861      9   True   False   False   False   True
#
#         BROOKLYN  MANHATTAN  QUEENS  STATEN_ISLAND
# 0          False      False    True          False
# 1          False      False    True          False
# 2          False      False   False          False
# 3          False      False   False           True
# 4          False      False    True          False
# ...          ...        ...     ...            ...
# 193605     False      False    True          False
# 193606     False       True   False          False
# 193607     False       True   False          False
# 193608     False      False   False          False
# 193609     False      False   False          False
#
# [193610 rows x 16 columns]

# %%
df2
# Out:
#         OFNS_DESC  OFFENSE_LEVEL  ARREST_PRECINCT  JURISDICTION_CODE  \
# 0              17              0              105                  0
# 1               4              0              107                 71
# 2              17              0               48                  0
# 3              17              0              121                  0
# 4              17              0              100                  0
# ...           ...            ...              ...                ...
# 193605         47              1              109                  0
# 193606          5              1               34                  0
# 193607          7              0               23                  0
# 193608         43              1               44                  1
# 193609         13              0               46                  0
#
#          Latitude  Longitude  MONTH   FALL  SPRING  SUMMER  ...  \
# 0       40.737043 -73.735514      1  False   False   False  ...
# 1       40.732881 -73.807899      2  False   False   False  ...
# 2       40.855109 -73.892818      3  False    True   False  ...
# 3       40.628967 -74.163275      5  False    True   False  ...
# 4       40.591980 -73.800066      6  False   False    True  ...
# ...           ...        ...    ...    ...     ...     ...  ...
# 193605  40.757691 -73.834115      9   True   False   False  ...
# 193606  40.856808 -73.928265      9   True   False   False  ...
# 193607  40.786116 -73.942614      9   True   False   False  ...
# 193608  40.827812 -73.925929      9   True   False   False  ...
# 193609  40.854588 -73.901861      9   True   False   False  ...
#
#         AGE_GROUP_<18  PERP_SEX_F  PERP_SEX_M  \
# 0               False       False        True
# 1               False       False        True
# 2               False       False        True
# 3               False       False        True
# 4               False       False        True
# ...               ...         ...         ...
# 193605          False       False        True
# 193606          False       False        True
# 193607          False       False        True
# 193608          False       False        True
# 193609          False       False        True
#
#         PERP_RACE_AMERICAN INDIAN/ALASKAN NATIVE  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ...                                          ...
# 193605                                     False
# 193606                                     False
# 193607                                     False
# 193608                                     False
# 193609                                     False
#
#         PERP_RACE_ASIAN / PACIFIC ISLANDER  PERP_RACE_BLACK  \
# 0                                    False            False
# 1                                    False            False
# 2                                    False             True
# 3                                    False            False
# 4                                    False             True
# ...                                    ...              ...
# 193605                               False            False
# 193606                               False            False
# 193607                               False            False
# 193608                               False             True
# 193609                               False            False
#
#         PERP_RACE_BLACK HISPANIC  PERP_RACE_UNKNOWN  PERP_RACE_WHITE  \
# 0                          False              False             True
# 1                          False              False             True
# 2                          False              False            False
# 3                          False              False             True
# 4                          False              False            False
# ...                          ...                ...              ...
# 193605                     False              False            False
# 193606                     False              False            False
# 193607                     False              False             True
# 193608                     False              False            False
# 193609                      True              False            False
#
#         PERP_RACE_WHITE HISPANIC
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# ...                          ...
# 193605                      True
# 193606                      True
# 193607                     False
# 193608                     False
# 193609                     False
#
# [193610 rows x 30 columns]

# %%
from sklearn.model_selection import train_test_split

X = df.drop(columns='OFFENSE_LEVEL')
y = df['OFFENSE_LEVEL']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

X2 = df2.drop(columns='OFFENSE_LEVEL')
y2 = df2['OFFENSE_LEVEL']

X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size=0.3, random_state=1234)

# %% [markdown]
# # <b> Histogram Gradient Classifier for Data without Demographics

# %%
# hist gradient booster classifier on df
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.metrics import accuracy_score

hgb = HistGradientBoostingClassifier(max_iter=1000, random_state=1234)
hgb.fit(X_train, y_train)
y_pred = hgb.predict(X_test)

accuracy_score(y_test, y_pred)

print('Accuracy: {:.4f}'.format(accuracy_score(y_test, y_pred)))
# Out:
# Accuracy: 0.9301

# %% [markdown]
# # <b> Histogram Gradient Classifier for Data with Demographics

# %%
# hist gradient booster classifier on df2
hgb2 = HistGradientBoostingClassifier(max_iter=1000, random_state=1234)
hgb2.fit(X_train2, y_train2)
y_pred2 = hgb2.predict(X_test2)

accuracy_score(y_test2, y_pred2)

print('Accuracy: {:.4f}'.format(accuracy_score(y_test2, y_pred2)))
# Out:
# Accuracy: 0.9337

# %% [markdown]
# # <b> Hyperparameter Tuning

# %%
# gridsearchcv on df
from sklearn.model_selection import GridSearchCV

param_grid = {'learning_rate': [0.1, 0.01],
                'max_depth': [3, 5, 7],
                'l2_regularization': [0.1, 0.01]}
grid_search = GridSearchCV(hgb, param_grid, cv=3, verbose=3)
grid_search.fit(X_train, y_train)

print('Best parameters: {}'.format(grid_search.best_params_))
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV 1/3] END l2_regularization=0.1, learning_rate=0.1, max_depth=3;, score=0.929 total time=   3.3s
# [CV 2/3] END l2_regularization=0.1, learning_rate=0.1, max_depth=3;, score=0.927 total time=   3.3s
# [CV 3/3] END l2_regularization=0.1, learning_rate=0.1, max_depth=3;, score=0.929 total time=   3.7s
# [CV 1/3] END l2_regularization=0.1, learning_rate=0.1, max_depth=5;, score=0.930 total time=   3.4s
# [CV 2/3] END l2_regularization=0.1, learning_rate=0.1, max_depth=5;, score=0.929 total time=   4.0s
# [CV 3/3] END l2_regularization=0.1, learning_rate=0.1, max_depth=5;, score=0.931 total time=   3.8s
# [CV 1/3] END l2_regularization=0.1, learning_rate=0.1, max_depth=7;, score=0.931 total time=   3.5s
# [CV 2/3] END l2_regularization=0.1, learning_rate=0.1, max_depth=7;, score=0.930 total time=   3.5s
# [CV 3/3] END l2_regularization=0.1, learning_rate=0.1, max_depth=7;, score=0.931 total time=   3.8s
# [CV 1/3] END l2_regularization=0.1, learning_rate=0.01, max_depth=3;, score=0.924 total time=  12.6s
# [CV 2/3] END l2_regularization=0.1, learning_rate=0.01, max_depth=3;, score=0.924 total time=  12.9s
# [CV 3/3] END l2_regularization=0.1, learning_rate=0.01, max_depth=3;, score=0.926 total time=  12.7s
# [CV 1/3] END l2_regularization=0.1, learning_rate=0.01, max_depth=5;, score=0.931 total time=  24.6s
# [CV 2/3] END l2_regularization=0.1, learning_rate=0.01, max_depth=5;, score=0.929 total time=  25.5s
# [CV 3/3] END l2_regularization=0.1, learning_rate=0.01, max_depth=5;, score=0.929 total time=  25.4s
# [CV 1/3] END l2_regularization=0.1, learning_rate=0.01, max_depth=7;, score=0.929 total time=  22.0s
# [CV 2/3] END l2_regularization=0.1, learning_rate=0.01, max_depth=7;, score=0.929 total time=  30.7s
# [CV 3/3] END l2_regularization=0.1, learning_rate=0.01, max_depth=7;, score=0.932 total time=  33.0s
# [CV 1/3] END l2_regularization=0.01, learning_rate=0.1, max_depth=3;, score=0.929 total time=   2.9s
# [CV 2/3] END l2_regularization=0.01, learning_rate=0.1, max_depth=3;, score=0.928 total time=   3.6s
# [CV 3/3] END l2_regularization=0.01, learning_rate=0.1, max_depth=3;, score=0.928 total time=   3.7s
# [CV 1/3] END l2_regularization=0.01, learning_rate=0.1, max_depth=5;, score=0.930 total time=   3.3s
# [CV 2/3] END l2_regularization=0.01, learning_rate=0.1, max_depth=5;, score=0.929 total time=   3.4s
# [CV 3/3] END l2_regularization=0.01, learning_rate=0.1, max_depth=5;, score=0.930 total time=   3.3s
# [CV 1/3] END l2_regularization=0.01, learning_rate=0.1, max_depth=7;, score=0.930 total time=   2.5s
# [CV 2/3] END l2_regularization=0.01, learning_rate=0.1, max_depth=7;, score=0.929 total time=   3.0s
# [CV 3/3] END l2_regularization=0.01, learning_rate=0.1, max_depth=7;, score=0.931 total time=   4.5s
# [CV 1/3] END l2_regularization=0.01, learning_rate=0.01, max_depth=3;, score=0.924 total time=  13.1s
# [CV 2/3] END l2_regularization=0.01, learning_rate=0.01, max_depth=3;, score=0.925 total time=  13.7s
# [CV 3/3] END l2_regularization=0.01, learning_rate=0.01, max_depth=3;, score=0.926 total time=  13.7s
# [CV 1/3] END l2_regularization=0.01, learning_rate=0.01, max_depth=5;, score=0.930 total time=  25.7s
# [CV 2/3] END l2_regularization=0.01, learning_rate=0.01, max_depth=5;, score=0.930 total time=  24.8s
# [CV 3/3] END l2_regularization=0.01, learning_rate=0.01, max_depth=5;, score=0.930 total time=  25.3s
# [CV 1/3] END l2_regularization=0.01, learning_rate=0.01, max_depth=7;, score=0.929 total time=  23.8s
# [CV 2/3] END l2_regularization=0.01, learning_rate=0.01, max_depth=7;, score=0.929 total time=  24.2s
# [CV 3/3] END l2_regularization=0.01, learning_rate=0.01, max_depth=7;, score=0.931 total time=  29.6s
# Best parameters: {'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_depth': 7}

# %% [markdown]
# # <b> Analysis, Accuracy, and Metrics

# %%
# Best parameters: {'l2_regularization': 0.1, 'learning_rate': 0.1, 'max_depth': 7}
# make Hist gradient booster classifier with best parameters
hgb_best = HistGradientBoostingClassifier(max_iter=1000, random_state=1234, l2_regularization=0.1, learning_rate=0.1, max_depth=7)
hgb_best.fit(X_train, y_train)
y_pred_best = hgb_best.predict(X_test)

accuracy_score(y_test, y_pred_best)
# Out:
# 0.9314085016269821

# %%
# make a hist gradient booster classifier with best parameters on df2
hgb_best2 = HistGradientBoostingClassifier(max_iter=1000, random_state=1234, l2_regularization=0.1, learning_rate=0.1, max_depth=7)
hgb_best2.fit(X_train2, y_train2)
y_pred_best2 = hgb_best2.predict(X_test2)

accuracy_score(y_test2, y_pred_best2)
# Out:
# 0.9338016287037515

# %%
# generate a classification report for df and df2
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_best))

print(classification_report(y_test2, y_pred_best2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92     24823
#            1       0.96      0.92      0.94     32721
#            2       0.96      0.86      0.91       539
#
#     accuracy                           0.93     58083
#    macro avg       0.94      0.91      0.92     58083
# weighted avg       0.93      0.93      0.93     58083
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92     24823
#            1       0.96      0.93      0.94     32721
#            2       0.97      0.86      0.91       539
#
#     accuracy                           0.93     58083
#    macro avg       0.94      0.91      0.93     58083
# weighted avg       0.93      0.93      0.93     58083

# %%
# Generate classification report
report = classification_report(y_test, y_pred, digits=2, output_dict=True)
df = pd.DataFrame(report).T

# Convert support column to integer
df['support'] = df['support'].apply(int)

# Apply background gradient
styled_df = df.style.background_gradient(cmap='viridis', subset=pd.IndexSlice['0':'9', :'f1-score'])

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_a888b_row0_col0, #T_a888b_row2_col1, #T_a888b_row2_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_a888b_row0_col1, #T_a888b_row1_col0, #T_a888b_row1_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_a888b_row0_col2 {
#   background-color: #2cb17e;
#   color: #f1f1f1;
# }
# #T_a888b_row1_col1 {
#   background-color: #1f958b;
#   color: #f1f1f1;
# }
# #T_a888b_row2_col0 {
#   background-color: #22a785;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a888b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a888b_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_a888b_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_a888b_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_a888b_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a888b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a888b_row0_col0" class="data row0 col0" >0.887117</td>
#       <td id="T_a888b_row0_col1" class="data row0 col1" >0.958949</td>
#       <td id="T_a888b_row0_col2" class="data row0 col2" >0.921635</td>
#       <td id="T_a888b_row0_col3" class="data row0 col3" >24823</td>
#     </tr>
#     <tr>
#       <th id="T_a888b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a888b_row1_col0" class="data row1 col0" >0.967552</td>
#       <td id="T_a888b_row1_col1" class="data row1 col1" >0.909477</td>
#       <td id="T_a888b_row1_col2" class="data row1 col2" >0.937616</td>
#       <td id="T_a888b_row1_col3" class="data row1 col3" >32721</td>
#     </tr>
#     <tr>
#       <th id="T_a888b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a888b_row2_col0" class="data row2 col0" >0.935091</td>
#       <td id="T_a888b_row2_col1" class="data row2 col1" >0.855288</td>
#       <td id="T_a888b_row2_col2" class="data row2 col2" >0.893411</td>
#       <td id="T_a888b_row2_col3" class="data row2 col3" >539</td>
#     </tr>
#     <tr>
#       <th id="T_a888b_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_a888b_row3_col0" class="data row3 col0" >0.930117</td>
#       <td id="T_a888b_row3_col1" class="data row3 col1" >0.930117</td>
#       <td id="T_a888b_row3_col2" class="data row3 col2" >0.930117</td>
#       <td id="T_a888b_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a888b_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_a888b_row4_col0" class="data row4 col0" >0.929920</td>
#       <td id="T_a888b_row4_col1" class="data row4 col1" >0.907905</td>
#       <td id="T_a888b_row4_col2" class="data row4 col2" >0.917554</td>
#       <td id="T_a888b_row4_col3" class="data row4 col3" >58083</td>
#     </tr>
#     <tr>
#       <th id="T_a888b_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_a888b_row5_col0" class="data row5 col0" >0.932875</td>
#       <td id="T_a888b_row5_col1" class="data row5 col1" >0.930117</td>
#       <td id="T_a888b_row5_col2" class="data row5 col2" >0.930376</td>
#       <td id="T_a888b_row5_col3" class="data row5 col3" >58083</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Generate classification report
report = classification_report(y_test2, y_pred2, digits=2, output_dict=True)
df = pd.DataFrame(report).T

# Convert support column to integer
df['support'] = df['support'].apply(int)

# Apply background gradient
styled_df = df.style.background_gradient(cmap='viridis', subset=pd.IndexSlice['0':'9', :'f1-score'])

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_d2e29_row0_col0, #T_d2e29_row2_col1, #T_d2e29_row2_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_d2e29_row0_col1, #T_d2e29_row1_col0, #T_d2e29_row1_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_d2e29_row0_col2 {
#   background-color: #23a983;
#   color: #f1f1f1;
# }
# #T_d2e29_row1_col1 {
#   background-color: #63cb5f;
#   color: #000000;
# }
# #T_d2e29_row2_col0 {
#   background-color: #3bbb75;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d2e29">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2e29_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_d2e29_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_d2e29_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_d2e29_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2e29_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d2e29_row0_col0" class="data row0 col0" >0.903500</td>
#       <td id="T_d2e29_row0_col1" class="data row0 col1" >0.946340</td>
#       <td id="T_d2e29_row0_col2" class="data row0 col2" >0.924424</td>
#       <td id="T_d2e29_row0_col3" class="data row0 col3" >24823</td>
#     </tr>
#     <tr>
#       <th id="T_d2e29_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d2e29_row1_col0" class="data row1 col0" >0.958469</td>
#       <td id="T_d2e29_row1_col1" class="data row1 col1" >0.925369</td>
#       <td id="T_d2e29_row1_col2" class="data row1 col2" >0.941628</td>
#       <td id="T_d2e29_row1_col3" class="data row1 col3" >32721</td>
#     </tr>
#     <tr>
#       <th id="T_d2e29_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d2e29_row2_col0" class="data row2 col0" >0.941057</td>
#       <td id="T_d2e29_row2_col1" class="data row2 col1" >0.858998</td>
#       <td id="T_d2e29_row2_col2" class="data row2 col2" >0.898157</td>
#       <td id="T_d2e29_row2_col3" class="data row2 col3" >539</td>
#     </tr>
#     <tr>
#       <th id="T_d2e29_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_d2e29_row3_col0" class="data row3 col0" >0.933716</td>
#       <td id="T_d2e29_row3_col1" class="data row3 col1" >0.933716</td>
#       <td id="T_d2e29_row3_col2" class="data row3 col2" >0.933716</td>
#       <td id="T_d2e29_row3_col3" class="data row3 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d2e29_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_d2e29_row4_col0" class="data row4 col0" >0.934342</td>
#       <td id="T_d2e29_row4_col1" class="data row4 col1" >0.910236</td>
#       <td id="T_d2e29_row4_col2" class="data row4 col2" >0.921403</td>
#       <td id="T_d2e29_row4_col3" class="data row4 col3" >58083</td>
#     </tr>
#     <tr>
#       <th id="T_d2e29_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_d2e29_row5_col0" class="data row5 col0" >0.934815</td>
#       <td id="T_d2e29_row5_col1" class="data row5 col1" >0.933716</td>
#       <td id="T_d2e29_row5_col2" class="data row5 col2" >0.933872</td>
#       <td id="T_d2e29_row5_col3" class="data row5 col3" >58083</td>
#     </tr>
#   </tbody>
# </table>
